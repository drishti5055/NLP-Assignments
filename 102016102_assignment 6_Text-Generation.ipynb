# %% [markdown]
# # Text Generation

# %% [markdown]
# ## Introduction

# %% [markdown]
# Markov chains can be used for very basic text generation. Think about every word in a corpus as a state. We can make a simple assumption that the next word is only dependent on the previous word - which is the basic assumption of a Markov chain.
#
# Markov chains don't generate text as well as deep learning, but it's a good (and fun!) start.

# %% [markdown]
# ## Select Text to Imitate

# %% [markdown]
# In this notebook, we're specifically going to generate text in the style of Ali Wong, so as a first step, let's extract the text from her comedy routine.

# %%
# Read in the corpus, including punctuation!
import pandas as pd

data = pd.read_pickle('corpus.pkl')
data
# Out:
#                                                 transcript         full_name
# ali      Ladies and gentlemen, please welcome to the st...          Ali Wong
# anthony  Thank you. Thank you. Thank you, San Francisco...  Anthony Jeselnik
# bill     [cheers and applause] All right, thank you! Th...         Bill Burr
# dave     This is Dave. He tells dirty jokes for a livin...    Dave Chappelle
# jim      [Car horn honks] [Audience cheering] [Announce...     Jim Jefferies
# joe      [rock music playing] [audience cheering] [anno...         Joe Rogan
# john     Armed with boyish charm and a sharp wit, the f...      John Mulaney
# louis    Intro Fade the music out. Let’s roll. Hold the...        Louis C.K.
# mike     Wow. Hey, thank you. Thanks. Thank you, guys. ...    Mike Birbiglia
# ricky    Hello. Hello! How you doing? Great. Thank you....     Ricky Gervais

# %%
# Extract only Ali Wong's text
ali_text = data.transcript.loc['ali']
ali_text[:200]
# Out:
# 'Ladies and gentlemen, please welcome to the stage: Ali Wong! Hi. Hello! Welcome! Thank you! Thank you for coming. Hello! Hello. We are gonna have to get this shit over with, ’cause I have to pee in, l'

# %%
ali_text = data.transcript.loc['ali']
ali_text
# Out:
# "Ladies and gentlemen, please welcome to the stage: Ali Wong! Hi. Hello! Welcome! Thank you! Thank you for coming. Hello! Hello. We are gonna have to get this shit over with, ’cause I have to pee in, like, ten minutes. But thank you, everybody, so much for coming. Um… It’s a very exciting day for me. It’s been a very exciting year for me. I turned 33 this year. Yes! Thank you, five people. I appreciate that. Uh, I can tell that I’m getting older, because, now, when I see an 18-year-old girl, my automatic thought… is “Fuck you.” “Fuck you. I don’t even know you, but fuck you!” ‘Cause I’m straight up jealous. I’m jealous, first and foremost, of their metabolism. Because 18-year-old girls, they could just eat like shit, and then they take a shit and have a six-pack, right? They got that-that beautiful inner thigh clearance where they put their feet together and there’s that huge gap here with the light of potential just radiating through. And then, when they go to sleep, they just go to sleep. Right? They don’t have insomnia yet. They don’t know what it’s like to have to take a Ambien or download a Meditation Oasis podcast to calm the chatter of regret and resentment towards your family just cluttering your mind. They have their whole lives ahead of them. They don’t have HPV yet. They just go to sleep in peace at night. Everybody has HPV, OK? Everybody has it. It’s OK. Come out already. Everybody has it. If you don’t have it yet, you go and get it. You go and get it. It’s coming. You don’t have HPV yet, you’re a fucking loser, all right? That’s what that says about you. A lot of men don’t know that they have HPV, because it’s undetectable in men. It’s really fucked up. HPV is a ghost that lives inside men’s bodies and says, “Boo!” in women’s bodies. My doctor told me that I have one of two strains of HPV. Either I have the kind that’s gonna turn into cervical cancer… …or I have the kind where my body will heal itself. Very helpful, this doctor, right? So, basically, either I’m gonna die… or you’re in the presence of Wolverine, bitches. We’ll find out. Um, I can also tell that I’m getting older, because my Kindle is turning into a self-help library. I’m not interested in books like Fifty Shades of Grey, OK? I’m interested in The Life-Changing Magic of Tidying Up. Yes. Yes, that’s right, how to declutter my home to achieve inner peace and my optimum level of success. That’s what your 30s is all about. How can I turn this shit around? I’m a horrible person, I’m not happy with where I am, how can I turn this shit around? Help me, Tony Robbins, help me! I have a hoarding problem, which I’m hoping is the center of all of my other problems. I’m hoping that if the hoarding goes away, the HPV will also disappear. I have a hoarding problem because my mom is from a third world country and she taught me that you can never throw away anything, because you never know when a dictator’s gonna overtake the country and snatch all your wealth. So, you better hold onto that retainer from the third grade, ’cause it might come in handy as a shovel when you’re busy stuffing gold up your butt and running away from the Communists. The last time I was at home in San Francisco, I was trying to help her get rid of shit. Don’t ever do that with your mom. It was like the worst experience of my life. It was so emotional. We were screaming and fighting and yelling and it all came to a climax when she refused to let go of a Texas Instruments TI-82… manual. The manual. She don’t even know… where the calculator is. Those of you under 25 probably don’t know what that calculator is. It was this calculator that bamboozled my generation. We were all required to buy it when we were in eight grade. It cost like $200. And everybody thought it was like this Judy Jetson’s laptop from the future. All because what? It could graph. It was like the Tesla of my time. And my mom got so emotional about the manual and she was like, “You never know when you might need this.” And I  ...

# %% [markdown]
# ## Build a Markov Chain Function

# %% [markdown]
# We are going to build a simple Markov chain function that creates a dictionary:
# * The keys should be all of the words in the corpus
# * The values should be a list of the words that follow the keys

# %%
from collections import defaultdict

def markov_chain(text):
    '''The input is a string of text and the output will be a dictionary with each word as
       a key and each value as the list of words that come after the key in the text.'''
    
    # Tokenize the text by word, though including punctuation
    words = text.split(' ')
    
    # Initialize a default dictionary to hold all of the words and next words
    m_dict = defaultdict(list)
    
    # Create a zipped list of all of the word pairs and put them in word: list of next words format
    for current_word, next_word in zip(words[0:-1], words[1:]):
        m_dict[current_word].append(next_word)

    # Convert the default dict back into a dictionary
    m_dict = dict(m_dict)
    return m_dict

# %%
# Create the dictionary for Ali's routine, take a look at it
ali_dict = markov_chain(ali_text)
ali_dict
# Out:
# {'Ladies': ['and'],
#  'and': ['gentlemen,',
#   'foremost,',
#   'then',
#   'have',
#   'there’s',
#   'resentment',
#   'get',
#   'get',
#   'says,',
#   'my',
#   'she',
#   'snatch',
#   'running',
#   'fighting',
#   'yelling',
#   'it',
#   'she',
#   'I',
#   'I',
#   'I',
#   'we',
#   'watched',
#   'I',
#   'have',
#   'that',
#   'recycling,',
#   'disturbing',
#   'it’s',
#   'all',
#   'just…',
#   'be',
#   'half-Vietnamese.',
#   'his',
#   'slide.',
#   'your',
#   'inflamed',
#   'you’re',
#   'I',
#   'half-Japanese',
#   'I’m',
#   'half-Vietnamese.',
#   'playing',
#   'rugby.',
#   'foremost,',
#   'a',
#   'emotionally',
#   'I',
#   '20',
#   'neither',
#   'I',
#   'I–',
#   'then',
#   'it’s',
#   'find',
#   'start',
#   'just',
#   'caves',
#   'gets',
#   'is',
#   'very',
#   'for',
#   'I',
#   'she',
#   'rise',
#   'be',
#   'eat',
#   'watch',
#   'be',
#   'now',
#   'most',
#   'in',
#   'then',
#   'digitally',
#   'then',
#   'then',
#   'then',
#   'steady',
#   'brings',
#   'let',
#   'reverberate',
#   'say,',
#   'my',
#   'he',
#   'when',
#   'I’m',
#   'sicker,',
#   'sicker.',
#   'sicker,',
#   'sicker,',
#   'posted',
#   'that’s',
#   'lies.',
#   'as',
#   'treat',
#   'you’ll',
#   'succeed,',
#   'they',
#   'that’s',
#   'be',
#   'just',
#   'sisters.',
#   'a',
#   'unusual',
#   'they’ll',
#   'boring.”',
#   'wearing',
#   'famous',
#   'you’re',
#   'just',
#   'therefore,',
#   'ignore',
#   'the',
#   'Biggie',
#   'your',
#   'there',
#   'I',
#   'Push',
#   'then,',
#   'melt',
#   'I',
#   'then',
#   'sniff',
#   'I',
#   'you’ve',
#   'outside',
#   'as',
#   'rapey',
#   'most',
#   'see',
#   'I’d',
#   'I',
#   'he',
#   'instead',
#   'remember',
#   'hold',
#   'I',
#   'do',
#   'to',
#   'a',
#   'terrible.',
#   'I',
#   'when',
#   'I',
#   'held',
#   'got',
#   'I',
#   'your',
#   'he',
#   'I',
#   'leaves',
#   'dark.',
#   'naked,',
#   'a',
#   'my',
#   'then',
#   'recently',
#   'a'],
#  'gentlemen,': ['please'],
#  'please': ['welcome'],
#  'welcome': ['to'],
#  'to': ['the',
#   'get',
#   'pee',
#   'sleep,',
#   'sleep.',
#   'have',
#   'take',
#   'calm',
#   'sleep',
#   'declutter',
#   'achieve',
#   'help',
#   'a',
#   'let',
#   'buy',
#   'clean',
#   'be',
#   'Deepak-Oprah,',
#   'achieve',
#   'trap',
#   'date',
#   'any',
#   'cool',
#   'be',
#   'go',
#   'say',
#   'a',
#   'be',
#   'do',
#   'private',
#   'this',
#   'see',
#   'leave',
#   'private',
#   'backpack',
#   'do',
#   'shut',
#   'go',
#   'be',
#   'do',
#   'incept',
#   'leave',
#   'go',
#   'my',
#   'send',
#   'him',
#   'be',
#   'sit',
#   'the',
#   'lie',
#   'women.',
#   'be',
#   'continue',
#   'do',
#   'have',
#   'show',
#   'work.',
#   'earn',
#   'shit',
#   'seat.',
#   'eat',
#   'pull',
#   'ration',
#   'try',
#   'make',
#   'moisten',
#   'come',
#   'start',
#   'make',
#   'just',
#   'the',
#   'podcasts.',
#   'me',
#   'come',
#   'me',
#   'get',
#   'work',
#   'eat',
#   'tell',
#   'get',
#   'you',
#   'make',
#   'fuck',
#   'marry',
#   'turn',
#   'you.',
#   'put',
#   'do',
#   'help',
#   'show',
#   'spank',
#   'abuse',
#   'be',
#   'be',
#   'do.',
#   'her,',
#   'use',
#   'say,',
#   'get',
#   'the',
#   'take',
#   'see',
#   'think',
#   'heal',
#   'me.',
#   'me',
#   'live',
#   'die.',
#   'hide',
#   'alert',
#   'have',
#   'keep',
#   'go.',
#   'be',
#   'support',
#   'be',
#   'the',
#   'protect',
#   'see',
#   'have',
#   'show',
#   'be.',
#   'get',
#   'get',
#   'take',
#   'act',
#   'find',
#   'discretely',
#   'immediately',
#   'be',
#   'smell',
#   'protect',
#   'see',
#   'have',
#   'get',
#   'save',
#   'be',
#   'close',
#   'shut',
#   'see',
#   'finish,',
#   'finish.',
#   'come',
#   'make',
#   'be',
#   'be…',
#   'be',
#   'me,',
#   'do',
#   'do',
#   'see',
#   'hire',
#   'Keyser',
#   'freak',
#   'freak',
#   'it.”',
#   'cleanse.',
#   'assist',
#   'make',
#   'do',
#   'be',
#   'be',
#   'all',
#   'all',
#   'go',
#   'those',
#   'see',
#   'chip',
#   'keep',
#   'get',
#   'protect',
#   'trap',
#   'propose',
#   'me.',
#   'Harvard'],
#  'the': ['stage:',
#   'light',
#   'chatter',
#   'kind',
#   'kind',
#   'presence',
#   'center',
#   'hoarding',
#   'HPV',
#   'country',
#   'third',
#   'Communists.',
#   'worst',
#   'calculator',
#   'future.',
#   'Tesla',
#   'manual',
#   'way',
#   'lucky',
#   'outside,',
#   'inside.',
#   'first',
#   'time,',
#   'fifth',
#   'back',
#   'park.”',
#   'middle',
#   'money',
#   'colonizer!”',
#   'time.',
#   'sexiest.',
#   'sexiest.',
#   'neck',
#   'last',
#   'rug',
#   'umami',
#   'difference.',
#   'Chinese,',
#   'Japanese.',
#   'East',
#   'west',
#   'name,',
#   'bathroom.',
#   'bathroom',
#   'corner.',
#   'wait',
#   'wall…',
#   'fuck',
#   'house.',
#   'idea',
#   'man’s',
#   'message,',
#   'whole',
#   'shit',
#   'fuck',
#   'woman',
#   'exact',
#   'following',
#   'goodness',
#   'C.O.O.',
#   'table',
#   'top.',
#   'fuck',
#   'worst',
#   'smart',
#   'next',
#   'secret.”',
#   'phrase,',
#   'street.',
#   'Boat',
#   'best',
#   'desert.',
#   'stall.',
#   'end',
#   'day',
#   'Goonies.',
#   'velocity',
#   'butt',
#   'doo',
#   'toilet',
#   'ends',
#   'toilet.',
#   'toilet',
#   'other',
#   'nerve',
#   'same',
#   'rest',
#   'promise',
#   'Internet',
#   'back.',
#   'Internet',
#   'Jewish',
#   'universe',
#   'pain.”',
#   'pain.',
#   'pain.',
#   'dick.',
#   'butt,',
#   'tush-tush.',
#   'man',
#   'look',
#   'man’s',
#   'first',
#   'woman,',
#   'Lord',
#   'Rim,',
#   'most',
#   'most',
#   'woman',
#   'time,',
#   'boss.',
#   'boss',
#   'time,',
#   'bedroom,',
#   'boss.',
#   'real',
#   'word',
#   'word',
#   'right',
#   'point',
#   'kind',
#   'case',
#   'audience',
#   'mom',
#   'fucking',
#   'baby’s',
#   'dream.”',
#   'point.',
#   'ultimate',
#   'world',
#   'rest',
#   'Galapagos,',
#   'phrase',
#   'women,',
#   'side',
#   'hood,',
#   'movie,',
#   'park,',
#   'sun.',
#   'sun',
#   'Tupac',
#   'time?',
#   'time,',
#   'peace',
#   'pill',
#   'progesterone',
#   'conference',
#   'urge',
#   'hood.',
#   'eggs',
#   'month,',
#   "Kraken!'”",
#   'time,',
#   'smiley',
#   'ovulation',
#   'time,',
#   'image',
#   'back',
#   'expression',
#   'fuck',
#   'indication',
#   'eye',
#   'shit',
#   'doctor',
#   'size',
#   'twins',
#   'toilet,',
#   'whole',
#   'fuck',
#   'marriage',
#   'pain',
#   'table?”',
#   'labor',
#   'floor',
#   'love',
#   'real',
#   'baby',
#   'house.',
#   'dishes?”',
#   'plants?”',
#   'channel.”',
#   'star',
#   'show.',
#   'camera',
#   'hero',
#   'baby',
#   'baby',
#   'kind',
#   'baby',
#   'same.',
#   'escrow',
#   'one',
#   'epicenter'],
#  'stage:': ['Ali'],
#  'Ali': ['Wong!', 'Wong.'],
#  'Wong!': ['Hi.'],
#  'Hi.': ['Hello!'],
#  'Hello!': ['Welcome!', 'Hello.'],
#  'Welcome!': ['Thank'],
#  'Thank': ['you!', 'you', 'you,', 'you.'],
#  'you!': ['Thank'],
#  'you': ['for',
#   'don’t',
#   'go',
#   'can',
#   'never',
#   'better',
#   'under',
#   'might',
#   'die.”',
#   'wanna',
#   'gotta',
#   'a',
#   'drop',
#   'know,',
#   'know,',
#   'feel',
#   'know.',
#   'know,',
#   'about',
#   'to',
#   'know,',
#   'right',
#   'get',
#   'like!',
#   'know?',
#   'know?',
#   'know,',
#   'can',
#   'eat',
#   'queef',
#   'know,',
#   'know',
#   'marry',
#   'something.',
#   'would',
#   'don’t',
#   'know',
#   'know',
#   'have',
#   'could',
#   'can',
#   'always',
#   'hurry,',
#   'never',
#   'dare',
#   'know,',
#   'deep,',
#   'not',
#   'guys',
#   'wanna',
#   'guys',
#   'telling',
#   'son',
#   'start',
#   'crave',
#   'realize',
#   'know…',
#   'now.',
#   'gotta',
#   'don’t',
#   'put',
#   'know?',
#   'haven’t',
#   'know,',
#   'stick',
#   'know?',
#   'just',
#   'as',
#   'know?',
#   'OK?',
#   'all',
#   'respect',
#   'need',
#   'know?',
#   'what',
#   'be',
#   'so,',
#   'know?',
#   'know',
#   'guys',
#   'gonna',
#   'know?',
#   'gonna',
#   'just',
#   'want',
#   'know',
#   'know?',
#   'remember',
#   'were',
#   'just',
#   'could',
#   'throw',
#   'scratch',
#   'can',
#   'urgently',
#   'gotta',
#   'need',
#   'do',
#   'when',
#   'when',
#   'to',
#   'know?',
#   'that–',
#   'know',
#   'push,',
#   'push,',
#   'push,',
#   'think',
#   'wash',
#   'water',
#   'makin’',
#   'about',
#   'get',
#   'know?',
#   'know,',
#   'see',
#   'know?',
#   'know,',
#   'think'],
#  'for': ['coming.',
#   'coming.',
#   'me.',
#   'me.',
#   'me',
#   'my',
#   'fashion',
#   'warmth?',
#   'marriage,',
#   'them.',
#   'the',
#   'a',
#   'the',
#   'four',
#   'five',
#   'five',
#   'the',
#   'us,',
#   'Fresh',
#   'me',
#   'them.',
#   'his',
#   'the',
#   'once.',
#   'the',
#   'all',
#   'the',
#   'me',
#   'me,',
#   'me',
#   'a',
#   'granted',
#   'a',
#   'a',
#   'me.',
#   'a',
#   '30',
#   'coming',
#   'the',
#   'playing',
#   'being'],
#  'coming.': ['Hello!', 'Um…', 'You'],
#  'Hello.': ['We'],
#  'We': ['are',
#   'were',
#   'were',
#   'had',
#   'need',
#   'both',
#   'like',
#   'like',
#   'do',
#   'do',
#   'do',
#   'eat',
#   'got',
#   'had',
#   'could',
#   'don’t',
#   'could',
#   'all',
#   'don’t'],
#  'are': ['gonna',
#   'shocked',
#   'very',
#   'the',
#   'the',
#   'both',
#   'big',
#   'white',
#   'always',
#   'free',
#   'you',
#   'C.E.O.s,',
#   'never',
#   'a',
#   'you',
#   'you',
#   'like',
#   'your',
#   'droppin’.',
#   'in'],
#  'gonna': ['have',
#   'turn',
#   'die…',
#   'overtake',
#   'have',
#   'trap',
#   'propose…',
#   'stick',
#   'recognize',
#   'see',
#   'be',
#   'have',
#   'live.',
#   'tell',
#   'happen',
#   'have',
#   'become–',
#   'disappear,',
#   'become',
#   'have',
#   'before',
#   'make',
#   'be.',
#   'recycle…',
#   'burn',
#   'be.',
#   'poop',
#   'be'],
#  'have': ['to',
#   'to',
#   'a',
#   'insomnia',
#   'to',
#   'their',
#   'HPV',
#   'it',
#   'HPV',
#   'HPV,',
#   'one',
#   'the',
#   'the',
#   'a',
#   'a',
#   'to',
#   'a',
#   'a',
#   'these',
#   'done',
#   'been',
#   'any',
#   'so',
#   'to',
#   'your',
#   'to',
#   'to,',
#   'executive',
#   'some',
#   'a',
#   'a',
#   'a',
#   'had',
#   'children',
#   'any',
#   'a',
#   'to',
#   'a',
#   'sex,',
#   'to',
#   'had',
#   'to',
#   'the'],
#  'get': ['this',
#   'it.',
#   'it.',
#   'rid',
#   'it,',
#   'to',
#   'to',
#   'to',
#   'the',
#   'very',
#   'very',
#   'to',
#   'to',
#   'my',
#   'sicker,',
#   'sicker,',
#   'really,',
#   'a',
#   'a',
#   'all',
#   'us',
#   'to',
#   'pregnant.',
#   'pregnant,',
#   'up',
#   'into',
#   'older.',
#   'as',
#   'a',
#   'pregnant.',
#   'pregnant',
#   'that…',
#   'my',
#   'pregnant,',
#   'huge',
#   'dark',
#   'big–',
#   'big,',
#   'all',
#   'pregnant.'],
#  'this': ['shit',
#   'year.',
#   'doctor,',
#   'shit',
#   'shit',
#   'calculator',
#   'Judy',
#   'shit',
#   'past',
#   'past',
#   'wedding',
#   'dude',
#   'guy',
#   'restaurant',
#   'restaurant',
#   'hippy-dippy',
#   'sneaking',
#   'wacky',
#   'dude,',
#   'dude,',
#   'huge',
#   'shit?',
#   'conversation.',
#   'is',
#   'fucking',
#   'relatable',
#   'left',
#   'red',
#   'huge',
#   'aggressive',
#   'shit.”',
#   'shit',
#   'far',
#   'crazy',
#   'shit',
#   'dream'],
#  'shit': ['over',
#   'and',
#   'around?',
#   'around?',
#   'up',
#   'is',
#   'on',
#   'like',
#   'we',
#   'outta',
#   'in',
#   'in',
#   'in',
#   'was',
#   'together',
#   'together.”',
#   'turns',
#   'you',
#   'out',
#   'that',
#   'over',
#   'at',
#   'on',
#   'around',
#   'anymore.',
#   'that'],
#  'over': ['with,', 'again.', 'again.', 'by', 'his'],
#  'with,': ['’cause'],
#  '’cause': ['I',
#   'it',
#   'it',
#   'my',
#   'you’re',
#   'when',
#   'her',
#   'it’s',
#   'you',
#   'I'],
#  'I': ['have',
#   'turned',
#   'appreciate',
#   'can',
#   'see',
#   'don’t',
#   'have',
#   'have',
#   'have',
#   'can',
#   'turn',
#   'am,',
#   'turn',
#   'have',
#   'have',
#   'was',
#   'was',
#   'was',
#   'do',
#   'grew',
#   'also',
#   'gave',
#   'dated',
#   'first',
#   'saw',
#   'was',
#   'learned',
#   'was',
#   'trapped',
#   'did',
#   'knew',
#   'was',
#   'thought',
#   'was',
#   'saw',
#   'was',
#   'knew,',
#   'was',
#   'dropped',
#   'was',
#   'don’t',
#   'get',
#   'mean,',
#   'just',
#   'could',
#   'think',
#   'was',
#   'don’t',
#   'go',
#   'think',
#   'have',
#   'read',
#   'was',
#   'pee,',
#   'need',
#   'grew',
#   'are',
#   'had',
#   'just',
#   'had',
#   'just',
#   'wanted.',
#   'sent',
#   'told',
#   'bought',
#   'had',
#   'was',
#   'was',
#   'was',
#   'need',
#   'was.',
#   'did',
#   'don’t',
#   'don’t.',
#   'straight',
#   'don’t',
#   'do',
#   'don’t',
#   'don’t',
#   'wanna',
#   'want',
#   'think',
#   'guess',
#   'hear',
#   'wanna',
#   'do',
#   'love',
#   'love',
#   'still',
#   'gotta',
#   'literally',
#   'had',
#   'hear',
#   'lose',
#   'heard',
#   'was',
#   'know',
#   'heard',
#   'wanna',
#   'was',
#   'should',
#   'trapped',
#   'choose',
#   'chose',
#   'said,',
#   'really',
#   'don’t',
#   'got',
#   'gave',
#   'got',
#   'think',
#   'started',
#   'broke',
#   'was',
#   'went',
#   'don’t',
#   'was',
#   'finally',
#   'just',
#   'got',
#   'was,',
#   'got',
#   'just',
#   'don’t–',
#   'don’t!',
#   'don’t!',
#   'like',
#   'respect',
#   'know',
#   'don’t',
#   'also',
#   'just',
#   'can’t',
#   'can',
#   'told',
#   'want',
#   'wanna',
#   'can',
#   'want',
#   'want?',
#   'wanna',
#   'have',
#   'don’t',
#   'am',
#   'dare',
#   'just',
#   'identify.”',
#   'don’t',
#   'was',
#   'won,',
#   'was',
#   'really',
#   'changed',
#   'get',
#   'need',
#   'don’t',
#   'need',
#   'get',
#   'need',
#   'get',
#   'say',
#   'mean',
#   'also',
#   'know,',
#   'slime',
#   'don’t',
#   'did',
#   'was',
#   'ate',
#   'found',
#   'had',
#   'would',
#   'had',
#   'had',
#   'want',
#   'wanna',
#   'smell',
#   'smell',
#   'discretely',
#   'were',
#   'would',
#   'would',
#   'need',
#   'want',
#   'was',
#   'would',
#   'would',
#   'know',
#   'could',
#   'would',
#   'would',
#   'learned',
#   'would',
#   'don’t',
#   'had',
#   'can’t',
#   'wish',
#   'told',
#   'told',
#   'had',
#   'found',
#   'see',
#   'was',
#   'don’t',
#   'was',
#   'lost.',
#   'sat',
#   'sat',
#   'was',
#   'used',
#   'wanted',
#   'love',
#   'finally',
#   'always',
#   'was',
#   'look',
#   'can’t',
#   'can',
#   'am',
#   'didn’t',
#   'can',
#   'can’t',
#   'get',
#   'do',
#   'berate',
#   'really',
#   'have',
#   'gotta',
#   'didn’t',
#   'didn’t',
#   'look',
#   'will',
#   'do',
#   'was',
#   'was',
#   'looked',
#   'met',
#   'had',
#   'meet',
#   'discovered',
#   'don’t'],
#  'pee': ['in,', 'on'],
#  'in,': ['like,', 'OK?'],
#  'like,': ['ten',
#   '“You',
#   '“But…',
#   '“Oh,',
#   '“Oh,',
#   '“All',
#   'we',
#   '“Hey,',
#   '“Wassup?”',
#   '“Hey,',
#   '“Where?”',
#   '“At',
#   '“Oh,',
#   'you',
#   '“I',
#   '“Hold',
#   '“I',
#   '“It’s',
#   '“It’s',
#   'private',
#   '“Oh,',
#   '“I’m',
#   '“Shut',
#   '“Oh,',
#   'very',
#   '“We’re',
#   '“We',
#   '“But,',
#   '“Look',
#   '“That',
#   '“Oh,',
#   '“You',
#   '“Hey,',
#   '“Why',
#   '“Uh,',
#   '“Oh,',
#   '“Oh,',
#   '“Yes,',
#   'become',
#   'a',
#   '“Guys,',
#   '“That’s',
#   '“Ali,',
#   '“Yeah,',
#   '“Why',
#   '“Yeah,',
#   '“Yeah!',
#   '“Oh,',
#   '“I’m',
#   '“Oh,',
#   'only',
#   '“We’re',
#   '‘Release',
#   'we',
#   '“OK,',
#   '“Hey,',
#   '“Oh,',
#   '“Uh,',
#   '“No!”',
#   '“Yes!”',
#   '“You',
#   '“Yeah,',
#   'that',
#   'this',
#   'I',
#   'a',
#   'a',
#   'really',
#   '“Why',
#   'way'],
#  'ten': ['minutes.', 'gallons'],
#  'minutes.': ['But'],
#  'But': ['thank',
#   'my',
#   'I',
#   'I',
#   'he',
#   'sometimes,',
#   'don’t',
#   'I',
#   'he’s',
#   'mostly',
#   'I’m',
#   'it’s'],
#  'thank': ['you,'],
#  'you,': ['everybody,', 'five', 'but', 'right?”', 'I', '’cause', 'boom,'],
#  'everybody,': ['so'],
#  'so': ['much',
#   'emotional.',
#   'emotional',
#   'much',
#   'vulnerable',
#   'smooth,',
#   'that',
#   'good.',
#   'many',
#   'that',
#   'that',
#   'in',
#   'that',
#   'do',
#   'annoying',
#   'that',
#   'lonely.',
#   'juicy.',
#   'hot.',
#   'tired',
#   'dark',
#   'they',
#   'bad',
#   'bad',
#   'resentful',
#   'little',
#   'little',
#   'supportive.”',
#   'that',
#   'that'],
#  'much': ['for', 'better', 'chemistry.', 'shittier', 'Netflix', 'resentment,'],
#  'Um…': ['It’s'],
#  'It’s': ['a',
#   'been',
#   'OK.',
#   'coming.',
#   'really',
#   'what',
#   'like',
#   'so',
#   'all',
#   'different.',
#   'a',
#   'a',
#   'basically',
#   'like',
#   'because',
#   'very',
#   'so',
#   'a',
#   'lonely.',
#   'very',
#   'when',
#   'super',
#   'whatevs,',
#   'not'],
#  'a': ['very',
#   'very',
#   'shit',
#   'six-pack,',
#   'Ambien',
#   'Meditation',
#   'fucking',
#   'ghost',
#   'self-help',
#   'horrible',
#   'hoarding',
#   'hoarding',
#   'third',
#   'dictator’s',
#   'shovel',
#   'climax',
#   'Texas',
#   'procrastinator',
#   'lot',
#   'man',
#   'lot',
#   'grown-ass',
#   'mattress',
#   'kitchen.',
#   'very',
#   'catch.',
#   'secret',
#   'public',
#   'hipster?',
#   'homeless',
#   'lot',
#   'lot',
#   'major',
#   'Yoko',
#   'white',
#   'white',
#   'Wes',
#   'lot',
#   'white',
#   'white',
#   'dolphin.',
#   'slip',
#   'Jewish',
#   'huge',
#   'number',
#   'supply',
#   'grandma',
#   'weekend.',
#   'shitty',
#   'new',
#   'man',
#   'Pinterest',
#   'Saturday.',
#   'completely',
#   'lot',
#   'genius.”',
#   'housewife,',
#   'great',
#   'lot.',
#   'great',
#   'office',
#   'office',
#   'office.',
#   'day,',
#   'sad-ass',
#   'MacGyver',
#   'slow',
#   'lot',
#   'part',
#   'circle',
#   'lot',
#   'disgusting',
#   'pervert.',
#   'gross',
#   'very',
#   'young',
#   'idiot,',
#   'result,',
#   'little',
#   'second',
#   'conqueror.',
#   'little–',
#   'little',
#   'little',
#   'lot',
#   'lot',
#   'magical',
#   'big',
#   'ban',
#   'very',
#   'little',
#   'housewife,',
#   'certain',
#   'couple',
#   'dude',
#   'stroll',
#   'sidewalk,',
#   'quarter,',
#   'princess.',
#   'Vietnam',
#   'half',
#   'female',
#   'baby,',
#   'week',
#   'little',
#   'sudden.',
#   'frozen',
#   'lot',
#   'lot',
#   'kid.',
#   'kid?',
#   'lot',
#   'kid,',
#   'kid?',
#   'Asian',
#   'billion.',
#   'turtle',
#   'right',
#   'U-turn!”',
#   'O-turn!”',
#   'car',
#   'mess.',
#   'full',
#   'century',
#   'living.',
#   'fuck.',
#   'free',
#   'contest',
#   'kid',
#   'bubble',
#   'little',
#   'lot',
#   'smoker’s',
#   'side',
#   'sandwich.',
#   'way',
#   'doctor.',
#   'kid,',
#   'lot',
#   'lot',
#   'while,',
#   'bunch',
#   'dictatorship,',
#   'hand',
#   'man',
#   'zombie,',
#   'half',
#   'miscarriage,',
#   'lot',
#   'miscarriage.',
#   'third',
#   'pair',
#   'reason.',
#   'heartbeat.”',
#   'miscarriage.',
#   'month',
#   'bike',
#   'doula.',
#   'doula',
#   'white',
#   'soft',
#   'baby',
#   'child',
#   'marriage,',
#   'eyeball,',
#   'foot?',
#   'great',
#   'shitty',
#   'bad',
#   'daily',
#   'daily',
#   'bullseye.',
#   'Minion.',
#   'year,',
#   'nude',
#   'half',
#   'bunch',
#   'half',
#   'good'],
#  'very': ['exciting',
#   'exciting',
#   'unusual',
#   'confusing…',
#   'picturesque',
#   'underrated.',
#   'well',
#   'surprised',
#   'soft,',
#   'nurturing',
#   'domestic.',
#   'upset',
#   'judgmental',
#   'distracting',
#   'young',
#   'sexually',
#   'roundabout',
#   'rare',
#   'demoralizing,',
#   'clinical.',
#   'universal',
#   'grateful',
#   'common.',
#   'early.',
#   'much.',
#   'scared'],
#  'exciting': ['day', 'year'],
#  'day': ['for',
#   'and',
#   'was',
#   'jobs,',
#   'long.',
#   'looks',
#   'since.',
#   'long.',
#   'on'],
#  'me.': ['It’s',
#   'I',
#   'And',
#   '‘Cause',
#   'When–',
#   'OK?”',
#   'You',
#   'Because',
#   'Like,',
#   'That’s',
#   'And',
#   '“Oh,',
#   'I',
#   'Oh,',
#   'How'],
#  'been': ['a',
#   'dating',
#   'pressuring',
#   'together',
#   'reading',
#   'to',
#   'run',
#   'eating',
#   'trying',
#   'Ali'],
#  'year': ['for', 'I'],
#  'turned': ['33'],
#  '33': ['this', 'and…'],
#  'year.': ['Yes!', 'Uh,'],
#  'Yes!': ['Thank'],
#  'five': ['people.', 'years,', 'years,'],
#  'people.': ['I', 'It’s…', 'Like,', 'I', 'That’s'],
#  'appreciate': ['that.'],
#  'that.': ['Uh,', 'Uh,', 'They', 'Don’t', 'I’m', 'They’re', 'I'],
#  'Uh,': ['I', 'this', 'we'],
#  'can': ['tell',
#   'also',
#   'I',
#   'I',
#   'never',
#   'you',
#   'be',
#   'tell,',
#   'tell',
#   'never',
#   'listen',
#   'do',
#   'talk,',
#   'comfortably',
#   'tell,',
#   'just',
#   'think',
#   'I',
#   'I',
#   'I',
#   'already',
#   'really',
#   'you',
#   'already',
#   'see,',
#   'find'],
#  'tell': ['that',
#   'that',
#   'by',
#   'you',
#   'them',
#   'me',
#   'you',
#   'you',
#   'you',
#   'because',
#   'you'],
#  'that': ['I’m',
#   'huge',
#   'says',
#   'they',
#   'lives',
#   'I',
#   'I’m',
#   'if',
#   'you',
#   'retainer',
#   'with',
#   'calculator',
#   'bamboozled',
#   'I’m',
#   'he',
#   'your',
#   'beard',
#   'shit',
#   'and',
#   'privilege',
#   'entitlement…',
#   'for',
#   'you',
#   'bread',
#   'tastes',
#   'lesbian',
#   'seems',
#   'he',
#   'you’re',
#   'I',
#   'I',
#   'so',
#   'he’d',
#   'book',
#   'book',
#   'got',
#   'ever',
#   'we’ll',
#   'fucking',
#   'housewife,',
#   'horrible',
#   'one-ply',
#   'office',
#   'they',
#   'your',
#   'the',
#   'no',
#   'shit',
#   'you',
#   'I',
#   'if',
#   'he’s',
#   'and',
#   'you',
#   'if',
#   'then,',
#   'they’re',
#   'fear.',
#   'fear',
#   'he',
#   'we',
#   'I’m',
#   'I',
#   'woman',
#   'now,',
#   'Whole',
#   'was',
#   'was',
#   'everybody',
#   'it’s',
#   'came',
#   'she’s',
#   '’cause',
#   'to',
#   'you',
#   'snail-trail',
#   'my',
#   'were',
#   'it',
#   'it’s',
#   'tell',
#   'means,',
#   'they',
#   'they',
#   'day',
#   'says,',
#   'stupid-ass',
#   'I',
#   'Harvard',
#   'I',
#   'shit',
#   'is?',
#   'you’re',
#   'you–',
#   'that',
#   'happens',
#   'he',
#   'he’s',
#   'goes',
#   'they',
#   'the',
#   'the',
#   'I’m',
#   'my'],
#  'I’m': ['getting',
#   'straight',
#   'jealous,',
#   'gonna',
#   'getting',
#   'not',
#   'interested',
#   'a',
#   'not',
#   'hoping',
#   'hoping',
#   'gonna',
#   'not',
#   'the',
#   'gonna',
#   'absorbing',
#   'half-Chinese',
#   'half-Chinese',
#   'a',
#   'very',
#   'like,',
#   "done.'”",
#   'done.',
#   'not',
#   'a–',
#   'a',
#   'a',
#   'a',
#   'scared',
#   'a',
#   'going',
#   'gonna',
#   'gonna',
#   'tired',
#   'the',
#   'the',
#   'just',
#   'talking',
#   'talking',
#   'striving',
#   'a',
#   'a',
#   'guaranteed,',
#   'still',
#   'just',
#   'older,',
#   'not',
#   'only',
#   'only',
#   'gonna',
#   '33,',
#   'very',
#   '33.',
#   'from,',
#   'scared',
#   'very,',
#   'going',
#   'all',
#   'busy',
#   'the',
#   'not',
#   'a',
#   'fucked.',
#   'not',
#   'seven',
#   'performing'],
#  'getting': ['older,', 'older,', 'busy', 'massages'],
#  'older,': ['because,', 'because', 'when'],
#  'because,': ['now,', 'usually,', 'last'],
#  'now,': ['when', 'because', 'instead', 'and', 'if'],
#  'when': ['I',
#   'they',
#   'a',
#   'you’re',
#   'she',
#   'we',
#   'you',
#   'you',
#   'I',
#   'you’re',
#   'a',
#   'our',
#   'you',
#   'we',
#   'I',
#   'I',
#   'I',
#   'I',
#   'you',
#   'he',
#   'I',
#   'that',
#   'you',
#   'you’re',
#   'they',
#   'I',
#   'I’m',
#   'I',
#   'I',
#   'my',
#   'you',
#   'trying',
#   'I',
#   'everything',
#   'I',
#   'the',
#   'it’s',
#   'it',
#   'they',
#   'I',
#   'he',
#   'a',
#   'they',
#   'they',
#   'you’re',
#   'they',
#   'I',
#   'they’re',
#   'you’re',
#   'you',
#   'he',
#   'you',
#   'I',
#   'it',
#   'it’s'],
#  'see': ['an',
#   'ten',
#   'on',
#   'that',
#   'the',
#   'a',
#   'a',
#   'how',
#   'that',
#   'who’s',
#   'a',
#   'the',
#   'the',
#   'two',
#   'is',
#   'Beyoncé.',
#   'how',
#   'how',
#   'if',
#   'me'],
#  'an': ['18-year-old', 'ATM', 'impression', 'investment'],
#  '18-year-old': ['girl,', 'girls,'],
#  'girl,': ['my', 'because'],
#  'my': ['automatic',
#   'body',
#   'Kindle',
#   'home',
#   'optimum',
#   'other',
#   'mom',
#   'life.',
#   'generation.',
#   'time.',
#   'mom',
#   'optimum',
#   'husband,',
#   'league,',
#   'God,',
#   'God,',
#   'part.',
#   'generation.',
#   'Volvo.',
#   'pussy.',
#   'God.',
#   'God.',
#   'bed',
#   'husband',
#   'God!',
#   'Pinterest',
#   'best',
#   'wedding',
#   'husband,',
#   'personality',
#   'heart.',
#   'financial',
#   'friends,',
#   'co-workers.',
#   'toilet',
#   'fingers',
#   'co-workers',
#   'co-workers',
#   'shit',
#   'husband',
#   'life?',
#   'destiny.',
#   'last',
#   'mom,',
#   'dad,',
#   'grandma.”',
#   '20s,',
#   'God!',
#   'God!',
#   'husband',
#   'Asian-American',
#   'female',
#   'friends',
#   'husband',
#   'mind,',
#   'mind',
#   'God,',
#   'face',
#   'husband',
#   'destiny,',
#   'body',
#   'God,',
#   'fault.',
#   '20s,',
#   'uterus',
#   'progesterone',
#   'writing',
#   'co-workers,',
#   'underwear,',
#   'fingers',
#   'fingers',
#   'own',
#   'fingers?',
#   'fingers?',
#   'fingers?”',
#   'husband',
#   'God,',
#   'husband',
#   'face',
#   'God.',
#   'mom–',
#   'six-week',
#   'God,',
#   'husband',
#   'miscarriage',
#   'shit',
#   'husband.',
#   'husband',
#   'doctor’s',
#   'God.',
#   'blood',
#   'husband',
#   'pussy’s',
#   'pussy’s',
#   'body’s',
#   'husband,',
#   'league,',
#   'God,',
#   'dreams',
#   'beautiful,',
#   'hard-earned',
#   'ass.'],
#  'automatic': ['thought…'],
#  'thought…': ['is'],
#  'is': ['“Fuck',
#   'a',
#   'turning',
#   'all',
#   'the',
#   'from',
#   'that?”',
#   'a',
#   'a',
#   'Asian.',
#   'turning',
#   'that',
#   'built',
#   'all',
#   'the',
#   'too',
#   'like,',
#   'always,',
#   'called',
#   'the',
#   'a',
#   'to',
#   'that…',
#   'doo',
#   'unfortunately',
#   'what',
#   'a',
#   'a',
#   'at',
#   'the',
#   'a',
#   '80,',
#   'so',
#   'not',
#   'not',
#   'not',
#   'most',
#   'fine',
#   'very',
#   'about',
#   'very',
#   'very',
#   'a',
#   'mysterious!”',
#   'so',
#   'it'],
#  '“Fuck': ['you.”', 'you.'],
#  'you.”': ['“Fuck', 'My'],
#  'you.': ['I', 'A', 'Don’t', 'I', 'There’s–', 'Ghostbusters!”', 'You'],
#  'don’t': ['even',
#   'have',
#   'know',
#   'have',
#   'have',
#   'have',
#   'know',
#   'even',
#   'know',
#   'know',
#   'gotta',
#   'know',
#   'go',
#   'got',
#   'wanna',
#   'wanna',
#   'feed',
#   'wanna',
#   'wanna',
#   'know',
#   'think',
#   'gotta',
#   'gotta',
#   'gotta…',
#   'gotta',
#   'gotta',
#   'gotta',
#   'gotta',
#   'gotta',
#   'gotta',
#   'wanna',
#   'wanna',
#   'worry,',
#   'cheat',
#   'wanna',
#   'wanna',
#   'want',
#   'know',
#   'get',
#   'know',
#   'you',
#   'crack.”',
#   'die.',
#   'die.',
#   'know',
#   'give',
#   'know',
#   'wanna',
#   'see',
#   'tell',
#   'work,'],
#  'even': ['know', 'know…', 'accidentally', 'effective.', 'have', 'come'],
#  'know': ['you,',
#   'what',
#   'that',
#   'when',
#   'what',
#   'when',
#   'what’s',
#   'why',
#   'the',
#   'anything',
#   'what',
#   'that',
#   'how',
#   'how',
#   'you',
#   'that',
#   'I',
#   'you',
#   'you’ve',
#   'what',
#   'if',
#   'what’s',
#   'the',
#   'why',
#   'what’s',
#   'what',
#   'what',
#   'plenty',
#   'what',
#   'what',
#   'that',
#   'that.',
#   'that'],
#  'but': ['fuck', 'I', 'it’s', 'I', 'I’m', 'my'],
#  'fuck': ['you!”', 'they', 'up!', 'down.', 'one', 'him', 'up.”', 'I'],
#  'you!”': ['‘Cause'],
#  '‘Cause': ['I’m', 'he', 'I', 'it’s', 'if', 'she', 'I'],
#  'straight': ['up', 'up', 'up'],
#  'up': ['jealous.',
#   'your',
#   'when',
#   'a',
#   'on',
#   'with',
#   'in',
#   'afterwards.',
#   'on',
#   'like',
#   'going',
#   'for',
#   'on',
#   'and',
#   'don’t',
#   'about',
#   'to',
#   'a',
#   'to',
#   'with',
#   'there',
#   'on',
#   'the',
#   'myself',
#   'from',
#   'your',
#   'soldier'],
#  'jealous.': ['I’m'],
#  'jealous,': ['first'],
#  'first': ['and', 'met', 'thing', 'dates,', 'and', 'lady', 'WebMD.', 'home'],
#  'foremost,': ['of', 'by'],
#  'of': ['their',
#   'potential',
#   'regret',
#   'them.',
#   'men',
#   'two',
#   'HPV.',
#   'Wolverine,',
#   'Grey,',
#   'Tidying',
#   'success.',
#   'all',
#   'my',
#   'shit.',
#   'my',
#   'a',
#   'you',
#   'my',
#   'success.”',
#   'losers.',
#   'losers.',
#   'skaters.',
#   'my',
#   'my',
#   'people',
#   'opinions,',
#   'cool',
#   'that',
#   'that',
#   'your',
#   'our',
#   'our',
#   'Los',
#   'all,',
#   'bleach,',
#   'your',
#   'this',
#   'Asian',
#   'us',
#   'the',
#   'my',
#   'Facebook,',
#   'women',
#   'options',
#   'my',
#   'day',
#   'the',
#   'the',
#   'their',
#   'credence.',
#   'my',
#   'privileged',
#   'this',
#   'my',
#   'early',
#   'myself',
#   'women',
#   'the',
#   'the',
#   'crazy',
#   'the',
#   'is',
#   'your',
#   'mine',
#   'resistance',
#   '“No!',
#   'the',
#   'control,',
#   'control',
#   'being',
#   'her,',
#   'saying,',
#   'saying:',
#   'income',
#   'one.',
#   'them.',
#   'shit.',
#   'a',
#   'my',
#   'my',
#   'your',
#   'nowhere.',
#   'their',
#   'her',
#   'those',
#   'longevity.',
#   'change.',
#   'mother',
#   'science',
#   'that…',
#   'my',
#   'the',
#   'people',
#   'fuckin’?”',
#   'the',
#   'that,',
#   'angry',
#   'the',
#   'the',
#   'your',
#   'their',
#   'their',
#   'him…',
#   'this',
#   'that',
#   'me.',
#   'women',
#   'women',
#   'shoes.',
#   'poppy',
#   'me',
#   'Craigslist.',
#   'childbirth.',
#   'women',
#   'the',
#   'your',
#   'life,',
#   'how',
#   'my',
#   'the',
#   'survival,',
#   'another',
#   'those',
#   'body',
#   'losers.',
#   'my',
#   'white-collar'],
#  'their': ['metabolism.',
#   'feet',
#   'whole',
#   'house.',
#   'communist',
#   'shit,',
#   'doo',
#   'hallways',
#   'iPad',
#   'eyebrows,',
#   'prostate.',
#   'fame',
#   'existence.',
#   'big-ass',
#   'Darth',
#   'arch-nemesis,',
#   'eyes',
#   'eyes.',
#   'eyes',
#   'head',
#   'eyelids.',
#   'face…',
#   '20s',
#   'husbands'],
#  'metabolism.': ['Because'],
#  'Because': ['18-year-old', 'according', 'I’m', 'I’m', 'we’re'],
#  'girls,': ['they'],
#  'they': ['could',
#   'take',
#   'put',
#   'go',
#   'just',
#   'have',
#   'were',
#   'like',
#   'teach',
#   'mean.',
#   'don’t',
#   'purposely',
#   'don’t',
#   'want.',
#   'want.',
#   'say',
#   'wax',
#   'do',
#   'like',
#   'just',
#   'do',
#   'generally',
#   'have',
#   'become',
#   'were',
#   'were',
#   'were',
#   'don’t',
#   'can',
#   'come',
#   'just',
#   'need',
#   'saw',
#   'get',
#   'look',
#   'just',
#   'hear',
#   'wouldn’t',
#   'go',
#   'get',
#   'get',
#   'get',
#   'get'],
#  'could': ['just',
#   'graph.',
#   'just',
#   'just',
#   'have',
#   'do',
#   'do',
#   'ask',
#   'just',
#   'just',
#   'always'],
#  'just': ['eat',
#   'radiating',
#   'go',
#   'cluttering',
#   'go',
#   'fucked',
#   'feel',
#   'right',
#   'crush',
#   'kill',
#   'like',
#   'smell',
#   'had',
#   'had',
#   'gonna',
#   'nag',
#   'stay',
#   'walking',
#   'dehydrates',
#   'blow',
#   'fulfilling',
#   'put',
#   'felt',
#   'wanted',
#   'see',
#   'become',
#   'not',
#   'wanna',
#   'want',
#   'wanna',
#   'wanna',
#   'waiting',
#   'keep',
#   'had',
#   'swells',
#   'gonna',
#   'travel',
#   'do',
#   'kidding.',
#   'gonna',
#   'sopping',
#   'took',
#   'reach',
#   'blow',
#   'scratch',
#   'vacuum,',
#   'come',
#   'give',
#   'got',
#   'twerk,',
#   'drain',
#   'shit',
#   'when'],
#  'eat': ['like',
#   'gluten-free,',
#   'all',
#   'that',
#   'it,',
#   'snacks',
#   'a',
#   'bananas.”'],
#  'like': ['shit,',
#   'to',
#   'Fifty',
#   'the',
#   '$200.',
#   'this',
#   'the',
#   'to',
#   'you’re',
#   'voting',
#   'that',
#   'I’m',
#   'making',
#   'a',
#   'loofah',
#   'responsibility.',
#   'host',
#   'Filipino',
#   'to',
#   'to',
#   'that.',
#   'free-range',
#   'we',
#   'you’re',
#   'wiping',
#   'it’s',
#   'you’re',
#   'I',
#   'I’m',
#   'a',
#   'it,',
#   'that',
#   'he’s',
#   'you’re',
#   'to',
#   'a',
#   'the',
#   'skittles.',
#   'a',
#   'everything',
#   'a',
#   'they',
#   'losing',
#   'fingers.',
#   'Whoppers',
#   'a',
#   'when'],
#  'shit,': ['and', 'too.'],
#  'then': ['they',
#   'after',
#   'also,',
#   'Asian',
#   'if',
#   'afterwards,',
#   'it',
#   'I',
#   'you',
#   'you',
#   'your',
#   'if',
#   'I',
#   'I',
#   'resist',
#   'he',
#   'I',
#   'she',
#   'we',
#   'we'],
#  'take': ['a', 'a', 'these', 'a', 'these', 'its'],
#  'six-pack,': ['right?'],
#  'right?': ['They', 'That’s', 'So,', 'You'],
#  'They': ['got',
#   'don’t',
#   'don’t',
#   'have',
#   'don’t',
#   'just',
#   'introduce',
#   'got',
#   'just',
#   'get',
#   'ruined',
#   'don’t',
#   'don’t',
#   'don’t',
#   'don’t',
#   'try',
#   'don’t',
#   'don’t',
#   'don’t',
#   'can',
#   'can',
#   'would',
#   'get',
#   'just',
#   'got',
#   'do',
#   'do',
#   'wear',
#   'just',
#   'make',
#   'watch',
#   'were',
#   'tried'],
#  'got': ['that-that',
#   'so',
#   'married.',
#   'no',
#   'a',
#   'me',
#   'engaged',
#   'women',
#   'married',
#   'married.',
#   'a',
#   'married',
#   'a',
#   'no',
#   'bit',
#   'him',
#   'married,',
#   'pregnant,'],
#  'that-that': ['beautiful'],
#  'beautiful': ['inner'],
#  'inner': ['thigh', 'peace', 'evil,'],
#  'thigh': ['clearance'],
#  'clearance': ['where'],
#  'where': ['they', 'my', 'I', 'the', 'the', 'I'],
#  'put': ['their', 'it', 'it', 'it'],
#  'feet': ['together'],
#  'together': ['and', 'now', 'to', 'when'],
#  'there’s': ['that', 'multiple'],
#  'huge': ['gap', 'unspoken', 'sit-down', 'bear', 'and'],
#  'gap': ['here'],
#  'here': ['with', 'is'],
#  'with': ['the',
#   'where',
#   'your',
#   'all',
#   'these',
#   'a',
#   'a',
#   'a',
#   'somebody',
#   'a',
#   'glaucoma',
#   'our',
#   'this',
#   'my',
#   'him.',
#   'me',
#   'their',
#   'the',
#   'which',
#   'me',
#   'the',
#   'eyelashes.',
#   'my',
#   'a',
#   'male',
#   'your',
#   'no',
#   'me,',
#   'it,',
#   'you',
#   'intention,',
#   'me.',
#   'your',
#   'my'],
#  'light': ['of', 'completely.”'],
#  'potential': ['just'],
#  'radiating': ['through.'],
#  'through.': ['And'],
#  'And': ['then,',
#   'everybody',
#   'my',
#   'I',
#   'the',
#   'I',
#   'I',
#   'we–',
#   'then',
#   'I',
#   'you',
#   'then',
#   'we',
#   'I',
#   'then',
#   'on',
#   'the',
#   'so,',
#   'then',
#   'look,',
#   'her',
#   'then,',
#   'they’re',
#   'they’ll',
#   'you',
#   'you’re',
#   'then',
#   'then',
#   'just',
#   'I',
#   'what',
#   'they’re',
#   'I',
#   'you',
#   'it’s',
#   'then,',
#   'I’m',
#   'I',
#   'all',
#   'their',
#   'they',
#   'you',
#   'then,',
#   'she',
#   'when',
#   'it–',
#   'it',
#   'a',
#   'I',
#   'then,',
#   'then,',
#   'I',
#   'they',
#   'then,',
#   'then,',
#   'then,',
#   'then',
#   'a',
#   'everything',
#   'the',
#   'I',
#   'then',
#   'I',
#   'most',
#   'he',
#   'I',
#   'just',
#   'it',
#   'then,',
#   'I',
#   'I',
#   'then,',
#   'me,',
#   'now,'],
#  'then,': ['when',
#   'all',
#   'it',
#   'you',
#   'on',
#   'at',
#   'at',
#   'a',
#   'when',
#   'because',
#   'I',
#   'you',
#   'I'],
#  'go': ['to',
#   'to',
#   'to',
#   'and',
#   'and',
#   'of',
#   'to',
#   'home…',
#   'for',
#   'on',
#   'very',
#   'back',
#   'call',
#   'home',
#   'paintballing',
#   'bald…',
#   'to',
#   'time,”',
#   'through',
#   'to'],
#  'sleep,': ['they'],
#  'sleep.': ['Right?'],
#  'Right?': ['They'],
#  'insomnia': ['yet.'],
#  'yet.': ['They', 'They'],
#  'what': ['it’s',
#   'that',
#   'your',
#   'that',
#   'love',
#   'the',
#   'I',
#   'happens',
#   'he',
#   'to',
#   'I’m',
#   'else',
#   'everybody',
#   'kind',
#   'that',
#   'I',
#   'that',
#   'a'],
#  'it’s': ['like',
#   'undetectable',
#   'a',
#   'very,',
#   'hot',
#   'funny,',
#   'too',
#   'probably',
#   'been',
#   'very',
#   'because',
#   'OK,',
#   'like',
#   'the',
#   'sexist',
#   'a',
#   'what',
#   'a',
#   'all',
#   'too',
#   'Easter',
#   'like,',
#   'go',
#   'not',
#   'because',
#   'different.',
#   'straight',
#   'Neosporin.'],
#  'Ambien': ['or'],
#  'or': ['download',
#   'you’re',
#   'you',
#   'for',
#   'something.',
#   'whatever.',
#   'something…'],
#  'download': ['a'],
#  'Meditation': ['Oasis'],
#  'Oasis': ['podcast'],
#  'podcast': ['to'],
#  'calm': ['the'],
#  'chatter': ['of'],
#  'regret': ['and'],
#  'resentment': ['towards'],
#  'towards': ['your', 'my'],
#  'your': ['family',
#   'mind.',
#   '30s',
#   'wealth.',
#   'butt',
#   'mom.',
#   'body',
#   'head',
#   'own',
#   'body',
#   'daily',
#   'butt',
#   'butt',
#   'co-worker’s',
#   'shoes',
#   'butt',
#   'underwear',
#   'shit',
#   'children',
#   'understand',
#   'son',
#   'shame,',
#   'inner',
#   'secrets',
#   'man',
#   'thumb',
#   'husband',
#   'lives',
#   'pussy',
#   'hand',
#   'pants',
#   'fingers.',
#   'first',
#   '20s,',
#   '30s,',
#   'sperm',
#   'face',
#   'pussy',
#   'husband',
#   'leg,',
#   'life.',
#   'doctor’s',
#   'body'],
#  'family': ['just', 'would', 'funny'],
#  'cluttering': ['your'],
#  'mind.': ['They'],
#  'whole': ['lives', 'manipulation', 'new', 'thing.”'],
#  'lives': ['ahead', 'inside', 'with'],
#  'ahead': ['of'],
#  'them.': ['They', 'They’re', 'Nothing', 'Once', 'They'],
#  'HPV': ['yet.', 'yet,', 'is', 'will'],
#  'sleep': ['in'],
#  'in': ['peace',
#   'men.',
#   'women’s',
#   'the',
#   'books',
#   'The',
#   'handy',
#   'San',
#   'eight',
#   'a',
#   'San',
#   'broad',
#   'the',
#   'a',
#   'America',
#   'a',
#   'my',
#   'it.',
#   'the',
#   'and',
#   'men.',
#   '2012.',
#   'my',
#   'her',
#   'terms',
#   'a',
#   'a',
#   'their',
#   'doo',
#   'the',
#   'the',
#   'the',
#   'her',
#   'different',
#   'my',
#   'time!”',
#   'the',
#   'the',
#   'his',
#   'his',
#   'bed.',
#   'control',
#   'the',
#   'elementary',
#   'the',
#   'their–',
#   'a',
#   'between',
#   'my',
#   'front',
#   'the',
#   'your',
#   'your',
#   'such',
#   'the',
#   'Atlanta.',
#   'their',
#   'front',
#   'my',
#   'labor,',
#   'the',
#   'front',
#   'our',
#   'shape',
#   'a',
#   'debt.'],
#  'peace': ['at', 'and', 'sign'],
#  'at': ['night.',
#   'home',
#   'this',
#   'the',
#   'Golden',
#   'any',
#   'how,',
#   'all',
#   'the',
#   'home',
#   'that',
#   'that',
#   'a',
#   'work',
#   'the',
#   'a',
#   'a',
#   'a',
#   'life,',
#   'first.',
#   'home,',
#   'any',
#   'my',
#   'Fresh',
#   'some',
#   'my',
#   'work.',
#   'him.',
#   'his'],
#  'night.': ['Everybody', 'And'],
#  'Everybody': ['has', 'has', 'has'],
#  'has': ['HPV,',
#   'it.',
#   'it.',
#   'HPV.',
#   'hosted',
#   'even',
#   'made',
#   'to',
#   'a',
#   'had',
#   'to'],
#  'HPV,': ['OK?', 'because'],
#  'OK?': ['Everybody',
#   'I’m',
#   'That',
#   'So,',
#   'A',
#   'I',
#   'You',
#   'So,',
#   'Are',
#   'We',
#   'I',
#   'Old',
#   'Do',
#   'When',
#   'When',
#   'They',
#   'Are'],
#  'it.': ['It’s',
#   'If',
#   'You',
#   'It’s',
#   'You',
#   'Second',
#   'So,',
#   'Sheryl',
#   'I',
#   'When',
#   'Now',
#   'That’s'],
#  'OK.': ['Come', 'And'],
#  'Come': ['out'],
#  'out': ['already.',
#   'of',
#   'there',
#   'of',
#   'at',
#   'about',
#   'down',
#   'of',
#   'of',
#   'of',
#   'first.',
#   'that',
#   'of',
#   'like',
#   'of',
#   'of',
#   'when',
#   'at',
#   'about',
#   'yet',
#   'of',
#   'of'],
#  'already.': ['Everybody'],
#  'If': ['you', 'it', 'a', 'you’re', 'you', 'it’s'],
#  'it': ['yet,',
#   'might',
#   'all',
#   'when',
#   'was',
#   'on',
#   'can',
#   'on',
#   'don’t',
#   'was',
#   'on',
#   'on',
#   'as',
#   'so',
#   'for',
#   'a',
#   'backfired',
#   'echo',
#   'in',
#   'in',
#   'in',
#   'up.',
#   'up,',
#   'interesting.',
#   'in',
#   'before,',
#   'tonight.',
#   'might',
#   'up.',
#   'was',
#   'in',
#   'scared',
#   'used',
#   'for',
#   'was',
#   'made',
#   'gets',
#   'was',
#   'so',
#   'as',
#   'very',
#   'takes',
#   'also',
#   'easier.',
#   'was',
#   'different?”',
#   'up,',
#   'all',
#   'turns'],
#  'yet,': ['you', 'you’re'],
#  'You': ['go',
#   'don’t',
#   'wanna',
#   'homeless',
#   'go',
#   'feel',
#   'feel',
#   'know?',
#   'get',
#   'don’t',
#   'guys',
#   'mess',
#   'guys',
#   'can',
#   'gotta',
#   'know,',
#   'guys',
#   'tell',
#   'ain’t',
#   'have',
#   'gotta',
#   'gotta',
#   'only',
#   'know',
#   'know?',
#   'know',
#   'know,',
#   'just',
#   'could',
#   'guys',
#   'pee',
#   'know',
#   'know',
#   'just',
#   'change',
#   'know,',
#   'owe'],
#  'you’re': ['a',
#   'in',
#   'busy',
#   'with',
#   'in',
#   'like,',
#   'too',
#   'like,',
#   'about',
#   'paranoid',
#   'like,',
#   'a',
#   'really',
#   'married,',
#   'gonna',
#   'fucking',
#   'the',
#   'supposed',
#   'eating',
#   'gonna',
#   'in',
#   '33,',
#   'having',
#   'gonna',
#   'in'],
#  'fucking': ['loser,', 'housewife.', 'different', 'baby.', 'baby,'],
#  'loser,': ['all'],
#  'all': ['right?',
#   'about.',
#   'of',
#   'your',
#   'came',
#   'required',
#   'this',
#   'his',
#   'of',
#   'of',
#   'the',
#   'up',
#   'fucked',
#   'red',
#   'that',
#   'of',
#   'over',
#   'with',
#   'riled',
#   'day',
#   'these',
#   'day,',
#   'over',
#   'day',
#   'the',
#   'sorts',
#   'of',
#   'your',
#   'he’s',
#   'squirmy',
#   'right?',
#   'the',
#   'the',
#   'my',
#   'these',
#   'of',
#   'know',
#   'the',
#   'day',
#   'you',
#   'good',
#   'of',
#   'the',
#   'backed',
#   'of',
#   'your',
#   'this',
#   'back',
#   'wet',
#   'wet',
#   'my',
#   'off.'],
#  'That’s': ['what',
#   'what',
#   'where',
#   'right,',
#   'how',
#   'how',
#   'right.',
#   'the',
#   'when',
#   'not',
#   'the',
#   'not',
#   'shit',
#   'right.',
#   'so',
#   'my',
#   'why',
#   'a',
#   'the',
#   'not'],
#  'says': ['about', 'to'],
#  'about': ['you.',
#   'the',
#   'him',
#   'a',
#   'Vietnamese',
#   'it',
#   'our',
#   'how',
#   'those',
#   'housewives',
#   'to',
#   'the',
#   'money.',
#   'anal.',
#   'is,',
#   'that',
#   'is,',
#   'to',
#   'to',
#   'it',
#   'giving',
#   'childbirth',
#   'all'],
#  'A': ['lot', 'lot', 'woman', 'lot', 'lot', 'lot', 'whole', 'big', 'lot'],
#  'lot': ['of',
#   'this',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'more',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'more',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of'],
#  'men': ['don’t', 'are', 'are', 'as'],
#  'because': ['it’s',
#   'my',
#   'my',
#   'you',
#   'what?',
#   'before',
#   'I',
#   'being',
#   'he’s',
#   'he’s',
#   'you',
#   'I',
#   'you',
#   'I',
#   'the',
#   'he',
#   'you',
#   'we’re',
#   'of',
#   'according',
#   'boys',
#   'female',
#   'they',
#   'uh,',
#   'they’re',
#   'they’re',
#   'then',
#   'the',
#   'we’re',
#   'when',
#   'the',
#   'I',
#   'if',
#   'my–',
#   'he'],
#  'undetectable': ['in'],
#  'men.': ['It’s', 'We'],
#  'really': ['fucked',
#   'work,',
#   'meant',
#   'scared',
#   'am!”',
#   'take',
#   'am',
#   'hot,'],
#  'fucked': ['up.', 'a', 'up'],
#  'up.': ['HPV', 'A', 'You', 'She’s'],
#  'ghost': ['that'],
#  'inside': ['men’s', 'of'],
#  'men’s': ['bodies'],
#  'bodies': ['and'],
#  'says,': ['“Boo!”', '“Please,'],
#  '“Boo!”': ['in'],
#  'women’s': ['bodies.', 'intuition.'],
#  'bodies.': ['My'],
#  'My': ['doctor',
#   'husband',
#   'husband,',
#   'last',
#   'father-in-law',
#   'husband',
#   'Toyota',
#   'mom',
#   'nipples'],
#  'doctor': ['told', 'says', 'appointments.'],
#  'told': ['me', 'her', 'you', 'my', 'her'],
#  'me': ['that',
#   'that',
#   'to',
#   'something.',
#   'off?”',
#   'feel',
#   'to',
#   'feel',
#   'the',
#   'tell',
#   'about',
#   'with',
#   'when',
#   'anymore',
#   'and',
#   'to',
#   'and',
#   'this',
#   'on,',
#   'and',
#   'enough',
#   'discouraged',
#   'from',
#   'when',
#   'from',
#   'see',
#   'of',
#   'company',
#   'when',
#   'when',
#   'anymore.',
#   'extremely',
#   'in',
#   'while',
#   'to',
#   'a',
#   'out.',
#   'out',
#   'to',
#   'money,',
#   'in',
#   'for'],
#  'one': ['of', 'of', 'of', 'of', 'person', 'of', 'of', 'who'],
#  'two': ['strains', 'homeless', 'days', 'Latina', 'sacks,', 'weeks'],
#  'strains': ['of'],
#  'HPV.': ['Either', 'Very'],
#  'Either': ['I'],
#  'kind': ['that’s', 'where', 'of', 'of', 'of', 'of'],
#  'that’s': ['gonna',
#   'right,',
#   'not',
#   'like…',
#   'not',
#   'gonna',
#   'why',
#   'the',
#   'cool…',
#   'so',
#   'like',
#   'enough'],
#  'turn': ['into', 'this', 'this', 'into', 'signal', 'upside'],
#  'into': ['cervical',
#   'a',
#   'the',
#   'a',
#   'the',
#   'banana',
#   'the',
#   'the',
#   'the',
#   'a',
#   'pleasure.',
#   'a',
#   'my',
#   'your',
#   'a',
#   'the'],
#  'cervical': ['cancer…'],
#  'cancer…': ['…or'],
#  '…or': ['I'],
#  'body': ['will', 'is', 'hair', 'is', 'odor.', 'was', 'when', 'where,'],
#  'will': ['heal', 'also', 'also', 'you', 'always', 'be', 'have', 'commend'],
#  'heal': ['itself.', 'from'],
#  'itself.': ['Very'],
#  'Very': ['helpful,', 'lucky'],
#  'helpful,': ['this'],
#  'doctor,': ['right?'],
#  'So,': ['basically,',
#   'you',
#   'we’re',
#   'he',
#   'you',
#   'you’re',
#   'I',
#   'when',
#   'now,',
#   'I',
#   'I',
#   'my',
#   'then',
#   'then',
#   'I',
#   'you',
#   'as'],
#  'basically,': ['either'],
#  'either': ['I’m'],
#  'die…': ['or'],
#  'presence': ['of'],
#  'Wolverine,': ['bitches.'],
#  'bitches.': ['We’ll', 'I'],
#  'We’ll': ['find'],
#  'find': ['out.', 'a', 'ways', 'a', 'it'],
#  'out.': ['Um,', 'They', 'They', 'They'],
#  'Um,': ['I', 'and'],
#  'also': ['tell', 'disappear.', 'got', 'last', 'don’t', 'decided', 'takes'],
#  'Kindle': ['is'],
#  'turning': ['into', 'into'],
#  'self-help': ['library.'],
#  'library.': ['I’m'],
#  'not': ['interested',
#   'happy',
#   'trying',
#   'the',
#   'kissing',
#   'ask',
#   'authentic,',
#   'recognize',
#   'a',
#   'even',
#   'have',
#   'be',
#   'dieting',
#   'scared',
#   'as',
#   'the',
#   'again!”',
#   'Rush',
#   'trying',
#   'my',
#   'technically',
#   'as',
#   'OK.',
#   'fuckin’.',
#   'because',
#   'doing',
#   'there.',
#   'gonna',
#   'like',
#   'the'],
#  'interested': ['in', 'in'],
#  'books': ['like'],
#  'Fifty': ['Shades'],
#  'Shades': ['of'],
#  'Grey,': ['OK?'],
#  'The': ['Life-Changing',
#   'last',
#   'manual.',
#   'next',
#   'advantage',
#   'fancy',
#   'images',
#   'Boat,'],
#  'Life-Changing': ['Magic'],
#  'Magic': ['of'],
#  'Tidying': ['Up.'],
#  'Up.': ['Yes.'],
#  'Yes.': ['Yes,', 'Yes.', 'Yes.', 'I', 'Because'],
#  'Yes,': ['that’s'],
#  'right,': ['how', 'Ali,', 'we', 'because', 'I’ve'],
#  'how': ['to',
#   'can',
#   'proposals',
#   'rotten',
#   'we',
#   'to',
#   'much',
#   'invincible',
#   'a',
#   'there’s,',
#   'it'],
#  'declutter': ['my'],
#  'home': ['to', 'in', 'all', 'and', 'together.'],
#  'achieve': ['inner', 'my'],
#  'optimum': ['level', 'level'],
#  'level': ['of', 'of'],
#  'success.': ['That’s'],
#  '30s': ['is'],
#  'about.': ['How'],
#  'How': ['can', 'did', 'did', 'did'],
#  'around?': ['I’m', 'Help'],
#  'horrible': ['person,', 'toilet'],
#  'person,': ['I’m'],
#  'happy': ['with'],
#  'am,': ['how'],
#  'Help': ['me,'],
#  'me,': ['Tony',
#   'he’s',
#   'this',
#   'but',
#   'I',
#   'because',
#   '“Oh,',
#   'I’m',
#   'out',
#   'with'],
#  'Tony': ['Robbins,'],
#  'Robbins,': ['help'],
#  'help': ['me!', 'her', 'you', 'as'],
#  'me!': ['I', 'I'],
#  'hoarding': ['problem,', 'goes', 'problem'],
#  'problem,': ['which'],
#  'which': ['I’m',
#   'is',
#   'means',
#   'would',
#   'their',
#   'is',
#   'is',
#   'means',
#   'subsequently'],
#  'hoping': ['is', 'that'],
#  'center': ['of'],
#  'other': ['problems.', 'homeless', 'day.', 'shitty'],
#  'problems.': ['I’m'],
#  'if': ['the',
#   'he',
#   'you',
#   'you',
#   'I',
#   'you',
#   'you',
#   'I',
#   'you',
#   'I’m',
#   'I',
#   'he',
#   'you',
#   'I',
#   'I'],
#  'goes': ['away,', 'down'],
#  'away,': ['the'],
#  'disappear.': ['I', 'That’s'],
#  'problem': ['because'],
#  'mom': ['is', 'got', 'is', 'is'],
#  'from': ['a',
#   'the',
#   'the',
#   'the',
#   'the',
#   'Pier',
#   'Harvard',
#   'the',
#   'the',
#   'having',
#   'having',
#   'the',
#   'this',
#   'pedestrians',
#   'their',
#   'a',
#   'holding',
#   'bacteria',
#   'Harvard'],
#  'third': ['world', 'grade,', 'world'],
#  'world': ['country', '♪', 'with', 'country,'],
#  'country': ['and', 'and'],
#  'she': ['taught', 'refused', 'was', 'wrote', 'knows', 'is', 'was', 'said,'],
#  'taught': ['me'],
#  'never': ['throw', 'know', 'know', 'finish', 'finish', 'called'],
#  'throw': ['away', 'up.', 'up'],
#  'away': ['anything,', 'from', 'at'],
#  'anything,': ['because'],
#  'dictator’s': ['gonna'],
#  'overtake': ['the'],
#  'snatch': ['all'],
#  'wealth.': ['So,'],
#  'better': ['hold', 'looking', 'just'],
#  'hold': ['onto', 'onto'],
#  'onto': ['that', 'the', 'his'],
#  'retainer': ['from'],
#  'grade,': ['’cause'],
#  'might': ['come', 'need', 'mean'],
#  'come': ['in', 'out,', 'up', 'out,', 'out', 'home,', 'with', 'out'],
#  'handy': ['as'],
#  'as': ['a',
#   'a',
#   'an',
#   'women',
#   'much',
#   'they',
#   'a',
#   'many',
#   'possible',
#   'the',
#   'freaky',
#   'me.',
#   'a',
#   'old',
#   'her.',
#   'wet',
#   'it',
#   'pent-up,',
#   'angry',
#   'possible.',
#   'leverage',
#   'it'],
#  'shovel': ['when'],
#  'busy': ['stuffing', 'in', 'makin’'],
#  'stuffing': ['gold'],
#  'gold': ['up'],
#  'butt': ['and', 'hole.', 'with', 'hole', 'cheeks', 'hole.'],
#  'running': ['away'],
#  'Communists.': ['The'],
#  'last': ['time',
#   'forever.',
#   'boyfriend',
#   'time',
#   'year,',
#   'boyfriend',
#   'year,'],
#  'time': ['I', 'shitting', 'I', 'I', 'you'],
#  'was': ['at',
#   'trying',
#   'like',
#   'so',
#   'this',
#   'like',
#   'like',
#   'like,',
#   'like,',
#   'like,',
#   'that,',
#   'attending',
#   'like,',
#   'a',
#   'like,',
#   'living',
#   'like,',
#   'like,',
#   'like,',
#   'like,',
#   'like,',
#   'like,',
#   'Cuban',
#   'like,',
#   'like,',
#   'like,',
#   'legit,',
#   'gonna',
#   'ready.',
#   'ripe.',
#   'rotten.',
#   'free?',
#   'like,',
#   'you.',
#   'like,',
#   'like,',
#   'like,',
#   'very',
#   'magical.',
#   'to',
#   'sliced',
#   'sliced',
#   'like,',
#   'like,',
#   'gonna',
#   'starting',
#   'just',
#   'so',
#   'in',
#   'OK,',
#   'clearly',
#   'that',
#   'Easter',
#   'so',
#   'about',
#   'like,',
#   'like,',
#   'like,',
#   'like,',
#   'like,',
#   '18',
#   'like,',
#   'like,',
#   '$70,000'],
#  'San': ['Francisco,', 'Francisco,'],
#  'Francisco,': ['I', 'when'],
#  'trying': ['to', 'to', 'to', 'to', 'to', 'to', 'to', 'to'],
#  'her': ['get',
#   'to',
#   'book',
#   'Lululemon',
#   'butt.”',
#   'nipples,',
#   'pussy',
#   'white',
#   'I'],
#  'rid': ['of'],
#  'shit.': ['Don’t', 'My', 'You’re', 'It’s'],
#  'Don’t': ['ever', 'try', 'your', 'kill', 'feel'],
#  'ever': ['do', 'actually', 'happened'],
#  'do': ['that',
#   'know…',
#   'fancy',
#   'yoga.',
#   'ayahuasca',
#   'silent',
#   'shit',
#   'it.',
#   'it',
#   'anything.',
#   'it!',
#   'anything.”',
#   'write',
#   'that.',
#   'whatever',
#   'that.',
#   'all',
#   'anal',
#   'it.',
#   'get',
#   'whatever',
#   'this',
#   'that',
#   'it',
#   'in',
#   'some',
#   'whatever',
#   'for',
#   'shit',
#   'mushrooms',
#   'a',
#   'it?',
#   'you'],
#  'mom.': ['It', 'People'],
#  'It': ['was',
#   'was',
#   'was',
#   'cost',
#   'could',
#   'was',
#   'happened',
#   'happened',
#   'basically',
#   'was',
#   'tells',
#   'was,',
#   'makes'],
#  'worst': ['experience', 'thing'],
#  'experience': ['of', 'some'],
#  'life.': ['It', 'And'],
#  'emotional.': ['We'],
#  'were': ['screaming',
#   'all',
#   'in',
#   'hipsters,',
#   'getting',
#   'done,',
#   'like,',
#   'discouraging',
#   'like,',
#   '18',
#   'alarmingly',
#   'suppositories,',
#   'trying',
#   'like,',
#   'the'],
#  'screaming': ['and'],
#  'fighting': ['and'],
#  'yelling': ['and'],
#  'came': ['to', 'outta', 'out'],
#  'climax': ['when'],
#  'refused': ['to', 'to'],
#  'let': ['go', 'it', 'their'],
#  'Texas': ['Instruments'],
#  'Instruments': ['TI-82…'],
#  'TI-82…': ['manual.'],
#  'manual.': ['The', 'She'],
#  'She': ['don’t', 'doesn’t'],
#  'know…': ['where', 'that', 'freaked'],
#  'calculator': ['is.', 'is.', 'that'],
#  'is.': ['Those', 'It'],
#  'Those': ['of'],
#  'under': ['25'],
#  '25': ['probably'],
#  'probably': ['don’t', 'Pinterested', 'one', 'looked'],
#  'bamboozled': ['my'],
#  'generation.': ['We', 'You'],
#  'required': ['to'],
#  'buy': ['it'],
#  'we': ['were',
#   'had,',
#   'had…',
#   'were',
#   'were',
#   'spend',
#   'pay',
#   'eat',
#   'eat',
#   'do…',
#   'are',
#   'have',
#   'as',
#   'better',
#   'have',
#   'had',
#   'walk',
#   'just',
#   'live',
#   'wouldn’t',
#   'got',
#   'got',
#   'bought',
#   'die.'],
#  'eight': ['grade.'],
#  'grade.': ['It'],
#  'cost': ['like'],
#  '$200.': ['And'],
#  'everybody': ['thought', 'doesn’t', 'thought'],
#  'thought': ['it', 'they', 'it'],
#  'Judy': ['Jetson’s'],
#  'Jetson’s': ['laptop'],
#  'laptop': ['from'],
#  'future.': ['All', '‘Cause'],
#  'All': ['because', 'of', 'the', 'right,'],
#  'what?': ['It'],
#  'graph.': ['It'],
#  'Tesla': ['of'],
#  'time.': ['And', 'And', 'And', 'It'],
#  'emotional': ['about'],
#  'manual': ['and'],
#  '“You': ['never', 'need', 'need', 'have', 'look.”', 'watch'],
#  'need': ['this.”',
#   'to',
#   'to',
#   'to',
#   'to',
#   'to',
#   'to',
#   'to',
#   'to',
#   'to',
#   'children',
#   'to',
#   'you',
#   'to'],
#  'this.”': ['And'],
#  '“But…': ['I'],
#  'clean': ['all'],
#  'die.”': ['“And'],
#  '“And': ['I’m', 'all'],
#  'be': ['a',
#   'a',
#   'nice',
#   'with',
#   'racist',
#   'exfoliated',
#   'providing',
#   'made',
#   'no',
#   'like,',
#   'like,',
#   'like,',
#   'a',
#   'all',
#   'abused',
#   'roughed',
#   'out',
#   'sure',
#   'out',
#   'the',
#   'able',
#   'like,',
#   'there',
#   'there',
#   'one',
#   'that',
#   'storyboarding',
#   'able',
#   'like,',
#   'as',
#   'like,',
#   'like,',
#   'pregnant',
#   'seven',
#   'asked',
#   'considered',
#   'considered',
#   'one'],
#  'procrastinator': ['anymore.'],
#  'anymore.': ['Because', 'I', 'I', 'I’ve', 'Since', 'I’m', 'I’m', 'I’m'],
#  'according': ['to', 'to'],
#  'Deepak-Oprah,': ['that’s'],
#  'way': ['for', 'out', 'of', 'to…”', 'more'],
#  'success.”': ['I'],
#  'grew': ['up', 'up', 'up', 'up'],
#  'past': ['year.', 'year'],
#  'married.': ['Yeah.', 'I’m'],
#  'Yeah.': ['To', 'Yes.', 'Which', 'It’s'],
#  'To': ['a'],
#  'man': ['who', 'and', 'has', 'a', 'at', 'all', 'is'],
#  'who': ['now',
#   'is',
#   'like',
#   'are',
#   'wrote',
#   'are',
#   'have',
#   'recycles',
#   'are',
#   'have',
#   'else',
#   'tries',
#   'trapped'],
#  'now': ['has', 'for', 'we’re'],
#  'lucky': ['guy.', 'girl,'],
#  'guy.': ['He'],
# ...
#   'him'],
#  'dude': ['believe', 'you', 'eats', 'and', 'named'],
#  'believe': ['that', 'that.”', 'he', 'that'],
#  'secret': ['garden.”'],
#  'garden.”': ['When,'],
#  'When,': ['really,'],
#  'really,': ['it’s', 'you', 'I'],
#  'public': ['park…'],
#  'park…': ['…that'],
#  '…that': ['has', 'blows'],
#  'hosted': ['many'],
#  'many': ['reggae', 'more', 'men'],
#  'reggae': ['fests…'],
#  'fests…': ['…and'],
#  '…and': ['has', 'half-jungle'],
#  'accidentally': ['let…'],
#  'let…': ['two'],
#  'homeless': ['people', 'or', 'friends,', 'dude!'],
#  'people': ['inside.',
#   'are',
#   'all',
#   'don’t',
#   'until',
#   'doing',
#   'were',
#   'will'],
#  'hipsters,': ['OK?'],
#  'store': ['Urban'],
#  'Urban': ['Outfitters'],
#  'Outfitters': ['has'],
#  'made': ['things', 'into', 'it,', 'me', 'you'],
#  'things': ['very', 'like'],
#  'confusing…': ['for'],
#  'hipster?': ['Is'],
#  'Is': ['that'],
#  'beard': ['for'],
#  'fashion': ['or'],
#  'warmth?': ['It'],
#  'happened': ['to…', 'in', 'to'],
#  'to…': ['It', 'Now,'],
#  'living': ['there,'],
#  'there,': ['and', 'through', 'OK?'],
#  'guy': ['in'],
#  'broad': ['daylight'],
#  'daylight': ['and'],
#  'had,': ['like,'],
#  'had…': ['We'],
#  'had': ['so',
#   'been',
#   'this',
#   'been',
#   'this',
#   'tried',
#   'it',
#   'to',
#   'a',
#   'to',
#   'the',
#   'this',
#   'a',
#   'such',
#   'this',
#   'to',
#   'to',
#   'to',
#   'to',
#   'a',
#   'a',
#   'one,',
#   'the',
#   'dated'],
#  'chemistry.': ['He'],
#  '“Hey,': ['wassup?”', 'can', 'I', 'hey!', 'can'],
#  'wassup?”': ['I'],
#  '“Wassup?”': ['And'],
#  'we–': ['The'],
#  'next': ['thing', 'century'],
#  'knew,': ['we'],
#  'back': ['of', 'out', 'in', 'of', 'in'],
#  'Volvo.': ['And'],
#  'after': ['we', 'they'],
#  'done,': ['he'],
#  'drop': ['me'],
#  'off?”': ['I'],
#  '“Where?”': ['He'],
#  '“At': ['the'],
#  'park.”': ['And'],
#  'dropped': ['him'],
#  'off': ['at', 'and', 'of'],
#  'Golden': ['Gate'],
#  'Gate': ['Park'],
#  'Park': ['and'],
#  'watched': ['him'],
#  'run': ['into', 'over'],
#  'middle': ['with'],
#  'friends,': ['and', 'when', 'dead.', 'dead.', 'dead.'],
#  'no!”': ['“I'],
#  '“I': ['just',
#   'could',
#   'did',
#   'saw',
#   'just',
#   'gotta',
#   'don’t',
#   'changed',
#   'slime',
#   'am'],
#  'dude!': ['Again!”'],
#  'Again!”': ['My'],
#  'husband': ['is',
#   'and',
#   'recently.',
#   'is',
#   'to',
#   'and',
#   'dies.”',
#   'isn’t',
#   'and',
#   'a',
#   'down',
#   'will',
#   'for',
#   'on,',
#   'was'],
#  'Asian.': ['Which', 'Yeah!'],
#  'Which': ['a', 'is…', 'means', 'is', 'is', 'he’s', 'is'],
#  'shocked': ['by,'],
#  'by,': ['because,'],
#  'usually,': ['Asian-American'],
#  'Asian-American': ['women', 'men', 'brothers'],
#  'women': ['who,',
#   'all',
#   'should',
#   'had',
#   'get',
#   'get',
#   'who',
#   'who',
#   'who',
#   'would',
#   'won’t',
#   'tried'],
#  'who,': ['like,'],
#  'know,': ['wear',
#   'because',
#   'white',
#   'it’s',
#   'just',
#   'learning',
#   'I',
#   'squeeze',
#   'it’s–',
#   'and',
#   'a',
#   'is',
#   'I–',
#   'they',
#   'I–'],
#  'wear': ['these', 'that'],
#  'these': ['kinda',
#   'bitches.',
#   'Chinese',
#   'women',
#   'boring,',
#   'other',
#   'hormone',
#   'ovulation'],
#  'kinda': ['glasses'],
#  'glasses': ['and'],
#  'opinions,': ['they'],
#  'date': ['white'],
#  'white': ['dudes.',
#   'dude',
#   'dude,',
#   'dudes,',
#   'dude.',
#   'dude',
#   'man!',
#   'people',
#   'people.',
#   'friends,',
#   'hippie'],
#  'dudes.': ['You'],
#  'any': ['hipster', 'moment,', 'real', 'sort', 'black', 'given'],
#  'hipster': ['neighborhood'],
#  'neighborhood': ['in'],
#  'major': ['city'],
#  'city': ['in'],
#  'America': ['and'],
#  'Yoko': ['Ono'],
#  'Ono': ['factory.'],
#  'factory.': ['It’s…'],
#  'It’s…': ['too', 'amazing.', 'It’s'],
#  'too': ['much.', 'nice.', 'old', 'late', 'stupid', 'funky,'],
#  'much.': ['I', 'For'],
#  'what’s': ['wrong', 'gonna', 'wrong'],
#  'wrong': ['with', 'with'],
#  'it,': ['you', 'you', 'and', 'that', 'when', 'just…'],
#  'being': ['with', 'the', 'courageous.'],
#  'feel': ['very…',
#   'very',
#   'like',
#   'more',
#   'like',
#   'like',
#   'rushed',
#   'like',
#   'so',
#   'bad,'],
#  'very…': ['You'],
#  'picturesque': ['when'],
#  'dude,': ['you', 'focus', 'and'],
#  'know.': ['You'],
#  'Wes': ['Anderson'],
#  'Anderson': ['movie'],
#  'movie': ['or'],
#  'dudes,': ['they'],
#  'teach': ['you'],
#  'cool': ['stuff', 'stuff'],
#  'stuff': ['like', 'like'],
#  'voting': ['and'],
#  'recycling,': ['and'],
#  'disturbing': ['documentaries.'],
#  'documentaries.': ['They'],
#  'introduce': ['you'],
#  'very,': ['you', 'very'],
#  'hot': ['hookin’'],
#  'hookin’': ['up'],
#  'dude.': ['I', 'Do', 'That’s–'],
#  'mean,': ['nothing'],
#  'nothing': ['makes', 'for'],
#  'makes': ['me', 'me', 'sense,'],
#  'more': ['powerful',
#   'like',
#   'options',
#   'doo',
#   'money',
#   'successful',
#   'to',
#   'women',
#   'handsome'],
#  'powerful': ['than'],
#  'eats': ['my'],
#  'pussy.': ['Oh,'],
#  'Oh,': ['my', 'my', 'you', 'my', 'my', 'my'],
#  'God.': ['I', 'It’s', 'That’s', 'I'],
#  'absorbing': ['all'],
#  'privilege': ['and'],
#  'entitlement…': ['…you'],
#  '…you': ['know,'],
#  'right': ['there,', 'now!', 'moment', 'turn–', 'there.', 'after'],
#  'through': ['the', 'Southeast', 'and', 'a', 'it.', 'a'],
#  'money': ['hole', 'if'],
#  'hole': ['and', 'feels'],
#  'just…': ['And', 'Let’s', '“I', 'And'],
#  'also,': ['he’s'],
#  'vulnerable': ['down'],
#  'down': ['there.', 'there,', 'your', 'immediately', 'in', 'so', 'with'],
#  'there.': ['I’m,', 'I', 'But'],
#  'I’m,': ['like,', 'like,'],
#  'crush': ['your'],
#  'head': ['at', 'shredding', 'and', 'for'],
#  'moment,': ['white', 'you'],
#  'man!': ['I'],
#  'kill': ['you', 'me!'],
#  'now!': ['Crush'],
#  'Crush': ['those', 'while'],
#  'those': ['brains!', 'comments.', 'green', 'old', 'doctor', 'crazy'],
#  'brains!': ['Colonize'],
#  'Colonize': ['the'],
#  'colonizer!”': ['You'],
#  'know?': ['But',
#   'My',
#   'Ooh-wee.',
#   'Maybe',
#   'I',
#   'Especially',
#   'My',
#   'Like,',
#   'I',
#   'I',
#   'Another',
#   'I',
#   'And,',
#   'Your',
#   'And'],
#  'think': ['that',
#   'my',
#   'feminism',
#   'we',
#   'it’s',
#   'of',
#   'about',
#   'that’s',
#   'so.',
#   'I’m'],
#  'marriage,': ['it', 'because'],
#  'nice': ['to'],
#  'somebody': ['of', 'closes', 'closes'],
#  'own': ['race.', 'goddamn'],
#  'race.': ['The'],
#  'advantage': ['is'],
#  'home…': ['and'],
#  'racist': ['together.'],
#  'together.': ['You', 'And,'],
#  'say': ['whatever', 'to', 'be'],
#  'whatever': ['you', 'they', 'you', 'the'],
#  'like!': ['You'],
#  'explain': ['shit.'],
#  'half-Filipino,': ['half-Japanese.'],
#  'half-Japanese.': ['I’m'],
#  'half-Chinese': ['and', 'and'],
#  'half-Vietnamese.': ['And', 'So,'],
#  'spend': ['100'],
#  '100': ['percent'],
#  'percent': ['of', 'of', 'spoken'],
#  'our': ['time', 'first', 'Buddha', 'careers.', 'day', 'society', 'first'],
#  'shitting': ['on'],
#  'Korean': ['people.'],
#  'amazing.': ['It’s'],
#  'love': ['is', 'to', 'it', 'my', 'it', 'of'],
#  'built': ['on,'],
#  'on,': ['you', 'you', 'like,'],
#  'boyfriend': ['was', 'because'],
#  'Cuban': ['and'],
#  'would': ['shit',
#   'double',
#   'not',
#   'have',
#   'I',
#   'crash.”',
#   'simultaneously',
#   'explode.',
#   'be',
#   'be',
#   'inevitably',
#   'only',
#   'be',
#   'come',
#   'just',
#   'close',
#   'jump',
#   'just',
#   'turn',
#   'just',
#   'talk'],
#  'Mexican': ['people', 'friends,'],
#  '“Hold': ['it.'],
#  'guys': ['aren’t', 'know', 'about', 'need', 'had.”', 'can', 'doin’'],
#  'aren’t': ['Mexican?”'],
#  'Mexican?”': ['Asian-American'],
#  'underrated.': ['I'],
#  'why': ['people', 'you', 'are', 'we’re', 'I’m'],
#  'sexiest.': ['Asian', 'They'],
#  'Asian': ['men', 'men,', 'people.', 'female', 'woman,', 'don’t', 'ladies'],
#  'no': ['body', 'body', 'job.', 'unpredictable', 'kid', 'shame.'],
#  'hair': ['from'],
#  'neck': ['down.'],
#  'down.': ['It’s', 'I', 'I', 'People'],
#  'making': ['love'],
#  'dolphin.': ['Oh,'],
#  'smooth,': ['just'],
#  'slip': ['and'],
#  'slide.': ['Just'],
#  'Just': ['black', 'sneak', 'give', 'give', 'choke', 'try'],
#  'black': ['fish,', 'friends.'],
#  'fish,': ['Tilikum,'],
#  'Tilikum,': ['all'],
#  'bed': ['every'],
#  'every': ['night,',
#   'day.”',
#   'single',
#   'day.',
#   'day.',
#   'day…',
#   'day',
#   'single'],
#  'night,': ['you', 'everybody.'],
#  'Ooh-wee.': ['You'],
#  'mess': ['with'],
#  'Jewish': ['dude', 'male'],
#  'afterwards.': ['It’s', 'I'],
#  'red': ['and', 'light'],
#  'inflamed': ['and'],
#  'ask': ['to', 'for,'],
#  'exfoliated': ['today.”'],
#  'today.”': ['“This'],
#  '“This': ['is'],
#  'J-date,': ['more'],
#  'loofah': ['date.'],
#  'date.': ['Thanks'],
#  'Thanks': ['for'],
#  'rug': ['burn,'],
#  'burn,': ['Avi.”'],
#  'Avi.”': ['And'],
#  'men,': ['no'],
#  'odor.': ['None.'],
#  'None.': ['They'],
#  'smell': ['like', 'my', 'my', 'my', 'my', 'my'],
#  'responsibility.': ['That’s'],
#  'umami': ['flavor'],
#  'flavor': ['comes'],
#  'comes': ['from.', 'out.', 'out', 'out,', 'to'],
#  'from.': ['I'],
#  'unspoken': ['understanding,'],
#  'understanding,': ['uh,'],
#  'between': ['each', 'your'],
#  'each': ['other,', 'other.'],
#  'other,': ['because'],
#  'half-Filipino': ['and'],
#  'half-Japanese': ['and'],
#  'we’re': ['both', 'too', 'expected', 'so', 'such', 'trying', 'hippies,'],
#  'both': ['half-fancy', 'total,', 'are'],
#  'half-fancy': ['Asian…'],
#  'Asian…': ['…and'],
#  'half-jungle': ['Asian.'],
#  'Yeah!': ['You', 'Never'],
#  'difference.': ['The'],
#  'fancy': ['Asians', 'things'],
#  'Asians': ['are', 'host'],
#  'Chinese,': ['the'],
#  'Japanese.': ['They'],
#  'host': ['Olympics.', 'diseases.'],
#  'Olympics.': ['Jungle'],
#  'Jungle': ['Asians'],
#  'diseases.': ['It’s…'],
#  'different.': ['But', 'It’s'],
#  'East': ['Coast,'],
#  'Coast,': ['going'],
#  'going': ['to', 'to', 'back', 'through', 'through', 'to'],
#  'private': ['school,', 'school,', 'school'],
#  'school,': ['playing', 'too.'],
#  'playing': ['lacrosse,', 'chess', 'dumb', 'Candy'],
#  'lacrosse,': ['uh,'],
#  'learning': ['Latin'],
#  'Latin': ['and'],
#  'chess': ['and'],
#  'rugby.': ['He'],
#  'Filipino': ['Carlton,'],
#  'Carlton,': ['OK?'],
#  'didn’t': ['know', 'think', 'know', 'know'],
#  'anything': ['about'],
#  'Vietnamese': ['people'],
#  'dates,': ['he'],
#  'took': ['me', 'it', 'me'],
#  'restaurant': ['on', 'deaf'],
#  'west': ['side'],
#  'side': ['of', 'from', 'effect'],
#  'Los': ['Angeles'],
#  'Angeles': ['called'],
#  'called': ['Pho', 'Lean', 'bossy.'],
#  'Pho': ['Show.'],
#  'Show.': ['He'],
#  '“It’s': ['authentic', 'not'],
#  'authentic': ['Vietnamese.'],
#  'Vietnamese.': ['I'],
#  'read': ['about'],
#  'Yelp!”': ['I'],
#  'authentic,': ['OK?”'],
#  'OK?”': ['You', '‘Cause', 'And', 'And'],
#  'tell,': ['first', 'but'],
#  'name,': ['’cause'],
#  'number': ['in'],
#  'Second': ['of'],
#  'all,': ['you'],
#  'bathroom.': ['If'],
#  'legit,': ['the'],
#  'bathroom': ['would'],
#  'double': ['as', 'standard'],
#  'supply': ['closet.'],
#  'closet.': ['When'],
#  'When': ['I',
#   'you',
#   'I',
#   'I’ve',
#   'can',
#   'can',
#   'my',
#   'in–',
#   'you’re',
#   'somebody',
#   'somebody',
#   'I',
#   'it’s'],
#  'pee,': ['I'],
#  'gallons': ['of'],
#  'bleach,': ['an'],
#  'ATM': ['machine'],
#  'machine': ['and'],
#  'grandma': ['with'],
#  'glaucoma': ['napping'],
#  'napping': ['in'],
#  'corner.': ['And'],
#  'wait': ['staff', 'to'],
#  'staff': ['here', 'and'],
#  'nice.': ['We'],
#  'leave': ['this', 'without', 'you,'],
#  'deaf': ['and'],
#  'emotionally': ['abused.'],
#  'abused.': ['I'],
#  'too.': ['Him', 'We', 'But', 'They'],
#  'Him': ['and', 'and'],
#  'total,': ['like,'],
#  'school': ['Asians.'],
#  'Asians.': ['We'],
#  'big': ['hippies,', 'fantasy', 'impact'],
#  'hippies,': ['too.', 'I’d'],
#  'backpack': ['through'],
#  'Southeast': ['Asia.'],
#  'Asia.': ['We'],
#  'yoga.': ['We'],
#  'ayahuasca': ['ceremonies.'],
#  'ceremonies.': ['We'],
#  'silent': ['meditation'],
#  'meditation': ['retreats.'],
#  'retreats.': ['That’s'],
#  'pay': ['$800', 'for'],
#  '$800': ['to'],
#  'shut': ['up', 'up!”', 'the'],
#  'weekend.': ['We'],
#  'gluten-free,': ['which'],
#  'means': ['we', 'I', 'the', 'you’re'],
#  'bread': ['that', 'that’s'],
#  'tastes': ['like', 'when'],
#  'free-range': ['Chewbacca.'],
#  'Chewbacca.': ['We'],
#  'lesbian': ['bread'],
#  'like…': ['…a'],
#  '…a': ['thousand'],
#  'thousand': ['percent'],
#  'daily': ['fiber…', 'basis.', 'basis…'],
#  'fiber…': ['and'],
#  '20': ['percent'],
#  'spoken': ['word'],
#  'word': ['poetry.', '“bossy”', '“bossy,”'],
#  'poetry.': ['When'],
#  'queef': ['a'],
#  'shitty': ['poem', 'dads', 'mom.'],
#  'poem': ['about…'],
#  'about…': ['…supporting'],
#  '…supporting': ['Caitlyn'],
#  'Caitlyn': ['Jenner'],
#  'Jenner': ['or'],
#  'whatever.': ['And'],
#  'so,': ['it’s', 'in', 'motherfucker,'],
#  'funny,': ['right,'],
#  'Asian,': ['too.'],
#  'sometimes,': ['all'],
#  'hippy-dippy': ['shit'],
#  'do…': ['makes'],
#  'doing': ['an', 'anything.', 'jack', 'it.'],
#  'impression': ['of'],
#  'Like,': ['we', 'you', '“I', 'I’m', '“You,'],
#  'Chinese': ['scrolls', 'ladies', 'ladies,'],
#  'scrolls': ['up'],
#  'wall…': ['and'],
#  'neither': ['of'],
#  'us': ['know', 'to,'],
#  'mean.': ['We’re'],
#  'We’re': ['like,', 'like,'],
#  'seems': ['to', 'to'],
#  'well': ['with'],
#  'Buddha': ['piggy'],
#  'piggy': ['bank'],
#  'bank': ['from'],
#  'Pier': ['1'],
#  '1': ['Imports.'],
#  'Imports.': ['That'],
#  'providing': ['some'],
#  'some': ['good', 'risk', 'useful', 'lame', 'point,', 'of'],
#  'good': ['feng', 'in', 'night,'],
#  'feng': ['shui'],
#  'shui': ['for'],
#  'house.': ['Him', 'Skin', '“Hey,'],
#  'four': ['years', 'days'],
#  'years': ['and', 'old,', 'old,'],
#  'I–': ['I', 'I–', 'I,', 'I,'],
#  'sneaking': ['suspicion'],
#  'suspicion': ['that'],
#  'propose…': ['because…'],
#  'because…': ['I', 'they’re'],
#  'pressuring': ['him'],
#  'wacky': ['women’s'],
#  'intuition.': ['That’s'],
#  'proposals': ['really'],
#  'work,': ['OK?', 'we'],
#  'woman': ['has', 'is', 'wants', 'who'],
#  'incept': ['the'],
#  'idea': ['into'],
#  'man’s': ['head.', 'eye'],
#  'head.': ['First'],
#  'First': ['passively'],
#  'passively': ['and'],
#  'doesn’t': ['get', 'see', 'have', 'have', 'believe'],
#  'message,': ['extremely'],
#  'extremely': ['aggressively.', 'itchy.'],
#  'aggressively.': ['You'],
#  'threaten': ['to'],
#  'without': ['ever'],
#  'actually': ['leaving,'],
#  'leaving,': ['because'],
#  'old': ['and', 'as', 'Chinese'],
#  'late': ['to'],
#  'there': ['and', 'and', 'is', 'for', 'for', 'would'],
#  'new': ['man', 'world'],
#  'start': ['the', 'all', 'watching'],
#  'manipulation': ['cycle'],
#  'cycle': ['all'],
#  'again.': ['So,', 'And', 'It’s', 'But'],
#  '“I’m': ['just', 'gonna', 'just'],
#  'stick': ['with', 'your'],
#  'focus': ['on'],
#  'trapping': ['this'],
#  'nag': ['the'],
#  'outta': ['him', 'nowhere.'],
#  'becomes': ['weak'],
#  'weak': ['and'],
#  'caves': ['in'],
#  'gets': ['fed', 'very'],
#  'fed': ['up'],
#  '“Shut': ['the'],
#  'up!': ['Fine,'],
#  'Fine,': ['will'],
#  'marry': ['me?”', 'him'],
#  'me?”': ['And'],
#  'afterwards,': ['the', 'and'],
#  'always,': ['like,'],
#  'God!': ['He', 'It’s', 'And'],
#  'proposed!”': ['“It'],
#  '“It': ['came'],
#  'nowhere.': ['And', 'And'],
#  'look,': ['he'],
#  'exact': ['ring'],
#  'ring': ['I'],
#  'wanted.': ['How', 'I’m'],
#  'Maybe': ['he', 'because'],
#  'Pinterest': ['page', 'page…'],
#  'page': ['or'],
#  'something…': ['that'],
#  'sent': ['to'],
#  'best': ['friend,', 'you'],
#  'friend,': ['that'],
#  'send': ['to'],
#  'day.”': ['Let'],
#  'Let': ['me', 'me'],
#  'page…': ['he’s'],
#  'Pinterested': ['in'],
#  'engaged': ['on'],
#  'Saturday.': ['I'],
#  'bought': ['my', 'me', 'our'],
#  'dress': ['the'],
#  'following': ['Tuesday…'],
#  'Tuesday…': ['because'],
#  'tried': ['it', 'to', 'to'],
#  '2012.': ['I'],
#  'ready.': ['I'],
#  'ripe.': ['I'],
#  'rotten.': ['I'],
#  'banana': ['bread.'],
#  'bread.': ['That’s'],
#  'rotten': ['I'],
#  'was.': ['People'],
#  'People': ['are', 'praise', 'don’t'],
#  'always': ['very', 'feel', 'catch', 'means', 'tell', 'wanted.'],
#  'surprised': ['at'],
#  'how,': ['off-stage,'],
#  'off-stage,': ['with'],
#  'completely': ['different'],
#  'different': ['person.', 'holes,', 'people.'],
#  'person.': ['You–'],
#  'You–': ['Like,'],
#  'recognize': ['my', 'your'],
#  'personality': ['at'],
#  'him.': ['With', 'But'],
#  'With': ['him,'],
#  'soft,': ['and,'],
#  'nurturing': ['and'],
#  'domestic.': ['We’ve'],
#  'We’ve': ['been'],
#  'years,': ['and', 'I’ve'],
#  'I’ve': ['packed', 'been', 'been', 'asked', 'picked', 'been'],
#  'packed': ['his'],
#  'lunch': ['every'],
#  'single': ['day.', 'night.'],
#  'day.': ['Yeah.', 'Which', 'Housewives,', 'This'],
#  'he’d': ['become'],
#  'become': ['dependent', 'the', 'a', 'this', 'some'],
#  'dependent': ['on'],
#  'graduated': ['from', 'from'],
#  'School,': ['and', 'the'],
#  'work': ['anymore.',
#   'anymore.',
#   'anymore.',
#   'at',
#   'because',
#   'on',
#   'anymore',
#   'anymore.'],
#  'don’t.': ['I'],
#  'feed': ['him'],
#  'goodness': ['of'],
#  ...}

# %% [markdown]
# ## Create a Text Generator

# %% [markdown]
# We're going to create a function that generates sentences. It will take two things as inputs:
# * The dictionary you just created
# * The number of words you want generated
#
# Here are some examples of generated sentences:
#
# >'Shape right turn– I also takes so that she’s got women all know that snail-trail.'
#
# >'Optimum level of early retirement, and be sure all the following Tuesday… because it’s too.'

# %%
import random

def generate_sentence(chain, count=15):
    '''Input a dictionary in the format of key = current word, value = list of next words
       along with the number of words you would like to see in your generated sentence.'''

    # Capitalize the first word
    word1 = random.choice(list(chain.keys()))
    sentence = word1.capitalize()

    # Generate the second word from the value list. Set the new word as the first word. Repeat.
    for i in range(count-1):
        word2 = random.choice(chain[word1])
        word1 = word2
        sentence += ' ' + word2

    # End it with a period
    sentence += '.'
    return(sentence)

# %%
generate_sentence(ali_dict)
# Out:
# 'Craigslist… and posted ‘Tiny Asian men, no body is so smooth, just gonna overtake the.'

# %% [markdown]
# ### Assignment:
# 1. Generate sentence for other comedians also.
# 2. Try making the generate_sentence function better. Maybe allow it to end with a random punctuation mark or end whenever it gets to a word that already ends with a punctuation mark.

# %%
#Part 1
jim_text = data.transcript.loc['jim']
jim_text[:200]
# Out:
# '[Car horn honks] [Audience cheering] [Announcer] Ladies and gentlemen, please welcome to the stage Mr. Jim Jefferies! [Upbeat music playing] Hello! Sit down, sit down, sit down, sit down, sit down. [C'

# %%
louis_text = data.transcript.loc['louis']
louis_text[:200]
# Out:
# 'Intro Fade the music out. Let’s roll. Hold there. Lights. Do the lights. Thank you. Thank you very much. I appreciate that. I don’t necessarily agree with you, but I appreciate very much. Well, this i'

# %%
jim_dict = markov_chain(jim_text)
jim_dict
# Out:
# {'[Car': ['horn'],
#  'horn': ['honks]'],
#  'honks]': ['[Audience'],
#  '[Audience': ['cheering]',
#   'cheering]',
#   'whooping]',
#   'cheering]',
#   'whooping]',
#   'cheering]',
#   'cheering]',
#   'cheering]',
#   'whooping]',
#   'cheering]',
#   'cheering]',
#   'cheering]',
#   'applauding]',
#   'cheering]',
#   'booing]',
#   'applauding]',
#   'cheering]',
#   'cheering]',
#   'laughing]',
#   'exclaiming]',
#   'laughing]',
#   'groaning]',
#   'exclaiming]',
#   'laughing]',
#   'cheering]',
#   'cheering]'],
#  'cheering]': ['[Announcer]',
#   'Thank',
#   'Now…',
#   'But',
#   'Boston,',
#   '[Audience',
#   'And',
#   'Second',
#   'We',
#   '–',
#   'I',
#   'See…',
#   'Ladies',
#   '[Upbeat'],
#  '[Announcer]': ['Ladies'],
#  'Ladies': ['and', 'and'],
#  'and': ['gentlemen,',
#   'I',
#   'I’m',
#   'I',
#   'my',
#   'we’re',
#   'on',
#   'my',
#   'invite',
#   'a',
#   'we',
#   'we',
#   'one',
#   'Dennis',
#   'the',
#   'most',
#   'it’s',
#   'I',
#   'they',
#   'you',
#   'you’re',
#   'they’re',
#   'then',
#   'you',
#   'goes,',
#   'whenever',
#   'drinks',
#   'Jim',
#   'all',
#   'it',
#   'how',
#   'bought',
#   'I',
#   'you',
#   'my',
#   'it’s',
#   'it',
#   'again,',
#   'go…',
#   'for',
#   'all',
#   'stuff,',
#   'you',
#   'I',
#   'she',
#   'then',
#   'they',
#   'she’ll',
#   'she’ll',
#   'try',
#   'I',
#   'the',
#   'rightly',
#   'daughters,',
#   'gone,',
#   'all',
#   'baby',
#   'when',
#   'inside',
#   'you',
#   'he',
#   'get',
#   'Hank',
#   'the',
#   'he',
#   'she',
#   'there’s',
#   'me',
#   'a',
#   'then',
#   'wipe.',
#   'down,',
#   'away.',
#   'away.',
#   'balls,',
#   'I’ll',
#   'he’ll',
#   'go,',
#   'we’ll',
#   'laugh',
#   'laugh.',
#   'she’s',
#   'larger',
#   'my',
#   'they',
#   'then',
#   'then',
#   'we',
#   'shit.”',
#   'then',
#   'it',
#   'you',
#   'you’re',
#   'then',
#   'the',
#   'they',
#   'the',
#   'the',
#   'Madonna',
#   'Asian',
#   'America',
#   'the',
#   'your',
#   'lies.',
#   'one',
#   'this',
#   'a',
#   'Americans',
#   'I',
#   'your',
#   'go,',
#   'her',
#   'you’d',
#   'she’d',
#   'see',
#   'gentlemen.',
#   'I',
#   'it’s',
#   'they’re',
#   'the',
#   'this',
#   'that’s',
#   'your',
#   'you',
#   'it’s',
#   'you’re',
#   'scream',
#   'work',
#   'went,',
#   'you',
#   'she',
#   'ran',
#   'that’s',
#   'you',
#   'your',
#   'fight',
#   'that’s',
#   'you’re',
#   'as',
#   'like',
#   'that',
#   'have',
#   'just',
#   'then',
#   'then',
#   'puts',
#   'you',
#   'going',
#   'going…',
#   'then',
#   'then',
#   'if',
#   'DJ',
#   'he’s',
#   'the',
#   'diseases',
#   'I’ll',
#   'I’m',
#   'we’re',
#   'at',
#   'I',
#   'I',
#   'I',
#   'I',
#   'that',
#   'his',
#   'his',
#   'practiced',
#   'I’m',
#   'I',
#   'he',
#   'then',
#   'go,',
#   'again.',
#   'you',
#   'I',
#   'I',
#   'all',
#   'I',
#   'you…',
#   'all',
#   'married',
#   'the…',
#   'hits',
#   'I’m',
#   'when',
#   'Hank',
#   'he',
#   'I',
#   'a',
#   'then',
#   'I',
#   'he',
#   'I’ve',
#   'there',
#   'I',
#   'I’m',
#   'stuff',
#   'then',
#   'the',
#   'I’m',
#   'they’re',
#   'the',
#   'millions',
#   'able-bodied',
#   'on',
#   'killed',
#   'that’s',
#   'on',
#   'a',
#   'he',
#   'then',
#   'making',
#   'all',
#   'he',
#   'cheers,',
#   'I',
#   'I',
#   'go',
#   'I',
#   'they’re',
#   'I',
#   'the',
#   'they',
#   'they',
#   'goes,',
#   'I',
#   'if',
#   'she',
#   'went,',
#   'then',
#   'one',
#   'I',
#   'all!',
#   'we',
#   'they',
#   'went,',
#   'he',
#   'he',
#   'I',
#   'I',
#   'all',
#   'all,',
#   'the',
#   'that',
#   'gentlemen,'],
#  'gentlemen,': ['please', 'thank'],
#  'please': ['welcome', 'understand', 'understand'],
#  'welcome': ['to'],
#  'to': ['the',
#   'be',
#   'party',
#   'party',
#   'be',
#   'party',
#   'have',
#   'elaborate',
#   'date',
#   'date',
#   'date',
#   'go',
#   'go',
#   'Madonna’s',
#   'another…”',
#   'another’',
#   'stretch',
#   'take',
#   'tip',
#   'your',
#   'raise',
#   'this',
#   'earn',
#   'earn',
#   'buy',
#   'spend',
#   'a',
#   'have…',
#   'have',
#   'take',
#   'fuck.',
#   'be',
#   'be',
#   'done?”',
#   'mouth.”',
#   'this',
#   'congratulate',
#   'fuck',
#   'hold',
#   'a',
#   'the',
#   'the',
#   'reach',
#   'the',
#   'bring',
#   'side,',
#   'call',
#   'have',
#   'me.',
#   'the',
#   'see',
#   'it',
#   'yours.”',
#   'bring',
#   'the',
#   'pass',
#   'get',
#   'purchase.',
#   'see',
#   'have',
#   'stop',
#   'have',
#   'protect',
#   'protect',
#   'use',
#   'shoot',
#   'me.”',
#   'time',
#   'rape',
#   'come',
#   'gun',
#   'home',
#   'be',
#   'murder',
#   'murder',
#   'the',
#   'the',
#   'the',
#   'be',
#   'her',
#   'that,',
#   'be',
#   'realize',
#   'be',
#   'that',
#   'Americans,',
#   'you.',
#   'me',
#   'have',
#   'have',
#   'use',
#   'protect',
#   'play',
#   'the',
#   'walk',
#   'keep',
#   'take',
#   'drive',
#   'drive',
#   'say',
#   'interpretation,',
#   '1,200',
#   'fair',
#   'your',
#   'be',
#   'sell',
#   'bear',
#   'fight',
#   'a',
#   'muskets,',
#   'calm',
#   'go',
#   'strip',
#   'go',
#   'them',
#   'be',
#   'a',
#   'each',
#   'see.',
#   'their',
#   'know',
#   'have',
#   'just',
#   'one',
#   'her',
#   'go',
#   'the',
#   'do',
#   'a',
#   'begin',
#   'make',
#   'work',
#   'work',
#   'do',
#   'worry',
#   'the',
#   'see',
#   'a',
#   'the',
#   'the',
#   'the',
#   'tell',
#   'go',
#   'rent',
#   'your',
#   'a',
#   'think',
#   'do',
#   'another',
#   'all',
#   'time,',
#   'you.',
#   'the',
#   'get',
#   'our',
#   'teach',
#   'the',
#   'do',
#   'airports',
#   'Melbourne.',
#   'the',
#   'anyone.',
#   'the',
#   'see',
#   'see',
#   'the',
#   'everyone?”',
#   'hundreds',
#   'me…',
#   'all',
#   'South',
#   'reenact',
#   'say',
#   'Rodriguez',
#   'my',
#   'prison.',
#   'put',
#   'rape',
#   'fucking',
#   'get',
#   'happen?',
#   'go,',
#   'pick',
#   'do,',
#   'fly',
#   'Los',
#   'go',
#   'London',
#   'dress',
#   'look',
#   'look',
#   'me',
#   'the',
#   'the',
#   'swear,',
#   'engage',
#   'hear',
#   'me',
#   'do?',
#   'the',
#   'Rodriguez,',
#   'business',
#   'the',
#   'speak',
#   'Simon',
#   'that',
#   'be',
#   'business',
#   'us,',
#   'me',
#   'calm',
#   'come'],
#  'the': ['stage',
#   'end',
#   'tour',
#   'future,',
#   'car,',
#   'back',
#   'radio',
#   'model',
#   'photos.',
#   'center',
#   'Miami',
#   'mother',
#   'center',
#   'Miami',
#   'four',
#   'fuck',
#   'mother',
#   'corner',
#   'end',
#   'table',
#   'rest',
#   'front',
#   'ER,',
#   'people',
#   'night',
#   'night',
#   'real',
#   'back,',
#   'size',
#   'open,',
#   'table.',
#   'best',
#   'morning',
#   'morning',
#   'thing.',
#   'moment,',
#   'minimum',
#   'workplace.”',
#   'workplace.',
#   'uglies,',
#   'Valentine’s',
#   'shopping',
#   'house,',
#   'crayon',
#   '“K”',
#   'room,',
#   'kid',
#   'handle’s',
#   'ass',
#   'shopping',
#   'decorations',
#   'ass,',
#   'same',
#   'ass',
#   'other',
#   'bar',
#   'ass',
#   'cunt.',
#   'ass',
#   'thing',
#   'girl’s',
#   'girl',
#   'experience',
#   'girl',
#   'porn',
#   'men',
#   'opposite',
#   'porn',
#   'cock',
#   'taste',
#   'man,',
#   'fine',
#   'ass',
#   'room',
#   'reason',
#   'ass',
#   'same',
#   'rest',
#   'time,',
#   'couple',
#   'road,',
#   'first',
#   'history',
#   'boys',
#   'gym',
#   'gym,',
#   'gym',
#   'other',
#   'two',
#   'stairs,',
#   'gym',
#   'feet',
#   'fuck',
#   'cunt.',
#   'foreskin,',
#   'best',
#   'ass,',
#   'history',
#   'most',
#   'second',
#   'party?”',
#   'fucking',
#   'dog…',
#   'humans,',
#   'fuck',
#   'dog,',
#   'kid',
#   'dog',
#   'dog,',
#   'dog',
#   'original',
#   'same',
#   'baby',
#   'same',
#   'short',
#   'same.',
#   'crowd',
#   'other',
#   'opinion.',
#   'biggest',
#   'guns.',
#   '10',
#   'gun',
#   'biggest',
#   'Australian',
#   'Sandy',
#   'big',
#   'argument…',
#   'best',
#   'fuck',
#   'window',
#   'time.',
#   'window',
#   'way,',
#   'house,',
#   'wrong',
#   'left',
#   'right?',
#   'fuck',
#   'window',
#   'NRA',
#   'answer',
#   'NRA',
#   'teachers',
#   'class',
#   'steering',
#   'school',
#   'people',
#   '50%',
#   'next',
#   'last',
#   'people',
#   'big',
#   'fuck',
#   'fuck',
#   'Second',
#   'constitution',
#   'theater,',
#   'Second',
#   'same',
#   'thing.',
#   '1%',
#   'rest',
#   'thing.',
#   'thing',
#   'better',
#   'guns',
#   'criminals',
#   'guns',
#   'kid',
#   'black',
#   'criminals,',
#   'people',
#   'massacres,',
#   'black',
#   'docks',
#   'one',
#   'right',
#   'real',
#   'government',
#   'government',
#   'Second',
#   'musket?',
#   'show,',
#   'fuck',
#   'fireman’s',
#   'ATM.”',
#   'special.',
#   'end,',
#   'skinny',
#   'movie',
#   'skinny',
#   'movie',
#   'white',
#   'movie',
#   'great',
#   'Actors’',
#   'problem',
#   'contagious',
#   'most',
#   'most',
#   'audition…',
#   'lines',
#   'dialog',
#   'room,',
#   'director',
#   'waiting',
#   'next',
#   'waist',
#   'role.”',
#   'same',
#   'role,',
#   'wheelchair',
#   'trunk',
#   'wheelchair',
#   'waiting',
#   'severely',
#   'fuck',
#   'headshots',
#   'different',
#   'greatest',
#   'fastest',
#   'guy’s',
#   'other',
#   'level',
#   'audition,',
#   'first',
#   'movies,',
#   'last',
#   'world?”',
#   'things',
#   'girls',
#   'Vietnam',
#   'First',
#   'women',
#   'effort',
#   'look',
#   'second',
#   'come',
#   'nicest',
#   'sweetest',
#   'guy',
#   'other',
#   'shower.',
#   'gym',
#   'morning,',
#   'shower,',
#   'glass',
#   'shower',
#   'condensation,',
#   '“K,”',
#   'bathroom',
#   'machine,',
#   'bag',
#   'gate',
#   'lady’s',
#   'plane',
#   'plane',
#   'TSA',
#   'airports.',
#   'Australians',
#   'TSA',
#   'TSA',
#   'guy',
#   'most',
#   'case,',
#   'greatest',
#   'Blade',
#   'disabled',
#   'able-bodied',
#   'hottest',
#   'fuck',
#   'theories',
#   'difference',
#   'difference.',
#   'shower.',
#   'bed.',
#   'phone,',
#   'fuck',
#   'fuck',
#   'greatest',
#   'fuck',
#   'room,',
#   'day…',
#   'Blade',
#   'blades',
#   'bathroom.',
#   'bathroom',
#   'few',
#   'door',
#   'blades,',
#   'prison',
#   'showers',
#   'end',
#   'rapist',
#   'villain',
#   'story,',
#   'hero.',
#   'side.',
#   'counter,',
#   'business',
#   'thing,',
#   'lady',
#   'tickets',
#   'first',
#   'executive',
#   'airport',
#   'counter.',
#   'woman',
#   'counter',
#   'manager',
#   'pale',
#   'guy',
#   'type,',
#   'women',
#   'group',
#   'pylon,',
#   'same',
#   'next',
#   'penny',
#   'woman',
#   'group',
#   'hell',
#   'men',
#   'group',
#   'fuck',
#   'fuck',
#   'group',
#   'corner',
#   'Neil',
#   'downgraded.',
#   'Internet,',
#   'airport',
#   'downgraded…',
#   'Neil'],
#  'stage': ['Mr.'],
#  'Mr.': ['Jim', 'Jefferies,'],
#  'Jim': ['Jefferies!', 'Jefferies'],
#  'Jefferies!': ['[Upbeat'],
#  '[Upbeat': ['music', 'music'],
#  'music': ['playing]', 'playing]'],
#  'playing]': ['Hello!', 'Thank'],
#  'Hello!': ['Sit'],
#  'Sit': ['down,'],
#  'down,': ['sit', 'sit', 'sit', 'sit', 'side', 'and'],
#  'sit': ['down,', 'down,', 'down,', 'down.'],
#  'down.': ['[Chuckles]', 'Someone', '[Chuckles]', 'And,', '“Hey,'],
#  '[Chuckles]': ['Thank', 'I', '[Laughs]', 'I', 'I’m', '[Man'],
#  'Thank': ['you,', 'you.', 'you.', 'God', 'you.'],
#  'you,': ['Boston.', 'Miss?', 'buddy!', 'not', 'Jim.”', 'ladies.”', 'a'],
#  'Boston.': ['I'],
#  'I': ['appreciate',
#   'now',
#   'got',
#   'love',
#   'don’t',
#   'don’t',
#   'was',
#   'used',
#   'went,',
#   'should',
#   'didn’t',
#   'didn’t',
#   'said,',
#   'go,',
#   'used',
#   'understand.”',
#   'went,',
#   'said,',
#   'said,',
#   'don’t',
#   'have',
#   'went,',
#   'have,',
#   'get',
#   'wouldn’t',
#   'was',
#   'don’t…',
#   'have',
#   'was',
#   'go,',
#   'spent',
#   'made',
#   'don’t',
#   'don’t',
#   'say',
#   'don’t',
#   'pay',
#   'bought',
#   'have',
#   'wonder',
#   'went,',
#   'was',
#   'went',
#   'assumed',
#   'wrote',
#   'wrote',
#   'got',
#   'went,',
#   'did',
#   'know',
#   'went,',
#   'don’t',
#   'said,',
#   'don’t',
#   'went,',
#   'don’t',
#   'don’t',
#   'much',
#   'think',
#   'think',
#   'do',
#   'get',
#   'feel',
#   'have',
#   'watch',
#   'don’t',
#   'love',
#   'like',
#   'enjoy',
#   'don’t',
#   'don’t',
#   'had',
#   'don’t',
#   'love',
#   'love',
#   'love',
#   'like',
#   'really',
#   'have',
#   'wouldn’t',
#   'just',
#   'don’t',
#   'hope',
#   'think…',
#   'think',
#   'hope',
#   'don’t',
#   'care',
#   'hope',
#   'hope',
#   'hope',
#   'go',
#   'bring',
#   'tried',
#   'don’t',
#   'find',
#   'have',
#   'fuck',
#   'pull',
#   'got',
#   'can’t',
#   'had',
#   'can',
#   'find',
#   'will',
#   'start',
#   'wanna',
#   'believe',
#   'don’t',
#   'don’t',
#   'understand',
#   'get',
#   'said,',
#   'am',
#   'think',
#   'am',
#   'like',
#   'need',
#   'need',
#   'had',
#   'was',
#   'had',
#   'was',
#   'wasn’t',
#   'wasn’t',
#   'keep',
#   'tell',
#   'know',
#   'find',
#   'quote,',
#   'think',
#   'understand',
#   'do',
#   'don’t.',
#   'came',
#   'pay',
#   'want.',
#   'can',
#   'understand',
#   'respect',
#   'don’t',
#   'get',
#   'have',
#   'get',
#   'like',
#   'have',
#   'use',
#   'keep',
#   'have',
#   'agree',
#   'take',
#   'have',
#   'have',
#   'am.”',
#   'think',
#   'think',
#   'hate',
#   'hate',
#   'don’t',
#   'do',
#   'really',
#   'don’t',
#   'don’t',
#   'don’t',
#   'don’t',
#   'can’t',
#   'don’t',
#   'got',
#   'know.',
#   'know',
#   'used',
#   'took',
#   'didn’t',
#   'wanted',
#   'think,',
#   'said,',
#   'said,',
#   'saw',
#   'don’t',
#   'had',
#   'just',
#   'didn’t',
#   'was',
#   'was',
#   'didn’t',
#   'thought',
#   'helped',
#   'come',
#   'said,',
#   'thought…',
#   'shake',
#   'went,',
#   'said,',
#   'just',
#   'rented',
#   'said,',
#   'assume.',
#   'said,',
#   'kicked',
#   'just',
#   'thought,',
#   'read',
#   'hated',
#   'carried',
#   'was,',
#   'go',
#   'get',
#   'got',
#   'literally',
#   'went,',
#   'went,',
#   'went…',
#   'could’ve',
#   'said,',
#   'stand',
#   'hate',
#   'believe',
#   'find',
#   'say,',
#   'think',
#   'enjoy',
#   'don’t',
#   'enjoy…',
#   'know',
#   'know',
#   'still',
#   'enjoy.',
#   'love',
#   'go',
#   'love',
#   'think',
#   'did',
#   'think',
#   'was',
#   'went…',
#   'saw',
#   'went,',
#   'drew',
#   'gave',
#   'did',
#   'could',
#   'stepped',
#   'stepped',
#   'went,',
#   'don’t',
#   'found',
#   'can’t',
#   'think',
#   'think',
#   'am',
#   'tipped',
#   'went,',
#   'think',
#   'just…',
#   'was',
#   'was',
#   'was',
#   'was',
#   'go',
#   'get',
#   'don’t',
#   'went…',
#   'need',
#   'said,',
#   'get',
#   'went…',
#   'put',
#   'get',
#   'don’t',
#   'believe',
#   'will',
#   'know,',
#   'am.”',
#   'would',
#   'know.',
#   'hate',
#   'hate',
#   'tell',
#   'go',
#   'think',
#   'assume',
#   'say',
#   'hate',
#   'have',
#   'was',
#   'just',
#   'like',
#   'leave,',
#   'thank',
#   'said,',
#   'always…',
#   'always',
#   'was',
#   'needed',
#   'was',
#   'don’t',
#   'used',
#   'just',
#   'had',
#   'had',
#   'didn’t',
#   'travel',
#   'try',
#   'like',
#   'might',
#   'try',
#   'go',
#   'go,',
#   'said,',
#   'said,',
#   'bought',
#   'can',
#   'just',
#   'went,',
#   'have',
#   'said,',
#   'said,',
#   'want',
#   'can’t',
#   'can',
#   'thought,',
#   'can',
#   'walk',
#   'get',
#   'hand',
#   'said…',
#   'was',
#   'was',
#   'said,',
#   'go',
#   'see',
#   'put',
#   'went,',
#   'said',
#   'was',
#   'get',
#   'tell',
#   'would',
#   'really',
#   'thought,',
#   'said,',
#   'said,',
#   'reacted',
#   'went,',
#   'went,',
#   'don’t',
#   'get'],
#  'appreciate': ['that.', 'seven', 'the', 'your', 'the'],
#  'that.': ['[Whooping]',
#   'And',
#   'It’s',
#   'Keep',
#   'If',
#   'Once',
#   'Up',
#   'There',
#   'And',
#   'He’s',
#   'Anyway…',
#   'Like,',
#   'What',
#   'And',
#   'That’s',
#   'Yeah,'],
#  '[Whooping]': ['Uh,', 'So,'],
#  'Uh,': ['that’s', 'all', 'well,'],
#  'that’s': ['very',
#   'a',
#   'disgusting.',
#   'what',
#   'good.”',
#   'great.',
#   'what',
#   'pissing',
#   'called',
#   'not',
#   'the',
#   'it.',
#   'why',
#   'a',
#   'when',
#   'got',
#   'our'],
#  'very': ['sweet',
#   'happy',
#   'sweet,',
#   'inviting.',
#   'hygienic.',
#   'occasionally,',
#   'nice',
#   'important',
#   'important.',
#   'proud',
#   'good,',
#   'good',
#   'good.”',
#   'good.”',
#   'politely,',
#   'much',
#   'angry,',
#   'much.'],
#  'sweet': ['of'],
#  'of': ['you.',
#   'the',
#   'home',
#   'your',
#   'things',
#   'us',
#   'my',
#   'my',
#   'us',
#   'coke.',
#   'us',
#   'the',
#   'us',
#   'us',
#   'the',
#   'this',
#   'remorse',
#   'money.',
#   'what',
#   'course,',
#   'things',
#   'stuff,',
#   'bringing',
#   'the',
#   'the',
#   'crying.',
#   'society.',
#   'her',
#   'my',
#   'the',
#   'any',
#   'the',
#   'Hank',
#   'age,',
#   'age,',
#   'fucking',
#   'fathers',
#   'cocks',
#   'a',
#   'them',
#   'my',
#   'all',
#   'women',
#   'them',
#   'time',
#   'splits',
#   'the',
#   'you',
#   'these',
#   'you',
#   'you',
#   'you',
#   'you',
#   'you',
#   'yourself',
#   'your',
#   'your',
#   'this',
#   'the',
#   'chalk',
#   'wiggle',
#   'Duty,',
#   'you',
#   'you',
#   'the',
#   'those',
#   'phased',
#   'you',
#   'reasons.',
#   'you',
#   'you',
#   'you',
#   'us.',
#   'a',
#   'the',
#   'does.',
#   'cunts,',
#   'a',
#   'sense',
#   'time',
#   'money,',
#   'your',
#   'a',
#   'it.',
#   'really',
#   'the',
#   'the',
#   'the',
#   'AIDS”',
#   'America',
#   'all',
#   'them.',
#   'them',
#   'them',
#   'them',
#   'people',
#   'the',
#   'the',
#   'your',
#   'stairs.',
#   'here.”',
#   'all',
#   'fucking',
#   'stairs',
#   'those',
#   'the',
#   'stuff.',
#   'it.',
#   'some',
#   'our',
#   'the',
#   'course',
#   'the',
#   'Australia,',
#   'these',
#   'anyone’s',
#   'sense.',
#   'disabled',
#   'rumors',
#   'the',
#   'you',
#   'the',
#   'the',
#   'the',
#   'a',
#   'a',
#   'shit…',
#   'the',
#   'fucking',
#   'Americans,',
#   'them.',
#   'any',
#   'the',
#   'us',
#   'Braveheart,',
#   'my',
#   'a'],
#  'you.': ['[Man]',
#   'Thank',
#   'Life',
#   'See,',
#   'I',
#   'If',
#   '[Men',
#   'Ah…',
#   'I',
#   'Go'],
#  '[Man]': ['Love', 'Love'],
#  'Love': ['you!', 'you!'],
#  'you!': ['I’m', 'Don’t', 'Don’t', 'Who', 'I’m', '[Grunting]', 'All'],
#  'I’m': ['at',
#   'very',
#   'awesome',
#   'not',
#   'not',
#   'really',
#   'sorry.',
#   'not',
#   'not',
#   'sure',
#   'not',
#   'saying',
#   'sure',
#   'not',
#   'right-handed.',
#   'thinking,',
#   'thinking',
#   'bigging-up',
#   'not',
#   'sure.',
#   'having',
#   'sure',
#   'not',
#   'a',
#   'thinking',
#   'glad',
#   'not',
#   'saying',
#   'yet',
#   'gonna',
#   'not',
#   'saying',
#   'gonna',
#   'like,',
#   'a',
#   'gonna',
#   'sure',
#   'doing',
#   'making',
#   'foreign…',
#   'leaving',
#   'like,',
#   'a',
#   'trained',
#   'responsible,',
#   'in',
#   'doing,',
#   'in',
#   'gonna',
#   'all',
#   'not',
#   'not',
#   'very',
#   'sitting',
#   'not',
#   'sitting',
#   'gonna',
#   'holding',
#   'gonna',
#   'looking',
#   'all',
#   'not',
#   'excited,',
#   'like,',
#   'going',
#   'the',
#   'there',
#   'in',
#   'happy',
#   'so',
#   'holding',
#   'like,',
#   'so',
#   'already',
#   'walking,',
#   'American,',
#   'not',
#   'going',
#   'punching',
#   'trying',
#   'Oscar',
#   'leaving',
#   'going',
#   'in',
#   'wearing',
#   'wearing',
#   'so',
#   'walking',
#   'sitting',
#   'eating',
#   'just',
#   'not',
#   'an'],
#  'at': ['the',
#   'telling',
#   'telling',
#   'Madonna’s',
#   'the',
#   'this',
#   'first,',
#   'the',
#   'the',
#   'it',
#   'the',
#   'times,',
#   'parties',
#   'her,',
#   'my',
#   'my',
#   'the',
#   'the',
#   'all',
#   'every',
#   'Call',
#   'home…',
#   'me',
#   '30,',
#   'Colorado',
#   'Sandy',
#   'the',
#   'all',
#   'that',
#   'first,',
#   'the',
#   'it,',
#   'him',
#   'the',
#   'her,',
#   'that.',
#   'least'],
#  'end': ['of', 'of', 'of', 'of'],
#  'tour': ['right', 'because', 'of', 'in'],
#  'right': ['now.',
#   'now.”',
#   'away',
#   'as',
#   'now,',
#   'to',
#   'in',
#   'from',
#   '’cause',
#   'there.'],
#  'now.': ['I’m'],
#  'happy': ['to', 'Then', 'to'],
#  'be': ['on',
#   'a',
#   'a',
#   'me',
#   'finishing',
#   'jokes',
#   'a',
#   'nice',
#   'walking',
#   'having',
#   'so',
#   'all',
#   'a',
#   'good',
#   'cleaning',
#   'laughing',
#   'able',
#   'ready',
#   'getting',
#   'hard',
#   'shaking,',
#   'crying',
#   'a',
#   'taken',
#   'taken',
#   'allowed',
#   'allowed',
#   'allowed',
#   'delivered',
#   'a',
#   'carrying',
#   'like…',
#   'honest',
#   'the',
#   'like…',
#   'to',
#   'illegal.',
#   'a',
#   'a',
#   'a',
#   'doing',
#   'with',
#   'worse',
#   'a',
#   'a',
#   'working',
#   'invited',
#   'like,',
#   'the'],
#  'on': ['tour',
#   'the',
#   'this.',
#   'this',
#   'drugs,',
#   'April',
#   'Valentine’s',
#   'them',
#   'porn,',
#   'the',
#   'its',
#   'my',
#   'my',
#   'my',
#   'his',
#   'work',
#   'work',
#   'the',
#   'the…',
#   'Earth.',
#   'Earth,',
#   'yourself,',
#   'a',
#   'this',
#   'the',
#   'or',
#   'or',
#   'a',
#   'in',
#   'it…',
#   'that',
#   'Netflix.',
#   'this',
#   'their',
#   'there,',
#   'that',
#   'his',
#   'me.',
#   'a',
#   'a',
#   'her',
#   'her',
#   'their',
#   'their',
#   'Earth.',
#   'the',
#   'him…',
#   'mats',
#   'your',
#   'Valentine’s',
#   'Earth…',
#   'what',
#   'that',
#   'her',
#   'Valentine’s',
#   'the',
#   'them,',
#   'Earth',
#   'other',
#   'it',
#   'it.”'],
#  'because': ['I',
#   'he’s',
#   'they’re',
#   'the',
#   'you',
#   'that',
#   'Jonathan',
#   'that',
#   'it’s',
#   'his'],
#  'now': ['have', 'and', 'I', 'and', 'that', 'and', 'be'],
#  'have': ['a',
#   'big',
#   'in',
#   'partied',
#   'to',
#   'extra',
#   'to',
#   'wanted',
#   'Father’s',
#   'something.”',
#   'one',
#   'to.',
#   'a',
#   'a',
#   'children,',
#   'shit',
#   'shit',
#   'children',
#   'children.',
#   'a',
#   'you?',
#   'a',
#   'to',
#   'a',
#   'a',
#   'taught',
#   'guns.',
#   'guns.',
#   'guns.',
#   'a',
#   'guns',
#   'a',
#   'it',
#   'it',
#   'it',
#   'happened',
#   'sort',
#   'one',
#   'had…',
#   'prohibition',
#   'this',
#   'with',
#   'my',
#   'my',
#   'to',
#   'to',
#   'to',
#   'my',
#   'guns.”',
#   '$34,000,',
#   'muskets…',
#   'a',
#   'a',
#   'a',
#   'we',
#   'to',
#   'to',
#   'gone,',
#   'two',
#   'been',
#   'feelings,',
#   'thought',
#   'been',
#   'little',
#   'AIDS.',
#   'to',
#   'to',
#   'been',
#   'been',
#   'to',
#   'done',
#   'downgraded…”',
#   'no',
#   'the',
#   'you',
#   'a'],
#  'a': ['child.',
#   'nice',
#   'way,',
#   'problem',
#   'problem',
#   'little',
#   'model',
#   'few',
#   'lot',
#   'big',
#   '7’2″',
#   'party.”',
#   'struggling',
#   'one-bedroom',
#   'coffee',
#   'plan.',
#   'model.',
#   'little',
#   'key,',
#   'man,',
#   'lot',
#   'lot',
#   'terrible',
#   'hot',
#   'vastly',
#   'lot',
#   'misogynistic',
#   'job.',
#   'mathematical',
#   'cunt?”',
#   'bad',
#   'new',
#   'cappuccino',
#   'card.',
#   'bastard.',
#   'card.',
#   'fucking',
#   'gift.”',
#   'fucking',
#   'gift.',
#   'bar.',
#   'guy.',
#   'guy',
#   'girl',
#   'huge',
#   'much',
#   'cunt',
#   'much',
#   'big',
#   'favor',
#   'cock',
#   'lot',
#   'good',
#   'pussy',
#   'thing',
#   'favor',
#   'drunken',
#   'big',
#   'good',
#   'father.',
#   'good',
#   'great',
#   'son.',
#   'good',
#   'girl.',
#   'baby',
#   'father',
#   'lot',
#   'cock.',
#   'little',
#   'woman',
#   'baby',
#   'daycare,',
#   'couple',
#   'thing.”',
#   'son',
#   'daughter.',
#   'wiping',
#   'baby’s',
#   'boy,',
#   'girl,',
#   'shit.',
#   'similar',
#   'woman',
#   'child,',
#   'baby',
#   'coke',
#   'coke',
#   'kid.”',
#   'bit',
#   'kid',
#   'dog,',
#   'Christmas',
#   'barbecue,',
#   'kid',
#   'baby',
#   'black',
#   'child,',
#   'little',
#   'single',
#   'coincidence,',
#   'gun,',
#   'gun',
#   'break-in',
#   'machete',
#   'hammer,',
#   'gun.”',
#   'shit',
#   'Facebook',
#   'secure',
#   'lot',
#   'toy,',
#   'responsible',
#   'safe.”',
#   'bit',
#   'gun',
#   'lot',
#   'fucking',
#   'comedy',
#   'little',
#   'couple',
#   'loop',
#   'circle,',
#   'fucking',
#   'problem,',
#   'thesaurus',
#   'constitution.',
#   'thesaurus',
#   'dictionary',
#   'responsible',
#   'safe!”',
#   'responsible',
#   'fucking',
#   'family.',
#   'good',
#   'mental',
#   'white',
#   'criminal.',
#   'great',
#   'lot',
#   'gun?”',
#   'militia',
#   'tyrannical',
#   'bunch',
#   'hell',
#   'lot',
#   'drone',
#   'musket',
#   'lot',
#   'bad',
#   'big',
#   'no…',
#   'man',
#   'strip',
#   'guy,',
#   'fireman.”',
#   'stripper',
#   'tool',
#   'holster,',
#   'man’s',
#   'woman',
#   'job.',
#   'job,',
#   'hand',
#   'private',
#   'woman',
#   'back',
#   'friend',
#   'brothel,',
#   'true',
#   'character',
#   'person',
#   'day',
#   'list.',
#   'lot',
#   'pretzel.',
#   'little',
#   'thing.',
#   'paraplegic',
#   'hooker',
#   'good',
#   'wheelchair.”',
#   'wheelchair.',
#   'fucking',
#   'wheelchair!',
#   'nurse!”',
#   'fucking',
#   'method',
#   'therapist…',
#   'therapist',
#   'word',
#   'girl’s',
#   'good',
#   'girl’s',
#   'horrible',
#   'girl’s',
#   'bit',
#   'bit',
#   'caveman',
#   'cavewoman,',
#   'load',
#   'parade',
#   'load',
#   'lie.',
#   'good',
#   'towel.',
#   'towel.',
#   'towel.',
#   'wonderful',
#   'little',
#   'little',
#   'voice',
#   'child',
#   'moment',
#   'tour',
#   'conveyor',
#   'fucking',
#   'terrorist.”',
#   'nice',
#   'bomb.”',
#   'legless',
#   'lesson',
#   'lot',
#   'South',
#   'South',
#   'South',
#   'black',
#   'rugby',
#   'rugby',
#   'whole',
#   'three-quarter',
#   'man.',
#   'man,',
#   'man,',
#   'legless',
#   'wonderful',
#   'Terminator',
#   'joke,',
#   'high-pitched',
#   '26-hour',
#   'trip.',
#   'business',
#   'fuck.',
#   'business',
#   'bag',
#   'white',
#   'hole',
#   'swear',
#   'white',
#   'business',
#   'business',
#   'new',
#   'beverage.',
#   'business',
#   'group',
#   'chair',
#   'scene',
#   'guy',
#   'little',
#   'strongly-worded',
#   'big',
#   'cunt',
#   'fucking',
#   'second',
#   'bit',
#   'day',
#   'fight',
#   'fighter.',
#   'drink.'],
#  'child.': ['Ah,'],
#  'Ah,': ['so…', 'you’re'],
#  'so…': ['any', 'And', 'Boing!'],
#  'any': ['time', 'man,', 'other', 'foreign', 'American'],
#  'time': ['out', '♪', 'that', 'to', 'We', 'to', 'to'],
#  'out': ['of',
#   'while',
#   'with',
#   'Madonna’s',
#   'two',
#   'the',
#   'the',
#   'some',
#   'of',
#   'good',
#   'at',
#   'that',
#   'for',
#   'a',
#   'of',
#   'that',
#   'with',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'at',
#   'of',
#   'of',
#   'and',
#   'of',
#   'of',
#   'like',
#   'of',
#   'there.',
#   'of',
#   'of',
#   'shit',
#   'there?',
#   'of',
#   'amongst'],
#  'home': ['is', 'from', 'security.', 'security'],
#  'is': ['good',
#   'in',
#   'not',
#   'how',
#   'at',
#   'the',
#   'the',
#   'something',
#   'they',
#   'just',
#   'coming!”',
#   'a',
#   'to',
#   'bullshit.',
#   'this?',
#   'I’m',
#   'a',
#   'because…',
#   'gay',
#   'of',
#   'my',
#   'a',
#   'how',
#   'to',
#   'the',
#   'not',
#   'they',
#   'they',
#   'this',
#   'biting',
#   'that',
#   'this',
#   'my',
#   'bullshit',
#   'one',
#   'the',
#   'more',
#   'a',
#   'the',
#   'on',
#   'very',
#   'important',
#   'set',
#   'open',
#   'a',
#   'on',
#   'being',
#   'based',
#   'a',
#   'the',
#   'people',
#   'all',
#   'how',
#   'an',
#   'a',
#   'what',
#   'what',
#   'what',
#   'the',
#   'what',
#   'illegal.',
#   'that',
#   'the',
#   'a',
#   'that',
#   'more',
#   'South',
#   'this?',
#   'a',
#   'the',
#   'going',
#   'full.',
#   'full.',
#   'wrong',
#   'wrong?”',
#   'for',
#   'great!'],
#  'good': ['for',
#   'nights',
#   'a',
#   '’cause',
#   'time',
#   'question.',
#   'little',
#   'for',
#   'father',
#   'for',
#   'points.',
#   'to',
#   'about',
#   'television,',
#   '’cause',
#   'enough',
#   'answer.',
#   'chance',
#   'at',
#   'in'],
#  'for': ['me.',
#   'two',
#   'the',
#   'the',
#   'my',
#   'women.',
#   'women.',
#   'romantics.',
#   'couples',
#   'women.',
#   'Mother’s',
#   'Father’s',
#   '24',
#   '20',
#   'men',
#   'fathers',
#   'life,',
#   'every',
#   '“ass',
#   'five',
#   'me.',
#   'me.',
#   'my',
#   'seven-and-a-half',
#   'a',
#   'like,',
#   'your',
#   'is',
#   'having',
#   'protection.',
#   'cunts',
#   'you.”',
#   'a',
#   'the',
#   'everyone.”',
#   'sure',
#   'it!',
#   'Netflix.',
#   'casting.',
#   'two',
#   'the',
#   'coming',
#   'the',
#   'renting',
#   'a',
#   'thinking',
#   'this',
#   'fuck’s',
#   'too',
#   'coming.',
#   'you?',
#   'business',
#   'a'],
#  'me.': ['Um,',
#   'He’s',
#   'I',
#   'Nothing',
#   'Women',
#   'I',
#   'I',
#   'Don’t',
#   'I…',
#   '“This',
#   'My',
#   'I'],
#  'Um,': ['I'],
#  'got': ['my',
#   'no',
#   'my',
#   'it,',
#   'it',
#   'shit',
#   'shit',
#   'pregnant…',
#   'a',
#   'pregnant,',
#   'Kevin.',
#   'that',
#   'drunk',
#   '$34,000.',
#   'the',
#   'to',
#   'canceled.',
#   'left?”',
#   'me!',
#   'the',
#   'parts,',
#   'a',
#   'a',
#   'brown',
#   'there?'],
#  'my': ['girlfriend',
#   'girlfriend',
#   'son',
#   'girlfriend',
#   'child!',
#   'life.”',
#   'career,',
#   'life.',
#   'God.',
#   'God.',
#   'drinks.',
#   'own',
#   'house',
#   'son',
#   'left',
#   'girlfriend',
#   'fucking',
#   'money',
#   'fucking',
#   'shows',
#   'ass.”',
#   'ass.',
#   'ass.',
#   'ass.”',
#   'own',
#   'ass.',
#   'ass.”',
#   'ex-girlfriend',
#   'guy',
#   'ass?”',
#   'son!',
#   'son',
#   'house,',
#   'head',
#   'son.',
#   'son',
#   'dream',
#   'son!',
#   'son.',
#   'boyfriend’s',
#   'boyfriend.',
#   'boyfriend.”',
#   'mates',
#   'girlfriend.',
#   'age',
#   'dick.',
#   'girlfriend',
#   'dick,',
#   'dick.”',
#   'girlfriend',
#   'life.',
#   'girlfriend',
#   'girlfriend,',
#   'actual',
#   'shows,',
#   'personal',
#   'guns!”',
#   'family.”',
#   'head',
#   'girlfriend.',
#   'holster.',
#   'house',
#   'guns',
#   'answer',
#   'taxes.',
#   'face',
#   'slaves!”',
#   'slaves',
#   'slaves',
#   'rights',
#   'slaves',
#   'family!',
#   'slaves',
#   'guns',
#   'guns',
#   'genitals…',
#   'forehead.',
#   'life.',
#   'assistance.',
#   'therapist',
#   'answer,',
#   'face,',
#   'son',
#   'daddy.',
#   'cock',
#   'cock,',
#   'ID',
#   'shoes',
#   'laptop',
#   'accent',
#   'accent,',
#   'gun',
#   'spirits.”',
#   'presence.',
#   'ticket.',
#   'ticket',
#   'little',
#   'peanuts.',
#   'impersonation',
#   'head',
#   'gears,',
#   'brain'],
#  'girlfriend': ['pregnant',
#   'is,',
#   'just',
#   'used',
#   'went,',
#   'or',
#   'super',
#   'goes',
#   'gives',
#   'in',
#   'got',
#   'got',
#   'has',
#   'goes'],
#  'pregnant': ['after'],
#  'after': ['knowing', 'my', 'being', 'that,', 'you', 'the', 'the', 'this'],
#  'knowing': ['her'],
#  'her': ['for',
#   'in',
#   'friends',
#   'a',
#   'to',
#   'ass,',
#   'pussy,',
#   'a',
#   'anus,',
#   'mouth,',
#   'mouth',
#   'on',
#   'here.',
#   'here.',
#   'cunt',
#   'and',
#   'cry.”',
#   'hands',
#   '1967',
#   'fucking',
#   'cunt',
#   'friend',
#   'knees',
#   'face',
#   'phone…',
#   'phone,',
#   'phone,',
#   'hair.',
#   'through'],
#  'two': ['months.',
#   'grams',
#   'weeks',
#   'of',
#   'months,',
#   'vastly',
#   'great',
#   'hours',
#   'bombs.”',
#   'Olympics,'],
#  'months.': ['So…'],
#  'So…': ['[Audience', 'I’m', 'Because', 'Also…', 'she’s', 'I', 'I’m'],
#  'Life': ['decisions.'],
#  'decisions.': ['And'],
#  'And': ['she’s',
#   'I',
#   'I',
#   'she',
#   'she',
#   'she',
#   'she',
#   'then',
#   'she',
#   'she',
#   'she',
#   'she',
#   'I',
#   'this',
#   'then',
#   'you',
#   'I',
#   'it’s',
#   'you',
#   'they’ll',
#   'that’s',
#   'of',
#   'don’t',
#   'she',
#   'I',
#   'so,',
#   'I',
#   'then',
#   'I',
#   'she',
#   'she',
#   'I',
#   'they',
#   'do',
#   'it’s',
#   'it’s',
#   'the',
#   'then',
#   'the',
#   'then',
#   'they',
#   'then',
#   'it’s',
#   'there’s',
#   'it’s',
#   'she',
#   'then',
#   'he’ll',
#   'then',
#   'you',
#   'then',
#   'what',
#   'then',
#   'they’re',
#   'you',
#   'then,',
#   'they’re',
#   'they',
#   'we',
#   '50%',
#   'there’s',
#   'people',
#   'then,',
#   'I’m',
#   'then',
#   'then',
#   'you’ve',
#   'then',
#   'then…',
#   'they’re',
#   'for',
#   'my',
#   'don’t',
#   'I’m',
#   'if',
#   'then',
#   'then',
#   '50%',
#   'the',
#   'that',
#   'he',
#   'whenever',
#   'when',
#   'she',
#   'so,',
#   'I',
#   'they',
#   'on',
#   'what',
#   'none',
#   'then',
#   'he',
#   'I',
#   'he',
#   'I',
#   'he',
#   'I',
#   'he',
#   'I',
#   'I',
#   'later',
#   'I’m',
#   'I',
#   'then',
#   'we',
#   'she',
#   'then',
#   'then',
#   'I',
#   'I’ve',
#   'as',
#   'you',
#   'I’m',
#   'I',
#   'I',
#   'then',
#   'he',
#   'I',
#   'I’m',
#   'I’m',
#   'she',
#   'I',
#   'she',
#   'I',
#   'she',
#   'all',
#   'the',
#   'I',
#   'he',
#   'the',
#   'then',
#   'she’s',
#   'then',
#   'when',
#   'I',
#   'she',
#   'then',
#   'she',
#   'I',
#   'I',
#   'he',
#   'the',
#   'I',
#   'I',
#   'as',
#   'I',
#   'they',
#   'the',
#   'I’m',
#   'in',
#   'whenever',
#   'this',
#   'I',
#   'as',
#   'the',
#   'all',
#   'a',
#   'he',
#   'then',
#   'I',
#   'he',
#   'as',
#   'Neil',
#   'then,',
#   'I',
#   'Neil',
#   'then'],
#  'she’s': ['a',
#   'very',
#   'shit',
#   'like,',
#   'like…',
#   'enjoying',
#   'been',
#   'thought,',
#   'coming',
#   'like,'],
#  'nice': ['girl,', 'to', 'ladies,', 'computer.', '’cause'],
#  'girl,': ['and', 'and', 'you'],
#  'love': ['her',
#   'a',
#   'the',
#   'my',
#   'my',
#   'cigarettes.',
#   'you',
#   'the',
#   'you.',
#   'my'],
#  'in': ['a',
#   'the',
#   'the',
#   'the',
#   'a',
#   'Miami,',
#   'proportion…',
#   'the',
#   'my',
#   'no',
#   'a',
#   'my',
#   'Vegas.',
#   'Vegas,',
#   'the',
#   'the',
#   'like,',
#   'the',
#   'the',
#   'the',
#   'the',
#   'this',
#   'society',
#   'the',
#   'his',
#   'my',
#   'the',
#   'school',
#   'the',
#   'the',
#   'the',
#   'a',
#   'the',
#   'her',
#   'her',
#   'my',
#   'porn.',
#   'my',
#   'my',
#   'my',
#   'her',
#   'her',
#   'the',
#   'my',
#   'the',
#   'my',
#   'the',
#   'your',
#   'the',
#   'their',
#   'and',
#   'their',
#   'the',
#   'the',
#   'her',
#   'the',
#   'your',
#   'the',
#   '1996,',
#   'America,',
#   'your',
#   'your',
#   'Manchester,',
#   'where',
#   'your',
#   'my',
#   'a',
#   'here,’',
#   'front',
#   'America',
#   'this',
#   'this',
#   'a',
#   'Australia.',
#   'my',
#   'car',
#   'stone.',
#   'there,',
#   'America',
#   'how',
#   'a',
#   'Boston',
#   'a',
#   'front',
#   'Australia,',
#   'Britain,',
#   'Sandy',
#   'Walmart.',
#   'Australia',
#   'there,',
#   'these',
#   'those',
#   'front.',
#   'your',
#   'female',
#   'Hollywood,',
#   'my',
#   'by',
#   'for',
#   'the',
#   'the',
#   'it',
#   'his',
#   'camera',
#   'your',
#   'the',
#   'Darwin',
#   'his',
#   'this',
#   'the',
#   'the',
#   'the',
#   'the',
#   'America',
#   'Australia,',
#   'two',
#   'one',
#   'her',
#   'South',
#   'trouble,',
#   'the',
#   'South',
#   'four',
#   'the',
#   'that',
#   'prison,',
#   'the',
#   'the',
#   'that',
#   'that',
#   'South',
#   'South',
#   'South',
#   'South',
#   'case',
#   'business',
#   'the',
#   'any',
#   'walks',
#   'a',
#   'the',
#   'seconds.',
#   'the',
#   'the',
#   'such',
#   'Neil',
#   'business'],
#  'way,': ['sure.', 'partied', 'most'],
#  'sure.': ['My', 'And'],
#  'My': ['problem',
#   'girlfriend',
#   'girlfriend’s',
#   'experience',
#   'girlfriend',
#   'girlfriend',
#   'boyfriend',
#   'boyfriend',
#   'girlfriend',
#   'son',
#   'heart',
#   'opinion',
#   'girlfriend',
#   'son',
#   'girlfriend'],
#  'problem': ['with', 'in', 'now', 'is'],
#  'with': ['my',
#   'Madonna.”',
#   'Madonna.”',
#   'Madonna.',
#   'Madonna,',
#   'a',
#   'your',
#   'a',
#   'an',
#   'an',
#   'my',
#   'women.',
#   'a',
#   'shit',
#   'children',
#   'my',
#   'racism',
#   'a',
#   'different',
#   'it.',
#   'saying,',
#   'a',
#   'machetes',
#   'a',
#   'me,',
#   'me,',
#   'me.',
#   'me,',
#   'guns.',
#   'you.',
#   'them,',
#   'with',
#   'the',
#   'him',
#   'his',
#   'muscular',
#   'muscular',
#   'muscular',
#   'muscular',
#   'you,',
#   'your',
#   'their',
#   'all',
#   'the',
#   'my',
#   'remorse.',
#   'my',
#   'things',
#   'too',
#   'a',
#   'a',
#   'just',
#   'the',
#   'customer',
#   'you',
#   'my',
#   'him.'],
#  'is,': ['she’s',
#   '“That’s',
#   'like,',
#   'you',
#   'kids.',
#   'when',
#   '[In',
#   '“No.”',
#   'get',
#   '“I',
#   '“Well,',
#   'pushes',
#   'right?',
#   'when',
#   'let',
#   'like,'],
#  'sweet,': ['but'],
#  'but': ['she’s',
#   'it’s',
#   'I',
#   'I’ve',
#   'the',
#   'then',
#   'this',
#   'didn’t',
#   'I’m',
#   'she',
#   'this',
#   'it’s',
#   'people',
#   'it',
#   'please',
#   'everything’s',
#   'we',
#   'there',
#   'that',
#   'you',
#   'basically,',
#   'we',
#   'once',
#   'he',
#   'I',
#   'I',
#   'extraordinarily',
#   'it',
#   'in',
#   'I’m',
#   'Oscar’s',
#   'whatever.',
#   'not',
#   'what',
#   'you',
#   'this',
#   'you',
#   'I’m',
#   'three'],
#  'shit': ['at',
#   'in',
#   'all',
#   'on',
#   'on',
#   'on',
#   'on',
#   'in',
#   'about',
#   'for',
#   'you'],
#  'telling': ['stories,', 'stories,', 'me', 'you', 'everyone.', 'me'],
#  'stories,': ['and', 'so'],
#  'awesome': ['at', 'moment,'],
#  'so': ['it',
#   'fucked',
#   'hard',
#   'hard',
#   'much?',
#   'that',
#   'fluently',
#   'happy.',
#   'much',
#   'fuck',
#   'precious',
#   'that',
#   'I’m',
#   'he',
#   'I',
#   'much',
#   'I',
#   'that',
#   'I',
#   'used',
#   'good',
#   'calm',
#   'I',
#   'sorry,',
#   '♪'],
#  'it': ['really',
#   'getting',
#   'would',
#   'a',
#   'off',
#   'goes',
#   'says,',
#   'and',
#   'be',
#   'in',
#   'in',
#   'in',
#   'on',
#   'seems',
#   'so',
#   'until',
#   'in',
#   'in',
#   'in',
#   'all',
#   'directly',
#   'is.',
#   'is',
#   'turns',
#   'off',
#   'funny',
#   'is',
#   'soothing.',
#   'as',
#   'says,',
#   'off',
#   'is',
#   'doesn’t',
#   'was',
#   'gets',
#   'away',
#   'for',
#   'at',
#   'readily',
#   'becomes',
#   'in',
#   'up,',
#   '32',
#   'might',
#   'off,',
#   'says.',
#   'for',
#   'up',
#   'worked.',
#   'worked,',
#   'in',
#   'covers',
#   'anymore.',
#   'was',
#   'was',
#   'was',
#   'goes.',
#   'to',
#   'would’ve',
#   'there',
#   'look',
#   'out,',
#   'in',
#   'up',
#   'down',
#   'and',
#   'dawned',
#   'might',
#   'so',
#   'illegal',
#   'really',
#   'prints',
#   'to',
#   'does',
#   'may',
#   'would',
#   'was',
#   'with',
#   'full.”',
#   'the'],
#  'really': ['bothers',
#   'partied.',
#   'partied',
#   'party,',
#   'passionate',
#   'like',
#   'is.',
#   'like',
#   'boring',
#   'should.',
#   'agree',
#   'agree',
#   'good',
#   'suit',
#   'wanted',
#   'like…',
#   'funny',
#   'offended,',
#   'grinds',
#   'would.”'],
#  'bothers': ['me'],
#  'me': ['when',
#   'and',
#   'were',
#   'in.',
#   'what',
#   'nothing,',
#   'mate,',
#   'taste',
#   'to',
#   'in',
#   'kisses',
#   'kisses',
#   'and',
#   'girlfriend’s',
#   'kisses.',
#   'kisses.',
#   'mate',
#   'a',
#   'who',
#   'and',
#   'this',
#   'wrong.',
#   'in',
#   'in',
#   'a',
#   'down',
#   'a',
#   'because…',
#   'carry',
#   'if',
#   'your',
#   'assume',
#   'shoes',
#   'fill',
#   'and',
#   'that',
#   'there',
#   'that',
#   'you’ve',
#   'to',
#   'and',
#   'that'],
#  'when': ['she',
#   'he',
#   'my',
#   'they',
#   'your',
#   'he’s',
#   'he',
#   'you',
#   'you',
#   'they',
#   'they’re',
#   'you’re',
#   'he',
#   'I’m',
#   'it',
#   'a',
#   'they',
#   'a',
#   'men',
#   'we',
#   'she',
#   'you',
#   'he',
#   'you’re',
#   'you',
#   'someone,',
#   'I',
#   'I’ve',
#   'you’re'],
#  'she': ['talks.',
#   'went,',
#   'went,',
#   'goes,',
#   'said,',
#   'goes,',
#   'went,',
#   'went,',
#   'goes,',
#   'goes,',
#   'wakes',
#   'went,',
#   'goes,',
#   'goes,',
#   'seems',
#   'thought',
#   'loves',
#   'does',
#   'goes,',
#   'kisses',
#   'goes,',
#   'came',
#   'stabbed',
#   'rubs',
#   'stands',
#   'goes,',
#   'was',
#   'went,',
#   'went,',
#   'went…',
#   'went,',
#   'came',
#   'went,',
#   'went,',
#   'went,',
#   'storms',
#   'went,',
#   'went,',
#   'goes,',
#   'looked',
#   'went,'],
#  'talks.': ['And'],
#  'don’t': ['know',
#   'see',
#   'wanna',
#   'think',
#   'know,',
#   'actually',
#   'work',
#   'do',
#   'deserve',
#   'think',
#   'appreciate',
#   'want',
#   'want',
#   'want',
#   'touch',
#   'touch',
#   'get',
#   'do',
#   'even',
#   'smell',
#   'know,',
#   'want',
#   'know',
#   'know',
#   'know',
#   'get',
#   'want',
#   'care',
#   'know',
#   'give',
#   'have',
#   'love',
#   'like',
#   'know',
#   'give',
#   'know',
#   'they',
#   'agree',
#   'agree',
#   'agree',
#   'like',
#   'like',
#   'know',
#   'get',
#   'know',
#   'fuck',
#   'know',
#   'need',
#   'know',
#   'behave',
#   'know…',
#   'know',
#   'know',
#   'imagine',
#   'know',
#   'wanna',
#   'do.',
#   'think',
#   'know',
#   'know.',
#   'speak',
#   'need',
#   'know!',
#   'know',
#   'know',
#   'think',
#   'know',
#   'like',
#   'have',
#   'know',
#   'you',
#   'worry',
#   'know'],
#  'know': ['if',
#   'what',
#   'there’s',
#   'why',
#   'when',
#   'how',
#   'if',
#   'what',
#   'of',
#   'you',
#   'how',
#   'that,',
#   'if',
#   'these',
#   'how',
#   'that,',
#   'what?',
#   'your',
#   'what',
#   'what',
#   'they’re',
#   'for',
#   'that',
#   'you',
#   'if',
#   'a',
#   'the',
#   'what’s',
#   'that',
#   'if',
#   'what',
#   'if',
#   'it.',
#   'why.',
#   'if',
#   'the',
#   'why,',
#   'it’s',
#   'you’re',
#   'that',
#   'who',
#   'if',
#   'what',
#   'me,',
#   'if',
#   'when',
#   'the',
#   'what',
#   'if'],
#  'if': ['that’ll',
#   'this',
#   'we',
#   'your',
#   'you',
#   'they’re',
#   'my',
#   'you',
#   'I',
#   'your',
#   'your',
#   'you’re',
#   'you',
#   'someone',
#   'you',
#   'you',
#   'you',
#   'the',
#   'you',
#   'you',
#   'you',
#   'you',
#   'women',
#   'there’s',
#   'you’re',
#   'people',
#   'he',
#   'he’s',
#   'it’s',
#   'this',
#   'you’ve',
#   'I',
#   'I’ll',
#   'something',
#   'you'],
#  'that’ll': ['be', 'work'],
#  'future,': ['but'],
#  'it’s': ['a',
#   'an',
#   'gotta',
#   'confusing',
#   'for',
#   'for',
#   'shit!',
#   'good',
#   'good,',
#   'a',
#   'different,',
#   'very',
#   'not',
#   'more',
#   'not',
#   'super',
#   'just',
#   'just',
#   'the',
#   'easier',
#   'not',
#   'all',
#   'a',
#   'too',
#   'not',
#   'just',
#   'just',
#   'all',
#   'dry',
#   'not',
#   'a',
#   'such',
#   'all',
#   'important',
#   'your'],
#  'see': ['it',
#   'a',
#   'a',
#   'each',
#   'how',
#   'a',
#   'her',
#   'how',
#   'how',
#   'a',
#   'everyone',
#   'that.”',
#   'your',
#   'Americans',
#   'that'],
#  'getting': ['better.',
#   'engaged.',
#   'fucking',
#   'married,',
#   'fucked',
#   'fucked',
#   'out',
#   'away',
#   'one',
#   'promoted.'],
#  'better.': ['Um…'],
#  'Um…': ['I’ll', 'So,', 'But', 'I', 'My', 'Keep', 'But'],
#  'I’ll': ['give',
#   'get',
#   'be',
#   'ring',
#   'tell',
#   'say',
#   'be',
#   'tell',
#   'also',
#   'get',
#   'get',
#   'tell',
#   'be',
#   'be',
#   'do'],
#  'give': ['you', 'a', 'me', 'a', 'that', 'up', 'a'],
#  'you': ['an',
#   'in',
#   'used',
#   'hear',
#   'were',
#   'care',
#   'being',
#   'care',
#   'have,',
#   'have.',
#   'really',
#   'go',
#   'can',
#   'to',
#   'can',
#   'party',
#   'have',
#   'go',
#   'can’t',
#   'won’t',
#   'think',
#   'know?',
#   'go,',
#   'want',
#   'don’t',
#   'wanna',
#   'could',
#   'go…',
#   'see',
#   'know,',
#   'know…',
#   'can’t',
#   'come',
#   'want…',
#   'want',
#   'know',
#   'done?',
#   'close',
#   'almost',
#   'know',
#   'in',
#   'fucking',
#   'dream,',
#   'have',
#   'in',
#   'pass',
#   'know…',
#   'go',
#   'can',
#   'hand',
#   'finish',
#   'come',
#   'go',
#   'have',
#   'do',
#   'go',
#   'can',
#   'want,',
#   'gotta',
#   'wipe',
#   'meet…',
#   'haven’t',
#   'meet',
#   'you’re',
#   'what,',
#   'wanna',
#   'go,',
#   'a',
#   'have',
#   'invite',
#   'go,',
#   'control…”',
#   'anymore.',
#   'buy',
#   'have.',
#   'can',
#   'from',
#   'had',
#   'went,',
#   'should',
#   'speak',
#   'talking',
#   'know',
#   'had',
#   'live',
#   'like',
#   'go',
#   'read',
#   'give',
#   'go',
#   'read',
#   'have',
#   'behind',
#   'have?',
#   'think',
#   'think',
#   'have',
#   'what.',
#   'up!',
#   'didn’t',
#   'and',
#   'agree',
#   'don’t',
#   'are',
#   'right',
#   'can’t',
#   'don’t',
#   'don’t',
#   'can.',
#   'can’t',
#   'need',
#   'need',
#   'don’t',
#   'went,',
#   'have',
#   'don’t',
#   'should',
#   'fucking',
#   'know',
#   'exist.',
#   'exist',
#   'take',
#   'can',
#   'have',
#   'don’t',
#   'and',
#   'know',
#   'can’t',
#   'could',
#   'could',
#   'do',
#   'a',
#   'go…',
#   'can',
#   'get',
#   'do',
#   'so',
#   'got',
#   'sat',
#   'wanna',
#   'have',
#   'finish',
#   'what',
#   'don’t',
#   'to',
#   'say',
#   'do…',
#   'deserve',
#   'could',
#   'do.',
#   'a',
#   'what',
#   'go…',
#   'fly',
#   'go',
#   'put',
#   'go.”',
#   'do.”',
#   'from',
#   'taking',
#   'showing',
#   'haven’t',
#   'don’t',
#   'in.',
#   'hot',
#   'want',
#   'fucking',
#   'cunts.',
#   'can’t',
#   'think',
#   'are?”',
#   'left',
#   'fucking',
#   'tell',
#   'very',
#   'cunts,',
#   'know',
#   'came',
#   'have',
#   'fucking',
#   'know',
#   'to',
#   'swear,',
#   'anymore.',
#   'fucking',
#   'want',
#   'what',
#   'back',
#   'people',
#   'fucking',
#   'say',
#   'fucking',
#   'see.',
#   'think',
#   'are?”',
#   'shut',
#   'can',
#   'that.',
#   'in',
#   'just',
#   'have',
#   'got',
#   'very'],
#  'an': ['example,',
#   'NBA',
#   'amazing',
#   'hour',
#   'hour,',
#   'April',
#   'April',
#   'armed',
#   'hour.',
#   'American',
#   "‘amendment.'”",
#   '“amendment”,',
#   'awesome',
#   'excellent',
#   'atheist,',
#   'animal',
#   'American',
#   'inspiration',
#   'inspiration',
#   'Olympian,',
#   'upgrade.',
#   'angry',
#   'excellent'],
#  'example,': ['right?', 'okay?'],
#  'right?': ['I',
#   'I’m',
#   'And',
#   'It’s',
#   'We’re',
#   'I’m',
#   'I’m',
#   'I’ve',
#   'April',
#   'You’re',
#   'But',
#   'And',
#   'She’s',
#   'With',
#   'These',
#   'Then',
#   'I',
#   'I’m',
#   'In',
#   'Right',
#   'Now,',
#   'I',
#   'Now,',
#   'Your',
#   'And',
#   'I’ve',
#   'And',
#   'I',
#   '[Audience',
#   'But',
#   'You',
#   'That',
#   'You',
#   'Because',
#   'I',
#   'And',
#   'I’m',
#   'And',
#   'Now,',
#   'He',
#   'So',
#   'He',
#   'Now,',
#   'They'],
#  'was': ['in',
#   'asleep',
#   'Dennis',
#   'a',
#   'at',
#   'six',
#   'and',
#   'for',
#   'born…',
#   '10',
#   'a',
#   'tied',
#   'naked',
#   'like.',
#   'gonna',
#   'The',
#   'Asperger’s',
#   'written',
#   'so',
#   'written.',
#   'just',
#   'it?”',
#   'the',
#   'like…',
#   'shaped',
#   'being',
#   'mentally',
#   'being',
#   'going,',
#   'funny.',
#   'smart.',
#   'impeccable.',
#   'just',
#   'still',
#   'very',
#   'saying',
#   'never',
#   'never',
#   'in',
#   'a',
#   'flying',
#   'doing',
#   'flying',
#   'flying',
#   'like…',
#   'wearing',
#   'going',
#   'crawling',
#   'enjoying',
#   'a',
#   'in',
#   'all',
#   'doing',
#   'going,',
#   'given,',
#   'like',
#   'doing',
#   'one.',
#   'a'],
#  'car,': ['and'],
#  'son': ['Hank', 'was', 'the', 'is', 'than', 'will', 'will', 'the'],
#  'Hank': ['was', 'would', 'was', 'being', 'fucks', 'fucking', 'up', 'ran'],
#  'asleep': ['in'],
#  'back': ['seat,',
#   'there',
#   'to',
#   'to',
#   'room',
#   'to',
#   'in.',
#   'on.',
#   'from',
#   'up',
#   'a'],
#  'seat,': ['and'],
#  'we’re': ['driving', 'gonna', 'gonna', 'doing', 'in'],
#  'driving': ['along,'],
#  'along,': ['and'],
#  'radio': ['comes'],
#  'comes': ['Madonna,',
#   'into',
#   'into',
#   'onto',
#   'out',
#   'in',
#   'in…',
#   'in,',
#   'out',
#   'in',
#   'out.',
#   'out.',
#   'over.'],
#  'Madonna,': ['and', 'and'],
#  'just': ['slips',
#   'be',
#   'by',
#   'stand',
#   'doing',
#   'for',
#   'for',
#   'for',
#   'by',
#   'watch',
#   'don’t',
#   'fucks',
#   'me.',
#   'loves',
#   'easier',
#   'little',
#   'easier.',
#   'two',
#   'facts,',
#   'want',
#   'add',
#   'funny',
#   'going',
#   'going,',
#   'because',
#   'rock',
#   'muskets.',
#   'look',
#   'go…',
#   'sat',
#   'lazy.',
#   'loved',
#   'great,',
#   'a',
#   'really',
#   'think,',
#   'out',
#   'say',
#   'raped',
#   'soon,',
#   'don’t',
#   'one',
#   'went,',
#   'angry',
#   'pointing',
#   'walking',
#   'called'],
#  'slips': ['into'],
#  'into': ['conversation,',
#   'your',
#   'it',
#   'your',
#   'your',
#   'the',
#   'school,',
#   'character'],
#  'conversation,': ['“Oh,'],
#  '“Oh,': ['I',
#   'okay,',
#   'you’re',
#   'oh.',
#   'my',
#   'my',
#   'I',
#   'Valentine’s',
#   'I',
#   'the',
#   'me',
#   'I',
#   'I',
#   'okay,',
#   'we’re',
#   'well,',
#   'thanks,',
#   'you',
#   'jeez,',
#   'I',
#   'for',
#   'come',
#   'you’re',
#   'Mr.',
#   'this',
#   'we’re'],
#  'used': ['to',
#   'to',
#   'to',
#   'to',
#   'to',
#   'to',
#   'to',
#   'to',
#   'to',
#   'to',
#   'to…',
#   'to',
#   'to',
#   'to',
#   'to',
#   'DJ',
#   'to',
#   'to'],
#  'party': ['with', 'with', 'with', 'in', 'that', 'around'],
#  'Madonna.”': ['And', 'Now,'],
#  'went,': ['“You',
#   '“I',
#   '“No,',
#   '“Shut',
#   '“What?”',
#   '“We',
#   '“That',
#   '“Oh,',
#   '“Probably',
#   '“H-A-N…”',
#   '“What',
#   '“I',
#   '“It’s',
#   '“Fuck',
#   '“That’s',
#   '“Yeah,',
#   '“Maybe…',
#   '“Fuck',
#   '“That’s',
#   '“Fuck',
#   '“Whoa!',
#   '“Red,”',
#   '“Blue.”',
#   '“Cooking,”',
#   '“Food,”',
#   '“And',
#   '“When',
#   '“Hello,',
#   '“G’day,',
#   '“Oh,',
#   '“Put',
#   '“I',
#   '“Would',
#   '“I’m',
#   '“Are',
#   '“Are',
#   '“Please',
#   '“Next.”',
#   '“Yes.”',
#   '[In',
#   '“You',
#   '“Fucking',
#   '[In',
#   '“Neil',
#   '[In',
#   '“Neil!',
#   '“Oh!'],
#  '“You': ['fucking',
#   'need',
#   'cannot',
#   'can’t',
#   'cannot',
#   'did',
#   'fucking',
#   'fucking',
#   'want',
#   'what',
#   'can',
#   'can'],
#  'fucking': ['what,',
#   'each',
#   'nothing.',
#   'moron.',
#   'shit,',
#   'money.',
#   'money?',
#   'ceramic',
#   'years,',
#   'girls',
#   'her,',
#   'ass,',
#   'you',
#   'hate',
#   'killing',
#   'creepy.',
#   'pussy',
#   'loves',
#   'adorable.',
#   'hate',
#   'years!',
#   'dog’s',
#   'baby.',
#   'dog',
#   '“protection',
#   'ready?',
#   'times.',
#   'TV!',
#   'enemies',
#   'day,',
#   'protection!',
#   'mother’s',
#   'murdered,',
#   'hero!',
#   'cut',
#   'furious.',
#   'seething.',
#   'turn',
#   'immigrant',
#   'moving,',
#   'champion,',
#   'drugs,',
#   'kids.',
#   'idiot!”',
#   'what',
#   'asshole,',
#   'psychosis',
#   'nurse?',
#   'slut…',
#   'simpleton.',
#   'shit.',
#   'missing',
#   'long.',
#   'want.',
#   'bitch!',
#   'rape',
#   'want?”',
#   'kidding',
#   'kidding',
#   'cunts.”',
#   'cunt.”',
#   'shit.',
#   'come',
#   'superhero…'],
#  'what,': ['when?”', 'it’s'],
#  'when?”': ['And'],
#  '“I': ['used',
#   'used',
#   'know',
#   'don’t',
#   'heart',
#   'love',
#   'like',
#   'need',
#   'think,',
#   'hate',
#   'love',
#   'think',
#   'don’t…',
#   'might',
#   'don’t',
#   'understand',
#   'bought',
#   'bought',
#   'want'],
#  'Now,': ['I',
#   'although',
#   'I',
#   'there’s',
#   'before',
#   'after',
#   'in',
#   'please',
#   'in',
#   'as',
#   'I’m',
#   'I',
#   'I’m',
#   'obviously,',
#   'I',
#   'is',
#   'there’s',
#   'I',
#   'can',
#   'I',
#   'you',
#   'you'],
#  'should': ['fill', 'be', 'I', 'be', 'I', 'be', 'all', 'be', 'I', 'be'],
#  'fill': ['you', 'you'],
#  'little': ['bit',
#   'room.',
#   'things',
#   'boy.',
#   'fella.',
#   'daycare',
#   'things.',
#   'bit.',
#   'bit.',
#   'saver.',
#   'bit',
#   'face',
#   'bowtie',
#   'suit…',
#   'tiny',
#   'speech,',
#   'insincere.'],
#  'bit': ['on',
#   'of',
#   'of',
#   'longer,',
#   'of',
#   'patronizing.',
#   'where',
#   'in',
#   'of'],
#  'this.': ['My', 'You', 'You'],
#  'model': ['in', 'years.'],
#  'Miami,': ['right?'],
#  'not': ['bragging.',
#   'true.',
#   'famous,',
#   'deserve',
#   'being',
#   'saying',
#   'saying',
#   'a',
#   'even',
#   'what',
#   'what',
#   'a',
#   'just',
#   'gonna',
#   'gonna',
#   'that',
#   'me',
#   'ready.',
#   'put',
#   'saying',
#   'trying',
#   'for',
#   'the',
#   'fucking',
#   'to',
#   'how',
#   'crazy?',
#   'a',
#   'allowed',
#   'allowed',
#   'that',
#   'disabled.”',
#   'disabled.',
#   'disabled',
#   'proud',
#   'fun.',
#   'excited,',
#   'even',
#   'a',
#   'in',
#   '“over.”',
#   'speak',
#   'like',
#   'much'],
#  'bragging.': ['I'],
#  'didn’t': ['get',
#   'get',
#   'cost',
#   'take',
#   'leave',
#   'want',
#   'know',
#   'have',
#   'really',
#   'give'],
#  'get': ['the',
#   'those',
#   'wasted',
#   'for',
#   'the',
#   'a',
#   'involved,',
#   'paid.',
#   'paid.',
#   'along',
#   'him.',
#   'a',
#   'a',
#   'Hans.',
#   'excited',
#   'it.',
#   'rid',
#   'sad',
#   'back',
#   'so',
#   'me',
#   'that',
#   'it,',
#   'a',
#   'that',
#   'that',
#   'your',
#   'that?',
#   'private',
#   'too',
#   'rid',
#   'themselves',
#   'depressed.',
#   'a',
#   'a',
#   'you',
#   'angry',
#   'through',
#   'up',
#   'my',
#   'going',
#   'an',
#   'really',
#   'up',
#   'it.',
#   'down.'],
#  'years.': ['I', 'I’ve'],
#  'those': ['years.', 'same', 'people', 'rooms,', 'moments'],
#  'I’ve': ['seen',
#   'gotten',
#   'never',
#   'had',
#   'really',
#   'got',
#   'never',
#   'had',
#   'got',
#   'ever',
#   'had',
#   'never',
#   'never',
#   'had',
#   'done',
#   'had',
#   'been',
#   'become',
#   'ever',
#   'been',
#   'never',
#   'never',
#   'already',
#   'been',
#   'been'],
#  'seen': ['the', 'it.', 'a', 'in'],
#  'photos.': ['Very'],
#  'Very': ['impressive.', 'important.', 'hard…'],
#  'impressive.': ['Um…'],
#  'So,': ['I', 'here’s', 'anyway,'],
#  'said,': ['“So',
#   '“I',
#   '“I',
#   '“You’re',
#   '“Honestly,',
#   'I',
#   'and',
#   '“You',
#   '“All',
#   '“Can',
#   '“That’s',
#   '“You’re',
#   '“Just',
#   '“You’re',
#   '“Coming',
#   '“I',
#   '“I',
#   '“soon,”',
#   '“You',
#   '“I',
#   '“Are',
#   '“I',
#   '“Tickets,',
#   '“I',
#   '“Look,',
#   '“Why'],
#  '“So': ['you'],
#  'Madonna.': ['Madonna'],
#  'Madonna': ['used', 'have'],
#  'big': ['parties',
#   'one.',
#   'fan',
#   'fan',
#   'guns?”',
#   'one,',
#   'party',
#   'Russian',
#   'group'],
#  'parties': ['and', 'that', 'and'],
#  'invite': ['models', 'them,'],
#  'models': ['over,'],
#  'over,': ['right?”', 'quick.'],
#  'right?”': ['And', 'I', 'And'],
#  '“No,': ['no,', 'dude.', 'you’re', 'I’d'],
#  'no,': ['it', 'that’s', 'no.'],
#  'would': ['just',
#   'have',
#   'be',
#   'I',
#   'have',
#   'see',
#   'be',
#   'be.',
#   'have',
#   'stand',
#   'I',
#   'rather',
#   'be',
#   'write'],
#  'few': ['other', 'men'],
#  'other': ['people.”',
#   'night',
#   'end',
#   'things,',
#   'kids,',
#   'people',
#   'people,',
#   'people',
# ...
#   'is',
#   'gets',
#   'desires.',
#   'plays.',
#   'starts',
#   'had',
#   'was',
#   'had',
#   'comes',
#   'has',
#   'just',
#   'grabbed',
#   'dragged',
#   'already',
#   'comes',
#   'was',
#   'was',
#   'agreed,',
#   'can',
#   'comes',
#   'goes…',
#   'goes,',
#   'went…',
#   'looks',
#   'wrote,',
#   'never',
#   'explained',
#   'went,',
#   'started',
#   'could',
#   'slapped',
#   'ran',
#   'went…',
#   'goes,',
#   'shot',
#   'became',
#   'found',
#   'goes,',
#   'is',
#   'was',
#   'keeps',
#   'put',
#   'was',
#   'goes,',
#   'tries',
#   'came',
#   'went,',
#   'goes,',
#   'said',
#   'was'],
#  'sees': ['the', 'all'],
#  'decorations': ['go', 'are'],
#  'shopping': ['mall,', 'center'],
#  'mall,': ['he'],
#  'coming!”': ['Valentine’s'],
#  'mathematical': ['equation'],
#  'equation': ['that'],
#  'every': ['man',
#   'single',
#   'day.',
#   'hour,',
#   'bit',
#   'morning.',
#   'day.”',
#   'fucking',
#   'school',
#   'country',
#   'disabled',
#   'now',
#   'year,'],
#  'head,': ['and'],
#  '“How': ['much', 'was'],
#  'spend': ['today'],
#  'today': ['so'],
#  'won’t': ['act', 'talk', 'come'],
#  'act': ['like', 'like', 'like', 'like'],
#  'cunt?”': ['It'],
#  'doesn’t': ['stop', 'matter.', 'mean', 'cover', 'it?', 'want', 'matter'],
#  'stop': ['there.', 'you', 'you'],
#  'there.': ['Mother’s', '“Hey,', 'You', 'Okay.'],
#  'Mother’s': ['Day!', 'Day', 'Day.', 'Day.”', 'Day', 'Day.'],
#  'Day!': ['Mother’s'],
#  'rocked': ['around'],
#  'house': ['when', 'just', '’cause', 'here,'],
#  'six': ['months', 'months', 'months'],
#  'months': ['old.', 'old.', 'to'],
#  'old.': ['My', 'What'],
#  'girlfriend’s': ['first', 'like,', 'here.', 'away', 'away'],
#  'first': ['Mother’s', 'thing', 'season', 'thing', 'adult'],
#  'wonder': ['what'],
#  'Day.”': ['And', 'Father’s'],
#  '“Probably': ['fucking'],
#  'nothing.': ['He’s'],
#  'He’s': ['got',
#   'six',
#   'a',
#   'my',
#   'a',
#   'the',
#   'like,',
#   'been',
#   'an',
#   'laying',
#   'the',
#   'no'],
#  'he’s': ['gonna',
#   'a',
#   'fucking',
#   'a',
#   'of',
#   'the',
#   'just',
#   'wheeling',
#   'a',
#   'been',
#   'holding'],
#  'gonna': ['buy',
#   'act',
#   'sleep',
#   'sleep.”',
#   'sleep.',
#   'have',
#   'talk',
#   'say',
#   'fuck',
#   'make',
#   'happen',
#   'use',
#   'wrap',
#   'go',
#   'call',
#   'call',
#   'change',
#   'say'],
#  'you?”': ['Within'],
#  'Within': ['an'],
#  'hour,': ['her', 'and'],
#  'friends': ['were', 'for', 'would'],
#  'coincidence,': ['telling', 'right?'],
#  'bad': ['person', 'guy.'],
#  'person': ['I', 'to', 'with', 'I’d', 'you’ve', 'now.”'],
#  'important': ['Mother’s', 'that', 'to', 'to'],
#  'new': ['mum,', 'dad', 'person.”', 'chair'],
#  'mum,': ['you'],
#  'know?': ['And'],
#  'so,': ['I', 'when', 'when', 'I’m'],
#  'went': ['and', 'through', 'like', 'back', 'to', 'like', 'through', 'like'],
#  'cappuccino': ['machine'],
#  'machine': ['’cause', 'gun]'],
#  'assumed': ['that’s'],
#  'wanted': ['her', 'a', 'the'],
#  'have…': ['and'],
#  'wrote': ['a', 'a'],
#  'card.': ['I’m', 'I’m'],
#  'bastard.': ['I'],
#  'right-handed.': ['So'],
#  'left': ['hand.', 'or', 'Oscar'],
#  'hand.': ['Every'],
#  'Every': ['new', 'now', 'cunt'],
#  'dad': ['knows'],
#  'knows': ['this.'],
#  'crayon': ['and'],
#  '[Imitating': ['child]'],
#  'child]': ['“Happy'],
#  '“Happy': ['Mother’s'],
#  'Love,': ['Hank.”', 'Hank.”'],
#  'Hank.”': ['And', 'But'],
#  '“H-A-N…”': ['And'],
#  'did': ['the', 'it,', 'the', 'very', 'something', 'it'],
#  '“K”': ['back-to-front'],
#  'back-to-front': ['because'],
#  'moron.': ['See,'],
#  'See,': ['now', 'me', 'if', 'that’s', 'one', 'the'],
#  'room,': ['they’re', '50%', 'and', 'and'],
#  'thinking,': ['“Well,', 'I', '“Well,'],
#  '“Well,': ['fathers', 'why', 'your', 'that’d', 'imagine', 'if', 'I'],
#  'fathers': ['have', 'and', 'and'],
#  'Father’s': ['Day.”', 'Day', 'Day.', 'Day', 'Day?”', 'Day'],
#  'bullshit.': ['It’s', 'The'],
#  'shit,': ['Father’s'],
#  'want': ['for',
#   'anything.',
#   'anything.”',
#   'anything.”',
#   'for',
#   'you…',
#   'it',
#   'them',
#   'your',
#   'to',
#   'them',
#   'to',
#   'DJ',
#   'whenever',
#   'to',
#   'me',
#   'you',
#   'a',
#   'me',
#   'to'],
#  'Day?”': ['And'],
#  'anything.': ['Don’t', 'Just', 'What'],
#  'worry': ['about', 'about', 'about', 'about'],
#  'it.': ['I',
#   'Just',
#   'I',
#   'They',
#   'Like,',
#   '[Cheering]',
#   'I…',
#   'The',
#   'Boys',
#   'It’s',
#   'In',
#   'There’s',
#   'I',
#   'If',
#   'No',
#   'Right',
#   'Who',
#   'We',
#   '…really',
#   '–',
#   'I',
#   'It’s',
#   'Well,',
#   'I',
#   '[Exhales',
#   'It’s',
#   '[Audience'],
#  'anything.”': ['And', 'And', 'He'],
#  '“Come': ['on.', 'on.”'],
#  'on.': ['You', 'It’s', 'Bag', 'I', '“Oh,'],
#  'something.”': ['I'],
#  '“Honestly,': ['I'],
#  'on.”': ['And', '[Jeffries'],
#  '“It’s': ['my'],
#  'touch': ['it.', 'my'],
#  'leave': ['my', 'the'],
#  'alone.': ['How'],
#  'this?': ['How', 'I’ve', 'Look…'],
#  'about,': ['for'],
#  '24': ['hours,'],
#  'hours,': ['you'],
#  'money?': ['That'],
#  'That': ['would',
#   'stands',
#   'worked',
#   'is',
#   'seems',
#   'same',
#   'the',
#   'one.',
#   'really'],
#  'gift.”': ['That’s'],
#  'single': ['father', 'massacre'],
#  'father': ['has', 'to', 'held'],
#  'gift': ['that'],
#  'cherish,': ['and'],
#  'It’s,': ['like,'],
#  'ceramic': ['mug'],
#  'mug': ['that'],
#  'kid': ['made', 'off', 'right', '’cause', 'back,', 'was', 'at', 'at', 'was'],
#  'school': ['where', 'was', 'across', 'and…'],
#  'handle’s': ['too'],
#  'too': ['big,', 'hot', 'tired.', 'much', 'fucking'],
#  'big,': ['and'],
#  'says,': ['“I', '“From', 'very'],
#  'heart': ['Dad.”', 'grows'],
#  'Dad.”': ['And'],
#  'keep': ['that', 'my', 'my', 'society', 'them'],
#  '20': ['fucking', 'seconds'],
#  'years,': ['this', 'they'],
#  'mug.': ['And'],
#  'it?': ['Every', 'Everyone’s', 'I’ve', 'Bathrooms'],
#  'again,': ['they', 'vastly'],
#  'look': ['at', 'the', 'at', 'authentic,', 'because', 'good', 'like'],
#  'cost': ['me', 'anything,'],
#  'nothing,': ['that'],
#  'mug.”': ['[Audience'],
#  'See…': ['wouldn’t', 'this'],
#  'day': ['that', 'ever.', 'you’re', 'before', 'has', 'watch', 'early.”'],
#  'type': ['of', 'of', 'of'],
#  'stuff,': ['but', 'but'],
#  'anything,': ['that'],
#  'could': ['participate',
#   'do',
#   'go',
#   'form',
#   'all',
#   'bring',
#   'march',
#   'happen',
#   'read',
#   'read',
#   'solve'],
#  'participate': ['in,'],
#  'in,': ['right?', 'jumping', 'which', 'I', '“And', 'prints', 'right?', 'and'],
#  'it,': ['right?',
#   'right?',
#   'Jim!”',
#   'ladies',
#   'go',
#   'go',
#   'but',
#   'but',
#   'right?',
#   'right?',
#   'man.',
#   'and'],
#  'April': ['18th…', '18th.', '18th', '18th,', '18th'],
#  '18th…': ['Anal'],
#  'Anal': ['Sex'],
#  'Sex': ['Day.'],
#  '[Men': ['cheering', 'whooping]', 'whooping]'],
#  'cheering': ['loudly]'],
#  'loudly]': ['It’s'],
#  'good,': ['isn’t', 'right?', 'either.'],
#  'isn’t': ['it?'],
#  'Everyone’s': ['girlfriend', 'going'],
#  'wife': ['has', 'took', 'fat,'],
#  'ass': ['on', 'twice.', 'that', 'fucking,', 'fucking,', 'is'],
#  '18th.': ['It’s'],
#  'nice.': ['A'],
#  'A': ['month', 'new'],
#  'month': ['before,'],
#  'before,': ['you’d', 'but'],
#  'you’d': ['be', 'go,'],
#  'walking': ['around', 'through', 'around'],
#  'bird': ['didn’t'],
#  'ass,': ['you', 'and', 'they', 'I'],
#  'same': ['thing',
#   'way',
#   'people',
#   'dog.',
#   'in',
#   'bullshit',
#   'gun',
#   'time.',
#   'lie'],
#  'gift.': ['You'],
#  'mate,': ['Jason,', 'what', 'don’t'],
#  'Jason,': ['his'],
#  'obviously,': ['they’re', 'he’s'],
#  'connected': ['than'],
#  'are.': ['They’ve,', '[Stammers]'],
#  'They’ve,': ['uh…”'],
#  'uh…”': ['I’m'],
#  'merchandise': ['after'],
#  'shows': ['and'],
#  'thinking': ['of', 'about', 'it.'],
#  'bringing': ['out', 'guns'],
#  'some': ['April', 'things', 'social', 'kind.', 'type', 'text', 'peanuts.'],
#  '18th': ['T-shirts.', 'T-shirt.'],
#  'T-shirts.': ['Not'],
#  'Not': ['even', 'a', 'true.', 'in', 'by'],
#  'putting': ['“Jim', 'it'],
#  '“Jim': ['Jefferies”'],
#  'Jefferies”': ['on'],
#  'them': ['or',
#   'in',
#   'light',
#   'holding',
#   'crazy.',
#   'in',
#   '’cause',
#   'anymore.',
#   'to',
#   'were',
#   'were',
#   'knew',
#   'they’ve',
#   'shut.'],
#  'T-shirts': ['that'],
#  'say,': ['“April', '“No,', '“Bravo!”'],
#  '“April': ['18th.”'],
#  '18th.”': ['‘Cause'],
#  '‘Cause': ['it’s', 'that’s', 'it', 'strip', 'I'],
#  'You’re': ['in',
#   'a',
#   'not',
#   'still',
#   'a',
#   'bringing',
#   'all',
#   'a',
#   'fucking',
#   'just'],
#  'bar.': ['You’re'],
#  'guy.': ['You', 'You’re', 'That’s'],
#  'guy': ['at',
#   'constantly',
#   'mistreated',
#   'out',
#   'out',
#   'out',
#   'came',
#   'was',
#   'up.',
#   'on',
#   'who’s',
#   'goes,',
#   'says,',
#   'said',
#   'went,',
#   'speaking',
#   'breaks'],
#  'bar': ['with'],
#  '18th,': ['and'],
#  'Fucking': ['friends', 'did', 'cunts,'],
#  'life,': ['right?', 'he’s'],
#  'better,': ['you'],
#  'T-shirt.': ['The'],
#  'weird': ['thing', 'when'],
#  'bigging-up': ['anal'],
#  'anal': ['sex', 'sex…'],
#  'sex': ['here,'],
#  'here,': ['and', 'buddy', 'you'],
#  'girls': ['in', 'and', 'being', 'who', 'have', 'out'],
#  'much.': ['I’m', 'Good'],
#  'huge': ['fan.'],
#  'fan.': ['I'],
#  'prefer': ['the'],
#  'cunt.': ['I', 'Very'],
#  'more…': ['I'],
#  'cunt': ['is', 'and', 'a', 'should', 'right', 'rented', 'called', 'there.”'],
#  'purpose-built': ['thing'],
#  'fuck.': ['But,', 'Right?', 'And'],
#  'But,': ['you', 'by'],
#  'sex…': ['Oh,'],
#  'know…': ['I', 'And', 'I'],
#  'involved,': ['’cause'],
#  'feel': ['like'],
#  'to.': ['You'],
#  'been': ['a',
#   'vastly',
#   'a',
#   'doing.',
#   'a',
#   'beaten.',
#   'a',
#   'an',
#   'telling',
#   'lying',
#   'training',
#   'following',
#   'getting',
#   'to',
#   'drying',
#   'through',
#   'texting',
#   'downgraded.”',
#   'downgraded.”',
#   'through!',
#   'downgraded!”',
#   'downgraded!”'],
#  'fan': ['of', 'of'],
#  'fucking,': ['I,', 'and'],
#  'I,': ['uh…'],
#  'uh…': ['When', 'But', 'Maybe', 'slavery!', 'I', 'I'],
#  'watch': ['it', 'it.', 'strippers,', 'it', 'this'],
#  'porn,': ['it'],
#  'seems': ['very', 'to', 'to', 'fair'],
#  'inviting.': ['The', 'It’s'],
#  'girl’s': ['taking', 'asshole.', 'face.”', 'face.”', 'on'],
#  'taking': ['it', 'my', 'your'],
#  'fluently': ['in'],
#  'having': ['fun,', 'a', 'shit', 'guns.', 'a', 'a'],
#  'fun,': ['and,'],
#  'and,': ['uh…'],
#  'smell': ['porn.', 'porn.'],
#  'porn.': ['You', 'You', 'It’s', 'And'],
#  'different,': ['porn.'],
#  'different.': ['They', 'I’ve…'],
#  'clean': ['the'],
#  'asshole.': ['They'],
#  'pump': ['water'],
#  'water': ['into'],
#  'until': ['it’s', '1996.'],
#  'hygienic.': ['I’m'],
#  'happy.': ['She’s'],
#  'She’s': ['like…', 'inviting.', 'my', 'always', 'been', 'listening'],
#  'like…': ['You’ve',
#   'She',
#   'Okay,',
#   'Think',
#   'And',
#   '[Mimicking',
#   '“Ice',
#   '“You'],
#  'pussy,': ['you’re'],
#  'her,': ['and', 'and', 'all', 'he’s'],
#  '“Put': ['it', 'your'],
#  'ass.”': ['She’s', 'And…', 'And'],
#  'favor': ['in', 'to'],
#  'She': ['says', 'does', 'sees', 'gets', 'goes,', 'comes', 'locked', 'goes,'],
#  'says': ['things…', '‘economy’'],
#  'things…': ['I'],
#  '“I’m': ['enjoying', 'gonna', 'not', 'gonna', 'gonna', 'sorry,', 'sorry,'],
#  'enjoying': ['that.', 'it.', 'claps'],
#  'Keep': ['putting', 'going.', 'the', 'your'],
#  'ass.': ['Fuck', 'I', 'Let', 'I'],
#  'Fuck': ['my', 'you!', 'you!”', 'you!'],
#  'cock': ['in', 'from', 'in', 'that', 'is,', 'and', 'and'],
#  'And…': ['And', 'I’m', 'And', 'Now,', 'unless'],
#  'life': ['has'],
#  'I’ve…': ['My'],
#  'crying.': ['Now,', 'I’ve'],
#  'although': ['that'],
#  'help': ['you'],
#  'times,': ['it’s'],
#  'want…': ['It’s'],
#  'day.': ['I', 'This', 'I', 'One', 'To'],
#  'acts': ['like'],
#  'enjoy': ['it.”', 'your'],
#  'it.”': ['She', 'And'],
#  'does': ['that', 'my', 'this,', 'make'],
#  'whole,': ['“Yeah.'],
#  '“Yeah.': ['Oh,'],
#  'good.”': ['[Moaning]', 'But', 'He’s', 'Anyway,'],
#  'Ahh!': ['♪'],
#  '♪': ['I’m',
#   'And',
#   'My',
#   'It’s',
#   'From',
#   '',
#   'One',
#   '',
#   'And',
#   'Protection.',
#   'It',
#   'And'],
#  '“Are': ['you', 'you', 'you', 'you', 'you,'],
#  'done?': ['Are', 'Finish'],
#  'Are': ['you'],
#  'close': ['to'],
#  'done?”': ['You'],
#  'pussy': ['and', 'or'],
#  'almost': ['done?'],
#  'Finish': ['this.”'],
#  'this.”': ['Like'],
#  'you…': ['They', 'When', 'Don’t', 'It’s'],
#  'quick.': ['And'],
#  'things,': ['the'],
#  'porn': ['girls.', 'girl'],
#  'girls.': ['I'],
#  'paid.': ['I’m', 'It’s'],
#  'opposite': ['bit'],
#  'society.': ['Um…'],
#  'called': ['“ATM.”', '“assault', 'an', 'an', 'Simon', 'a'],
#  '“ATM.”': ['I'],
#  'kids.': ['That', 'Happens', 'Oh!'],
#  'stands': ['for', 'over'],
#  '“ass': ['to'],
#  'mouth.”': ['That’s'],
#  'pull': ['the', 'out,'],
#  'from': ['out',
#   'the',
#   'high',
#   'the',
#   'the',
#   'Norway',
#   'having',
#   'me.”',
#   'me.',
#   'time',
#   'being',
#   'wrong,',
#   'blowing',
#   'South',
#   'a',
#   'Cape',
#   'everywhere.',
#   'the',
#   'the',
#   'the'],
#  'anus,': ['and'],
#  'she’ll': ['put', 'say'],
#  'put': ['it',
#   'their',
#   'up',
#   'an',
#   'it',
#   'it',
#   'your',
#   'the',
#   'me',
#   'the',
#   '“a',
#   'my'],
#  'directly': ['in'],
#  'mouth,': ['and'],
#  'taste': ['of', 'my'],
#  'Let': ['me', 'that', 'him'],
#  'woman,': ['puts'],
#  'puts': ['his', 'her'],
#  'mouth': ['to', 'ever.'],
#  'congratulate': ['her'],
#  'fine': ['work…'],
#  'work…': ['[Applause]'],
#  '[Applause]': ['she’s', '[Cheering]'],
#  'doing.': ['Now,'],
#  'drunken': ['night'],
#  'ex-girlfriend': ['where'],
#  'thought': ['she’d', 'he', 'it', 'he', 'that.', 'maybe'],
#  'she’d': ['be', 'stand', 'get', 'be'],
#  'wild': ['and'],
#  'try': ['that.', 'to', 'to', 'to'],
#  'Once': ['again,'],
#  'experience.': ['I’m'],
#  'truthful,': ['really'],
#  'is.': ['Now,', 'I'],
#  'constantly': ['bother', 'telling', 'fucking'],
#  'bother': ['me'],
#  'ass?”': ['[Woman'],
#  '[Woman': ['shouting]', 'whoops]'],
#  'shouting]': ['What'],
#  'question.': ['[Woman'],
#  'whoops]': ['Women,'],
#  'Women,': ['the', 'when'],
#  'reason': ['that', 'it'],
#  'because…': ['we', 'paraplegics'],
#  'hate': ['it.',
#   'having',
#   'it.',
#   'you.”',
#   'guns.',
#   'guns.',
#   'guns.”',
#   'myself',
#   'you!',
#   'you!”',
#   'that'],
#  '[Cheering]': ['So…', 'So…', 'I’m'],
#  'father.': ['Um…'],
#  'son!': ['I', '[Audience'],
#  'cigarettes.': ['I'],
#  'hold': ['him'],
#  'him': ['for',
#   'here.',
#   'over.',
#   'at',
#   'in.',
#   'out',
#   'out.',
#   'down',
#   'right',
#   'a',
#   'because',
#   'through.”'],
#  'five': ['minutes'],
#  'minutes': ['every'],
#  'killing': ['me.'],
#  'boy.': ['No,', 'I'],
#  'No,': ['he’s', 'wait.', 'let’s', 'no,', 'I'],
#  'great': ['little', 'little', 'FXX', 'seasons', 'thing', 'for', 'disabled'],
#  'fella.': ['I'],
#  'him.': ['Um…', 'And', 'We', 'Anyway…', 'He’s', 'Let'],
#  'loves': ['him,', 'my', 'Hank,', 'her,', 'a'],
#  'him,': ['though.', 'and'],
#  'though.': ['It’s'],
#  'creepy.': ['And…'],
#  'glad': ['I'],
#  'son.': ['That', 'I', 'She'],
#  'worked': ['out'],
#  'girl.': ['It'],
#  'Nothing': ['weird.'],
#  'weird.': ['Wouldn’t'],
#  'Wouldn’t': ['fuck'],
#  'along': ['with', '’cause', 'and', 'to'],
#  'and…': ['So…', '[Mimicking', 'they', 'then'],
#  'Because': ['you', 'Sarah', 'even', 'basically'],
#  'dream,': ['see…'],
#  'see…': ['For'],
#  'okay?': ['When', 'I’m', 'The'],
#  'born…': ['the'],
#  'couple': ['over', 'of', 'come', 'of'],
#  'road,': ['within'],
#  'within': ['two'],
#  'weeks': ['of'],
#  'born,': ['had'],
#  'baby': ['girl,',
#   'girl',
#   'girls',
#   'boys',
#   'girl…',
#   'lays',
#   'is',
#   'everywhere.”',
#   'is',
#   'dies?',
#   'that'],
#  'rightly': ['or'],
#  'wrongly,': ['the'],
#  'head': ['was…', 'cut.', 'around'],
#  'was…': ['“Aw,', 'I’m'],
#  '“Aw,': ['that’s'],
#  'great.': ['I', 'You’re'],
#  'hope': ['Hank', 'when', 'you', 'you’re', 'you'],
#  'fucks': ['that', 'everything.', 'off.'],
#  'day.”': ['That’s', 'And'],
#  'think…': ['‘Cause'],
#  'age,': ['he', 'that'],
#  'everything.': ['I'],
#  'gay': ['or'],
#  'straight.': ['All'],
#  'All': ['I',
#   'I’m',
#   'right,',
#   'right.',
#   'right?',
#   'right.',
#   'right.',
#   'right,',
#   'right,',
#   'right?'],
#  'desires.': ['That'],
#  'dream': ['for'],
#  'history': ['of', 'of'],
#  'daughters,': ['has'],
#  'held': ['his'],
#  'gone,': ['“Oh,', '“That'],
#  'cocks': ['through'],
#  'shy': ['of'],
#  'cock.': ['I'],
#  'pass': ['out', 'it'],
#  'boys': ['are', 'differently'],
#  'queuing': ['up.”'],
#  'Right,': ['you'],
#  'treat': ['baby'],
#  'differently': ['as'],
#  'well.': ['My', 'It’s'],
#  'gym': ['every', 'where', 'and', 'in'],
#  'morning.': ['I', 'You'],
#  'occasionally,': ['and'],
#  'gym,': ['there’s'],
#  'daycare': ['crèche'],
#  'crèche': ['thing'],
#  'hand': ['your', 'your', 'full', 'over'],
#  'off,': ['and', 'you', 'and', 'they’ve'],
#  'inside': ['that'],
#  'daycare,': ['there’s,', 'and'],
#  'there’s,': ['like,'],
#  'three': ['women', 'flights', 'hours', 'flights', 'people', 'seats'],
#  '50s.': ['They’re'],
#  'They’re': ['very', 'constantly', 'looking', 'like,'],
#  'ladies,': ['and'],
#  'plays.': ['Then'],
#  ...}

# %%
louis_dict = markov_chain(louis_text)
louis_dict
# Out:
# {'Intro': ['Fade'],
#  'Fade': ['the'],
#  'the': ['music',
#   'lights.',
#   'nicest',
#   'sidewalk',
#   'street',
#   'middle',
#   'road.',
#   'different',
#   'country.',
#   'dog',
#   'street',
#   'time,',
#   'dog.',
#   'old',
#   'dog',
#   'dog',
#   'old',
#   'one',
#   'toilet,',
#   'drain.',
#   'rest',
#   'toilet?',
#   'toilet.',
#   'fish',
#   'fish,',
#   'toilet,',
#   'bottom,',
#   'reason.',
#   'actual',
#   'facts',
#   'aquarium.',
#   'aquarium',
#   'plexiglas,',
#   'alternatives.',
#   'food',
#   'food–',
#   'food',
#   'fact',
#   'food',
#   'only',
#   'food',
#   'food',
#   'morning.',
#   'mail',
#   'train',
#   'top',
#   'water?',
#   'fuck',
#   'parents',
#   'kid,',
#   'meat.”',
#   'way.',
#   'face',
#   'courtyard',
#   'building',
#   'courtyard',
#   'first',
#   'stone',
#   'courtyard,',
#   'building.',
#   'streets',
#   'courtyard.',
#   'worst',
#   'things',
#   'doorman.”',
#   'doorman',
#   'doorman',
#   'doorman',
#   'look',
#   'news,',
#   'world.',
#   'bathroom',
#   'waistband',
#   'lawn,',
#   'grass',
#   'information',
#   'worst',
#   'future',
#   'worst',
#   'fat',
#   'systems',
#   'socks.',
#   'interesting',
#   'dark',
#   'only',
#   'motel',
#   '55-year-old.',
#   'president',
#   'president.',
#   'whole',
#   'world',
#   'easy',
#   'rest',
#   'sexual',
#   'girls',
#   'branch',
#   'ground.',
#   'sexiest',
#   'world.”',
#   'lips,',
#   'problem',
#   'one',
#   'fuck',
#   'courage',
#   'whole',
#   'fact',
#   'number-one',
#   'number-one',
#   'worst',
#   'whole',
#   'first',
#   'way',
#   'line',
#   'guy',
#   'thing,',
#   'elderly',
#   'young,',
#   'end',
#   'book',
#   'end',
#   'very–',
#   'end',
#   'sensitivity',
#   'male',
#   'first',
#   'second',
#   'guy,',
#   'one.',
#   'middle',
#   'best',
#   'last.',
#   'only',
#   'way,',
#   'best',
#   'best',
#   'best',
#   'best',
#   'week,',
#   'week,',
#   'parents,',
#   'kids–',
#   'stage',
#   'kids–',
#   'witness',
#   'kids',
#   'kid',
#   'comments.',
#   'video.',
#   'videos',
#   'first',
#   'bathroom',
#   'same',
#   'deal.',
#   'way',
#   'balls,',
#   'stuff',
#   'situation.',
#   'worst',
#   'wheel,',
#   'most',
#   'worst',
#   'worst.',
#   'world',
#   'law',
#   'number-one',
#   'mail–',
#   'mall',
#   'environment.',
#   'red',
#   'dispensers',
#   'red',
#   'other',
#   'plastic',
#   'bag.”',
#   'good',
#   'thing',
#   'good',
#   'thing',
#   'dude',
#   'worst',
#   'nuts.',
#   'worst',
#   'nation',
#   'railroad',
#   'factory',
#   'fucking'],
#  'music': ['out.'],
#  'out.': ['Let’s', 'Her', 'And'],
#  'Let’s': ['roll.', 'get'],
#  'roll.': ['Hold'],
#  'Hold': ['there.'],
#  'there.': ['Lights.',
#   'I',
#   'So?',
#   '“As',
#   'That',
#   '“Tits”',
#   'Well.”',
#   'It’s',
#   'You'],
#  'Lights.': ['Do'],
#  'Do': ['the', 'you', 'you', 'you'],
#  'lights.': ['Thank'],
#  'Thank': ['you.', 'you', 'you.', 'you', 'you.'],
#  'you.': ['Thank',
#   '“I',
#   'Bye.”',
#   'There’s',
#   'That’s',
#   'It’s',
#   'I’ll',
#   'Next',
#   'Yecch,',
#   'Of'],
#  'you': ['very',
#   'compliment',
#   'put',
#   'flush,',
#   'back.',
#   'really',
#   'consider',
#   'gotta',
#   'think',
#   'can',
#   'go',
#   'circle',
#   'make',
#   'know?',
#   'know,',
#   'know,',
#   'live',
#   'doing',
#   'don’t',
#   'know?',
#   'know?',
#   'start',
#   'didn’t,',
#   'liar,',
#   'know,',
#   'start',
#   'kind',
#   'didn’t',
#   'know?',
#   'have',
#   'what.',
#   'brush',
#   'help',
#   'should',
#   'have.',
#   'crazy?',
#   'know',
#   'know',
#   'know,',
#   'are,',
#   'pretty',
#   'stay',
#   'can',
#   'can',
#   'know?',
#   'try',
#   'know–',
#   'say,',
#   'consider',
#   'three',
#   'alone',
#   'with',
#   'could',
#   'see',
#   'can',
#   'know,',
#   'see',
#   'know,',
#   'know,',
#   'wish',
#   'could',
#   'squeeze',
#   'know,',
#   'tomorrow',
#   'should',
#   'read',
#   'always',
#   'ever',
#   'know,',
#   'could',
#   'touch',
#   'touch',
#   'didn’t',
#   'didn’t',
#   'know?',
#   'meet',
#   'just',
#   'can',
#   'got',
#   'know',
#   'shitting',
#   'come',
#   'just',
#   'taping',
#   'missed',
#   'watch',
#   'get',
#   'tape',
#   'think',
#   'get',
#   'have',
#   'get',
#   'get',
#   'have',
#   'get',
#   'gonna',
#   'get',
#   'awkwardly',
#   'want,',
#   'want.',
#   'get',
#   'know,',
#   'put',
#   'need',
#   'are',
#   'were',
#   'were,',
#   'a',
#   'ever',
#   'would',
#   'die!”',
#   'die!”',
#   'made',
#   'get',
#   'to',
#   'kill',
#   'murder',
#   '“not',
#   'could',
#   'have',
#   'do',
#   'an',
#   'get',
#   'pick',
#   'get',
#   'get',
#   'were',
#   'applauded,',
#   'understand?',
#   'go,',
#   'can',
#   'don’t',
#   'can',
#   'very,'],
#  'very': ['much.',
#   'much.',
#   'old.',
#   'different',
#   'cute',
#   'nice.',
#   'short.',
#   'differently',
#   'much.'],
#  'much.': ['I', 'Well,', 'Some', 'Thank'],
#  'I': ['appreciate',
#   'don’t',
#   'appreciate',
#   'was',
#   'love',
#   'live',
#   'live',
#   'live–',
#   'live',
#   'always–',
#   'guess',
#   'saw',
#   'have',
#   'see',
#   'always',
#   'always',
#   'hope',
#   'do.',
#   'hope',
#   'don’t',
#   'don’t',
#   'know',
#   'had',
#   'came',
#   'just',
#   'gonna',
#   'took',
#   'don’t',
#   'don’t',
#   'don’t',
#   'really',
#   'don’t',
#   'don’t',
#   'mean,',
#   'don’t',
#   'even',
#   'think',
#   'don’t',
#   'think',
#   'am',
#   'live',
#   'live',
#   'never',
#   'was',
#   'had',
#   'mean,',
#   'was',
#   'don’t',
#   'went',
#   'didn’t',
#   'was.',
#   'notice',
#   'can',
#   'don’t',
#   'just',
#   'can',
#   'see',
#   'am.',
#   'said,',
#   'said,',
#   'said,',
#   'said,',
#   'don’t',
#   'could',
#   'was',
#   'was',
#   'just',
#   'see',
#   'see',
#   'had',
#   'was.',
#   'don’t',
#   'won’t',
#   'don’t',
#   'don’t',
#   'guess.',
#   'think',
#   'die',
#   'die',
#   'have',
#   'really',
#   'love',
#   'would',
#   'need',
#   'need',
#   'accept',
#   'have',
#   'really',
#   'gotta,',
#   'have',
#   'have',
#   'put',
#   'have',
#   'have',
#   'have',
#   'don’t',
#   'do',
#   'don’t',
#   'do',
#   'start,',
#   'can',
#   'just',
#   'have',
#   'start',
#   'know',
#   'know.',
#   'saw',
#   'saw',
#   'thought,',
#   'don’t',
#   'like',
#   'just',
#   'can',
#   'don’t',
#   'don’t',
#   'don’t',
#   'mean',
#   'like',
#   'am,',
#   'mean,',
#   'didn’t',
#   'always',
#   'see',
#   'see',
#   'can',
#   'don’t',
#   'can’t–',
#   'told',
#   'hope',
#   'always–',
#   'love',
#   'see',
#   'think',
#   'never',
#   'do.',
#   'just',
#   'just–“”',
#   'just–“”',
#   'was',
#   'was',
#   'could',
#   'wanted',
#   'go.',
#   'could',
#   'don’t',
#   'don’t',
#   'don’t',
#   'just',
#   'know',
#   'know',
#   'touched',
#   'touched',
#   'said',
#   'liked',
#   'meant,',
#   'like',
#   'like',
#   'don’t',
#   'had',
#   'love',
#   'can',
#   'can’t',
#   'get',
#   'get',
#   'went',
#   'wanna',
#   'promise',
#   'think',
#   'see',
#   'like',
#   'like',
#   'feel',
#   'got',
#   'mean,',
#   'think,',
#   'mean',
#   'don’t',
#   'have',
#   'am',
#   'can',
#   'am',
#   'was',
#   'said,',
#   'mean,',
#   'was',
#   'don’t',
#   'yelled',
#   'said,',
#   'said',
#   'hope',
#   'mean,',
#   'capable',
#   'don’t',
#   'wonder',
#   'might',
#   'don’t',
#   'hate',
#   'always',
#   'have,',
#   'believe,',
#   'believe–',
#   'don’t',
#   'call,',
#   'have'],
#  'appreciate': ['that.', 'very', 'the'],
#  'that.': ['I', '“fuck', 'Yes.', 'It’s', 'If', 'Nobody', 'If', 'I’d'],
#  'don’t': ['necessarily',
#   'want',
#   'think',
#   'know',
#   'care.',
#   'think',
#   'care,',
#   'care.',
#   'go–',
#   'know!',
#   'know',
#   'get',
#   'think',
#   'know.',
#   'live',
#   'really',
#   'leave,',
#   'know',
#   'know',
#   'know.',
#   'even',
#   'know',
#   'know.',
#   'have',
#   'have',
#   'know',
#   'have',
#   'have',
#   'have',
#   'know',
#   'know',
#   'usually–',
#   'see,',
#   'mean',
#   'know',
#   'know–',
#   'know.',
#   'get',
#   'watch',
#   'know.',
#   'know–',
#   'remember,',
#   'know,',
#   'know.',
#   'believe',
#   'get',
#   'give'],
#  'necessarily': ['agree'],
#  'agree': ['with'],
#  'with': ['you,',
#   'one',
#   'green',
#   'no',
#   'little',
#   'fountains?',
#   'me',
#   'a',
#   'every',
#   'that,',
#   'Michael',
#   'the',
#   'somebody',
#   'three',
#   'no',
#   'all',
#   'a',
#   'guys',
#   'you',
#   'you',
#   'my',
#   'an',
#   'a',
#   'that!”',
#   'other',
#   'the',
#   'their',
#   'a',
#   'life.',
#   'your',
#   'that',
#   'the',
#   'nut',
#   'the',
#   'me',
#   'slaves.',
#   'the'],
#  'you,': ['but',
#   'you',
#   '“just',
#   'nuts?',
#   'Deborah.',
#   'But',
#   'you’re',
#   'there’s',
#   'you’re'],
#  'but': ['I',
#   'they’re',
#   'so',
#   'it’s',
#   'so',
#   'it’s',
#   'put',
#   'it',
#   'maybe…',
#   'maybe…'],
#  'Well,': ['this', 'go'],
#  'this': ['is',
#   'old',
#   'old',
#   'sweater',
#   'lady,',
#   'dog',
#   'piece',
#   'house.”',
#   'seal,',
#   'seal/sea',
#   'together,',
#   'courtyard',
#   'guy',
#   'thing,',
#   'building?”',
#   'beautiful',
#   'was.',
#   'seems',
#   'is',
#   'happen',
#   'and',
#   'idiot',
#   'situation',
#   'is',
#   'your',
#   'membrane',
#   'is',
#   'one’s',
#   'shit.',
#   'book',
#   'big',
#   'came',
#   'for',
#   'thing,',
#   'thing',
#   'thing.',
#   'for',
#   'with',
#   'amazing'],
#  'is': ['a',
#   'easily',
#   'odd',
#   'aware',
#   'all',
#   'because',
#   'awful.',
#   'he',
#   'a',
#   'a',
#   'another',
#   'bullshit.”',
#   'it',
#   'private',
#   'basically',
#   'pretty',
#   'something',
#   'way',
#   'way',
#   'what–',
#   'being',
#   'a',
#   'when',
#   'the',
#   'murdered',
#   'hard,',
#   'putting',
#   'an',
#   'rooted',
#   'Arizona.',
#   'a',
#   'a',
#   '55.',
#   'OK',
#   'not',
#   'better',
#   'being',
#   'not',
#   'dating.',
#   'a',
#   'that',
#   'telling',
#   'beyond',
#   'literally',
#   'no',
#   'not',
#   'over,',
#   'a',
#   'unbelievable,',
#   'when',
#   'granted,',
#   'that',
#   'the',
#   'just',
#   'divorce,',
#   'forever.',
#   'for',
#   'falling',
#   'the',
#   'standing',
#   'unbelievable',
#   'short.',
#   'very',
#   'an',
#   'basic',
#   'earth,',
#   'when',
#   'that',
#   'that',
#   'context.',
#   'a',
#   'a',
#   'there.',
#   'the',
#   'the',
#   'that'],
#  'a': ['nice',
#   'building',
#   'town',
#   'cloudy',
#   'cloudy',
#   'sweater',
#   'nightmare.',
#   'guy',
#   'pet',
#   'weird',
#   'second!',
#   'nap!',
#   'shit?',
#   'shit',
#   'farm?',
#   'slave!',
#   'pretty',
#   'massive',
#   'bed,',
#   'bad',
#   'thing',
#   'shark',
#   'predator,',
#   'predator,',
#   'guy',
#   'minute',
#   'gay',
#   'nice',
#   'nice',
#   'child.',
#   'pretty',
#   'fountain',
#   'fountain',
#   'fountain?”',
#   'Greek',
#   'lot.',
#   'year',
#   'Sunday',
#   'lot',
#   'little',
#   'confrontation',
#   'hard',
#   'new',
#   'healthy',
#   'not-so-healthy',
#   'good',
#   'candidate.',
#   'lot.',
#   'sudden,',
#   'bag',
#   'tough',
#   'pretty',
#   'whole',
#   'snow',
#   'terrible',
#   'bowling',
#   'day,',
#   'weird',
#   'room',
#   'cancer',
#   'million',
#   '28-year-old',
#   'dead',
#   'bus',
#   'hand',
#   'fair…',
#   'miner.',
#   'miner.',
#   'minor,',
#   'miner.',
#   'mine',
#   'county',
#   'helicopter',
#   'fun',
#   '17-year-old',
#   'young,',
#   'big',
#   'smelly',
#   'fun',
#   'little',
#   'little',
#   'formula',
#   'guy',
#   'weird',
#   'real',
#   'lot',
#   'nice',
#   'date,',
#   'couple',
#   'date',
#   'couple',
#   'date,',
#   'date,',
#   'random',
#   'second,”',
#   'woman',
#   'date',
#   'man',
#   'guy,',
#   'half-bear,',
#   'date.',
#   'date,',
#   'mess.',
#   'first',
#   'mishmash',
#   'couple',
#   'ransom',
#   'lot',
#   'blind',
#   'date',
#   'date',
#   'lot–',
#   'flaw',
#   'woman,',
#   '68-year-old',
#   'stately',
#   'young',
#   'young',
#   'weird,',
#   'violent',
#   'tit.',
#   'tit.',
#   'crowded',
#   'subway',
#   'sports',
#   'tit',
#   'tit.',
#   'tit.',
#   'tack',
#   'tit–',
#   'shirt',
#   'sweater',
#   'jacket',
#   'tit!',
#   'tit!',
#   'tit!',
#   'four-leaf',
#   'time.',
#   'tit',
#   'bomb!”',
#   'few',
#   'larva',
#   'piece',
#   'good',
#   'fact.',
#   'good',
#   'good',
#   'good',
#   'dance',
#   'shitty',
#   'million',
#   'nap',
#   'kid',
#   'second.',
#   'future',
#   'basic',
#   'particularly',
#   'healthy',
#   'life,',
#   'location.',
#   'woman,',
#   'dick',
#   'gay',
#   'lesbian,',
#   'great',
#   'mockingbird.”',
#   'great',
#   'lot',
#   'different',
#   'weapon',
#   'guy',
#   'second,',
#   'way',
#   'pickup',
#   'car',
#   'person’s',
#   'little',
#   'couple',
#   'person.',
#   'second',
#   'nice',
#   'lot',
#   'few',
#   'lot.',
#   'misdemeanor–',
#   'thing',
#   'camera',
#   'few',
#   'creep.',
#   'hooker?',
#   'life.',
#   'Mormon',
#   'lot',
#   'mall,',
#   'new',
#   'public',
#   'logo',
#   'murdered',
#   'whole',
#   'row,',
#   'row.',
#   'compressed',
#   'competition',
#   'category',
#   'nut',
#   'nephew',
#   'terrible',
#   'gun',
#   'tiny',
#   'whole',
#   'terrible,',
#   'shit',
#   'fuck',
#   'nightmare',
#   'choice.',
#   'little',
#   'mean',
#   'shit.',
#   'lot,'],
#  'nice': ['place.', 'building.', 'place', 'thing.', 'and', 'person,'],
#  'place.': ['This', 'You'],
#  'This': ['is',
#   'dog',
#   'is',
#   'is',
#   'isn’t',
#   'is',
#   'is',
#   'is',
#   'is',
#   'is',
#   'is',
#   'is',
#   'is'],
#  'easily': ['the'],
#  'nicest': ['place'],
#  'place': ['For', 'before.'],
#  'For': ['many', 'just', 'one', 'me,', 'kids'],
#  'many': ['miles', 'people', 'more.', 'people'],
#  'miles': ['in', 'in'],
#  'in': ['every',
#   'the',
#   'New',
#   'a–',
#   'New',
#   'my',
#   'two-second',
#   'and',
#   'her',
#   'her',
#   'water.',
#   'the',
#   'constant',
#   'this',
#   'boston,',
#   'person.',
#   'the',
#   'the',
#   'a',
#   'the',
#   'the',
#   'up',
#   'the',
#   'and',
#   'the',
#   'New',
#   'a',
#   'a',
#   'the',
#   'the',
#   'the',
#   'off',
#   'the',
#   'this',
#   'that.”',
#   'the',
#   'the',
#   'the',
#   'half.',
#   'an',
#   'more',
#   'that',
#   'the',
#   'a',
#   'the',
#   'a',
#   'the',
#   'school',
#   'your',
#   'the',
#   'your',
#   'your',
#   'your',
#   'space',
#   'infinite',
#   'a',
#   'there.',
#   'windows.',
#   'New',
#   'any',
#   'front',
#   'men',
#   'that',
#   'tone',
#   'a',
#   'with',
#   'there,',
#   'moderation.”',
#   'the',
#   'my',
#   'love',
#   'a',
#   'it.',
#   'the',
#   'it.',
#   'my',
#   'front',
#   'the',
#   'the',
#   'every',
#   'your',
#   'your',
#   'there',
#   'and',
#   'and',
#   'there,',
#   'certain',
#   'my',
#   'your',
#   'a',
#   'an',
#   'the',
#   'the',
#   'a',
#   'the',
#   'the',
#   'the',
#   'a',
#   'a',
#   'their',
#   'my',
#   'this',
#   'America,',
#   'Egypt.',
#   'history',
#   'caves',
#   'there.'],
#  'every': ['direction.',
#   'day,',
#   'other',
#   'time',
#   'wisp',
#   'day',
#   'day,',
#   'time.',
#   'time.',
#   'week.',
#   'parent’s',
#   'week?',
#   'Wednesday,',
#   'parent',
#   'direction,',
#   'time',
#   'incredible'],
#  'direction.': ['That’s'],
#  'That’s': ['how',
#   'the',
#   'the',
#   'why',
#   'how',
#   'why',
#   'why',
#   'my',
#   'not',
#   'how',
#   'a',
#   'hard.”',
#   'about',
#   'every',
#   'like',
#   'what',
#   'all',
#   'all',
#   'the',
#   'true.',
#   'the',
#   'it,',
#   'what',
#   'crazy.”',
#   'rare,',
#   'fine',
#   'just',
#   'why',
#   'how',
#   'free',
#   'part',
#   'when',
#   'somebody’s',
#   'mostly',
#   'the',
#   'where'],
#  'how': ['you',
#   'all',
#   'excited',
#   'long',
#   'I',
#   'I',
#   'we',
#   'we',
#   'they–',
#   'it',
#   'long',
#   'bad',
#   'good',
#   'nasty',
#   'do'],
#  'compliment': ['a'],
#  'building': ['And', 'one', 'about'],
#  'And': ['shit',
#   'seeing',
#   'The',
#   'she’s',
#   'the',
#   'they',
#   'she’s',
#   'her',
#   'he',
#   'I',
#   'I',
#   'just',
#   'that’s',
#   'then',
#   'then',
#   'we',
#   'say,',
#   'we',
#   'he’s',
#   'he’s',
#   'they’re',
#   'your',
#   'it’s',
#   'your',
#   'we’re',
#   'just',
#   'it’s',
#   'my',
#   'I',
#   'so',
#   'feeling',
#   'then',
#   'he’s',
#   'sat',
#   'dealing',
#   'I’m',
#   'I’m,',
#   'then',
#   'he',
#   'I',
#   'I',
#   'I',
#   'he',
#   'the',
#   'all',
#   'then',
#   'I',
#   'I',
#   'go',
#   'I',
#   'he',
#   'I',
#   'so',
#   'they’re',
#   'then',
#   'then',
#   'the',
#   'some',
#   'dating',
#   'she’s',
#   'you',
#   'then,',
#   'you',
#   'you’re',
#   'she’s',
#   'he’s',
#   'then',
#   'he',
#   'we',
#   '100%',
#   'then',
#   'you',
#   'you’re',
#   'your',
#   'her',
#   'I',
#   'if',
#   'it’s',
#   'then',
#   'again,',
#   'everybody’s',
#   'every',
#   'everybody’s',
#   'then',
#   'guess',
#   'if',
#   'just',
#   'it’s',
#   'he’s',
#   'responsible',
#   'he',
#   'things',
#   'I',
#   'you',
#   'then'],
#  'shit': ['on',
#   'little',
#   'what',
#   'to',
#   'was',
#   'matters,',
#   'you',
#   'on',
#   'what'],
#  'on': ['a',
#   'the',
#   'her',
#   'TV',
#   'the',
#   'me',
#   'the',
#   'his',
#   'his',
#   'old',
#   'the',
#   'his',
#   'my',
#   'my',
#   'my',
#   'my',
#   'my',
#   'TV',
#   'my',
#   'live',
#   'a',
#   'TV,',
#   'the',
#   'the',
#   'a',
#   'a',
#   'a',
#   'them',
#   'a',
#   'planet',
#   'his',
#   'one–',
#   'the',
#   'the',
#   'Facebook.',
#   'your',
#   'Facebook,',
#   'Facebook.',
#   'your–',
#   'earth.',
#   'earth',
#   'the',
#   'it',
#   'YouTube'],
#  'town': ['with'],
#  'one': ['sentence.',
#   'he',
#   'person',
#   'morning',
#   'of',
#   'summer.',
#   'of',
#   'and',
#   'tomorrow,',
#   'way',
#   'second?”',
#   'second?”',
#   'tit.',
#   'tit.',
#   'tit',
#   'and',
#   'second',
#   'simple',
#   'of',
#   'year,'],
#  'sentence.': ['It'],
#  'It': ['is',
#   'would',
#   'wouldn’t',
#   'was',
#   'was',
#   'was',
#   'means',
#   'takes',
#   'doesn’t',
#   'means',
#   'gets',
#   'means',
#   'really',
#   'was',
#   'looked',
#   'fucking',
#   'doesn’t'],
#  'odd': ['around'],
#  'around': ['here,', 'his', 'like,'],
#  'here,': ['as', 'by', 'by'],
#  'as': ['I',
#   'soon',
#   'you’re',
#   'I',
#   'you',
#   'you’re',
#   'people,',
#   'long',
#   'they’re'],
#  'was': ['driving',
#   'a',
#   'like,',
#   'dead.',
#   'taking',
#   'alive.',
#   'growing',
#   'a',
#   'a',
#   'thinking',
#   'saying,',
#   'like,',
#   'just',
#   'this',
#   'describing',
#   'crazy',
#   'gonna',
#   'up.',
#   'good.',
#   'walking',
#   'trying',
#   'a',
#   'an',
#   'having',
#   'an',
#   'blocking',
#   'driving,',
#   'a',
#   'once',
#   'different.',
#   'legal,',
#   'legal,',
#   'legal,',
#   'legal.',
#   'legal,',
#   'legal.',
#   'done'],
#  'driving': ['here.', 'a'],
#  'here.': ['There', 'People', 'It’s', 'I', 'That’s', 'You'],
#  'There': ['doesn’t', 'are', 'are', 'are'],
#  'doesn’t': ['seem', 'even', 'mean', 'do', 'matter.', 'matter'],
#  'seem': ['to'],
#  'to': ['be',
#   'your',
#   'look',
#   'lose',
#   'handle',
#   'say,',
#   'flush',
#   'the',
#   'the',
#   'the',
#   'be',
#   'a',
#   'be',
#   'just',
#   'try',
#   'work',
#   'work.',
#   'it',
#   'the',
#   'look',
#   'me,',
#   'have',
#   'rest.',
#   'the',
#   'the',
#   'the',
#   'hurt',
#   'be',
#   'me',
#   'wipe',
#   'the',
#   'wipe',
#   'get',
#   'another',
#   'be',
#   'me.',
#   'me,',
#   'decide,',
#   'be',
#   'get',
#   'get',
#   'put',
#   'me,',
#   'do.',
#   'get',
#   'know',
#   'them.',
#   'clap.',
#   'do',
#   'celebrate',
#   'a',
#   'him.',
#   'cape',
#   'Montreal.',
#   'the',
#   'him.',
#   'be.',
#   'do',
#   'make',
#   'the',
#   'this.',
#   'say',
#   'people',
#   'go',
#   'ask.',
#   'a',
#   'her',
#   'get',
#   'say',
#   'a',
#   'women',
#   'women.',
#   'women.',
#   'them.',
#   'imagine',
#   'do.”',
#   'figure',
#   'find',
#   'witness',
#   'do',
#   'just',
#   'decide.',
#   'walk',
#   'each',
#   'hear',
#   'hear',
#   'ruin',
#   'tits,',
#   'touch',
#   'screw',
#   'the',
#   'her',
#   'me',
#   'say',
#   'these',
#   'go,',
#   'watch',
#   'read',
#   'this.”',
#   'you.',
#   'have',
#   'be',
#   'be',
#   'be',
#   'eat',
#   'put',
#   'fuck.',
#   'put',
#   'just',
#   'just',
#   'the',
#   'do',
#   'eat.',
#   'fuck.',
#   'read',
#   'be',
#   'feel',
#   'other',
#   'a',
#   'their',
#   'them.',
#   'a',
#   'think',
#   'think,',
#   'think',
#   'a',
#   'stop',
#   'me!”',
#   'clean',
#   'the',
#   'let',
#   'be',
#   'segregate',
#   'be',
#   'die.',
#   'him,',
#   'another',
#   'cherry-pick.',
#   'you.',
#   'them.',
#   'what',
#   'each'],
#  'be': ['any',
#   'able',
#   'destroyed',
#   'like,',
#   'in',
#   'separate',
#   'like,',
#   'awful',
#   'other',
#   'another',
#   'embarrassed',
#   'bummed',
#   'fun',
#   'like,',
#   'like,',
#   'like,',
#   'sitting',
#   'told',
#   'alive',
#   'when',
#   'there.',
#   'amazing',
#   'the',
#   'so',
#   'the',
#   'doing',
#   'better.',
#   'a',
#   'on',
#   'on',
#   'here.',
#   'when',
#   'the',
#   'so',
#   'a',
#   'murdering',
#   'just–',
#   'stepping',
#   'protected,',
#   'aware',
#   'devastated',
#   'a'],
#  'any': ['difference',
#   'respect',
#   'other',
#   'idea',
#   'day.',
#   'way,',
#   'guy',
#   'other'],
#  'difference': ['Between'],
#  'Between': ['the'],
#  'sidewalk': ['and'],
#  'and': ['the',
#   'she’s',
#   'bones',
#   'I',
#   'the',
#   'it',
#   'he',
#   'we',
#   'sea',
#   'walruses,',
#   'shit-colored,',
#   'it’s',
#   'says,',
#   'you’re',
#   'bite',
#   'eat',
#   'you',
#   'it’s',
#   'a',
#   'me',
#   'whatever…',
#   'stuff,',
#   'he’s',
#   'I’m',
#   'I’m',
#   'he',
#   'he',
#   'I',
#   'then',
#   'confusion.',
#   'you',
#   'then',
#   'it’s',
#   'ineffectual.',
#   'open,',
#   'doing',
#   'fucking',
#   'somebody',
#   'go',
#   'it',
#   'I',
#   'he',
#   'he',
#   'he',
#   'I',
#   'if',
#   'they’re',
#   'those',
#   'flew',
#   'a',
#   'washed,',
#   'stop',
#   'nobody',
#   'then',
#   'if',
#   'fuck',
#   'he',
#   'jerk',
#   'said,',
#   'if',
#   'the',
#   'ill-advised,',
#   'the',
#   'I',
#   'historically,',
#   'mayhem',
#   'something',
#   'she’s',
#   'there’s',
#   'I',
#   'you’re',
#   'a',
#   'a',
#   'bra,',
#   'quickly',
#   'two.',
#   'then',
#   'by',
#   'get',
#   'everything’s',
#   'I,',
#   'we’re',
#   'I’m',
#   'responsible',
#   'pour',
#   'everybody’s',
#   'the',
#   'the',
#   'they',
#   'then',
#   'just',
#   'closing',
#   'for',
#   'look',
#   'I',
#   'go',
#   'out,',
#   'out',
#   'warm',
#   'tight',
#   'I’ve',
#   'yet',
#   'I',
#   'there',
#   'this',
#   'some',
#   'go,',
#   'some',
#   'it',
#   'bad',
#   'then',
#   'I',
#   'then',
#   'anybody',
#   'you',
#   'go',
#   'you',
#   'suffering',
#   'blew',
#   'didn’t',
#   'horses',
#   'be'],
#  'street': ['for', 'In'],
#  'for': ['pedestrians',
#   'her',
#   'the',
#   'every',
#   'his',
#   'a',
#   'the',
#   '50-year-old',
#   'this.”',
#   'me,',
#   'the',
#   'the',
#   'guys',
#   'her',
#   'them.',
#   'everyone.”',
#   'them,',
#   'a',
#   'both',
#   'a',
#   'a',
#   'one',
#   'at',
#   'you,',
#   'three',
#   'two',
#   'me.',
#   'five',
#   'true',
#   'how',
#   'half',
#   'no',
#   '20',
#   'a',
#   'trillions',
#   'a',
#   'half',
#   'the',
#   'one',
#   'your',
#   'dead'],
#  'pedestrians': ['here.'],
#  'People': ['just', 'like', 'fuck'],
#  'just': ['kind',
#   'stands',
#   'being',
#   'fights',
#   'stand',
#   'white',
#   'have',
#   'left',
#   'some',
#   'flush',
#   'keeps',
#   'shitting',
#   'flushed',
#   'die',
#   'be',
#   'hold',
#   'sit',
#   'little',
#   'stains,',
#   'wandered',
#   'need',
#   'the',
#   'stay,',
#   'so–',
#   'to',
#   'like,',
#   'sitting',
#   'feel',
#   'believe',
#   'watched',
#   'show',
#   'dumpy,',
#   'like',
#   'takes',
#   'time.',
#   'nobody',
#   'wash',
#   'solve',
#   'our',
#   'a',
#   'has',
#   'a',
#   'anything,',
#   'like',
#   'thrusting',
#   'decide',
#   'get',
#   'look',
#   'look',
#   'touched',
#   'to',
#   'like',
#   'let',
#   'gets',
#   'saying,',
#   'a',
#   'look.',
#   'put',
#   'your',
#   'record',
#   'lay',
#   'have',
#   'shoving',
#   'fill',
#   'fill',
#   'change.',
#   'a',
#   'leave',
#   'do',
#   'shooting',
#   'threw',
#   'threw'],
#  'kind': ['of', 'of', 'of', 'of', 'of', 'of', 'of', 'of–I', 'of'],
#  'of': ['walk',
#   'the',
#   'the',
#   'them,',
#   'three',
#   'shit',
#   'her',
#   'stuff,',
#   'thing,',
#   'the',
#   'the',
#   'everything',
#   'the',
#   'that',
#   'those',
#   'my',
#   'this',
#   'place.',
#   'coming',
#   'view',
#   'anger',
#   'start',
#   'yourself,',
#   'a',
#   'leaves',
#   'wind.',
#   'my',
#   'rocking',
#   'a',
#   'my',
#   'every',
#   'my',
#   'every',
#   'that',
#   '2,400.',
#   'America',
#   'us',
#   'disappointing.”',
#   'guy',
#   'a',
#   'my',
#   'those',
#   'people',
#   'people,',
#   'courage.',
#   'injury',
#   'the',
#   'different',
#   'dudes',
#   'seconds',
#   'a',
#   'magazines,',
#   'us',
#   'us',
#   'course.”',
#   'a',
#   '“the',
#   'wrath,”',
#   'wrath,”',
#   'a',
#   'that',
#   'the',
#   'here!”',
#   'my',
#   'my',
#   'oak.',
#   'our',
#   'every',
#   'their',
#   'a',
#   'it',
#   'just',
#   'all–my',
#   'miles',
#   'your',
#   'the',
#   'you',
#   'time',
#   'values.',
#   'any',
#   'me,',
#   'my',
#   'shit.”',
#   'a',
#   'shit”?',
#   'a',
#   'shit!”',
#   'pieces',
#   'glass',
#   'my',
#   'it',
#   'things',
#   'murder.',
#   'the',
#   'America.',
#   'a',
#   'horrible',
#   'bad',
#   'good',
#   'course',
#   'course.',
#   'deadly',
#   'course,',
#   'course,',
#   'course…',
#   'course',
#   'course',
#   'people',
#   'course…'],
#  'walk': ['in', 'slowly'],
#  'middle': ['of', 'school.', 'of–'],
#  'road.': ['I'],
#  'love': ['traveling',
#   'you',
#   'you.',
#   'sitting',
#   'when',
#   'women',
#   'tits',
#   'tits,',
#   'being',
#   'and',
#   'to'],
#  'traveling': ['And'],
#  'seeing': ['all'],
#  'all': ['the',
#   'the',
#   'he',
#   'she',
#   'she',
#   'those',
#   'seals',
#   'be',
#   'right.',
#   'fat',
#   'life',
#   'see',
#   'up',
#   'right.',
#   'fountain',
#   'spiffy-looking.',
#   'and',
#   'the',
#   'right,”',
#   'of',
#   'the',
#   'that',
#   'the',
#   'the',
#   'grow',
#   'it',
#   'true,',
#   'unanimously',
#   'that',
#   'that',
#   'mean.',
#   'this',
#   'men',
#   'do',
#   'over',
#   'went,',
#   'the',
#   'in',
#   'the',
#   'the',
#   'the',
#   'times,',
#   'just',
#   'clapped'],
#  'different': ['parts', 'kinds', 'kinds', 'set', 'moms'],
#  'parts': ['of'],
#  'country.': ['I'],
#  'live': ['in',
#   'in',
#   'in',
#   'in',
#   'in',
#   'in',
#   'in',
#   'in',
#   'television.',
#   'apart'],
#  'New': ['York.', 'York.', 'York', 'York'],
#  'York.': ['I', 'I'],
#  'a–': ['There’s'],
#  'There’s': ['no',
#   'no–',
#   'a',
#   'way',
#   'so',
#   'a',
#   'something',
#   'no',
#   'no',
#   'people',
#   'a',
#   'no'],
#  'no': ['value',
#   'legs',
#   'thank',
#   'money.',
#   'candlelight',
#   'face.',
#   'idea',
#   'greater',
#   'actual',
#   'cohesive–',
#   'idea.',
#   'idea',
#   'other',
#   'dense,',
#   'one.',
#   'people.',
#   'end'],
#  'value': ['to', 'on'],
#  'your': ['doing',
#   'toast,',
#   'kid',
#   'phone’s',
#   'mortgage',
#   'thing.',
#   'teeth,',
#   'whole',
#   '40s.',
#   'looks,',
#   'heart.',
#   'body',
#   'car',
#   'death,',
#   'tits.',
#   'elbow',
#   'mom’s',
#   'mom’s',
#   'tits',
#   'fucking',
#   'kids',
#   'Facebook.',
#   'kids’',
#   'kid’s',
#   'own',
#   'own',
#   'kid',
#   'boilerplate',
#   'eyes',
#   'head',
#   'mouth.',
#   'mouth,',
#   'dick',
#   'boyfriend’s',
#   'dick,',
#   'buddy.',
#   'life',
#   'kids',
#   'kids',
#   'child',
#   'murdered',
#   'alive',
#   'bad',
#   'country',
#   'fault.'],
#  'doing': ['that',
#   'here?”',
#   'nothing,',
#   'nothing',
#   'it,',
#   'it,',
#   'this.',
#   'open',
#   'shit'],
#  'that': ['at',
#   'shit.”',
#   'fish’s',
#   'get',
#   'your',
#   'sharks–',
#   'sharks',
#   'we',
#   'at',
#   'looks',
#   'die,',
#   'get',
#   'happens',
#   'nobody',
#   'shit',
#   'ever',
#   'day',
#   'means',
#   'even',
#   'demographic,',
#   'clapped,',
#   'she',
#   'happens,',
#   'kindness',
#   'it',
#   'we',
#   'he',
#   'there',
#   'ever',
#   'this',
#   'you',
#   'happens',
#   'I',
#   'we',
#   'book',
#   'genre.',
#   'book.',
#   'was',
#   'I',
#   'about,',
#   'on',
#   'your',
#   'deal?',
#   'to',
#   'even',
#   'to',
#   'I’m',
#   'guy?',
#   'are',
#   'tells',
#   'weird.',
#   'ever',
#   'ever',
#   'we’re',
#   'we'],
#  'at': ['all.',
#   'the',
#   'that',
#   'them,',
#   'this',
#   'this',
#   'us',
#   'the',
#   'all.',
#   'me.',
#   'me',
#   'me',
#   'all,”',
#   'all',
#   'middle',
#   'a',
#   'a',
#   '45,',
#   '45.',
#   'all',
#   'night.”',
#   'his',
#   'someplace,',
#   'you.',
#   'women.',
#   '2:00.”',
#   'the',
#   'the',
#   'the',
#   'the',
#   'a',
#   'her',
#   'your',
#   'shit,',
#   'people',
#   'my',
#   'all',
#   'them'],
#  'all.': ['“The', 'I', 'Burn'],
#  '“The': ['Old', 'Food'],
#  'Old': ['Lady'],
#  'Lady': ['And'],
#  'The': ['Dog”',
#   'two',
#   'dog’s',
#   'second',
#   'dog',
#   'scientists',
#   'worst',
#   'garbage',
#   'kind',
#   'male',
#   'only',
#   'resolution',
#   'first',
#   'Wheel”',
#   'law'],
#  'Dog”': ['I'],
#  'live–': ['I'],
#  'always–': ['Like,', 'I'],
#  'Like,': ['there’s',
#   '“yeah,',
#   'all',
#   '“please',
#   'as',
#   'this',
#   'let’s',
#   'my',
#   'a',
#   'sucking',
#   'the',
#   'look',
#   'most',
#   'when',
#   'if',
#   '“I',
#   'of'],
#  'there’s': ['this',
#   'one',
#   'these',
#   'this',
#   'no',
#   'just',
#   'still',
#   'these',
#   'nothing',
#   'this'],
#  'old': ['lady',
#   'sweater',
#   'lady',
#   'lady.',
#   'in',
#   'guy,',
#   'yet,',
#   'is,',
#   'pajama',
#   'Honda'],
#  'lady': ['in', 'dies'],
#  'my': ['neighborhood,',
#   'daughter’s',
#   'daughter',
#   'kids',
#   'mom',
#   'building,',
#   'first',
#   'least',
#   'shirt,',
#   'ass',
#   'ass',
#   'ass.',
#   'asshole’s',
#   'asshole.',
#   'age',
#   'age,',
#   'day,',
#   'life,',
#   'socks.',
#   'socks',
#   'grandmother',
#   'other',
#   'socks',
#   'socks,',
#   'hands',
#   'pointed',
#   'vital',
#   'back',
#   'socks.',
#   'life',
#   'sex',
#   'life.”',
#   'little',
#   'tit',
#   'history',
#   'life,',
#   'life,',
#   'favorite',
#   'life.',
#   'divorce',
#   'own',
#   'car,',
#   'most',
#   'lane',
#   'mouth.',
#   'window,',
#   'life.',
#   'reflexes,',
#   'brain'],
#  'neighborhood,': ['And'],
#  'she’s': ['always',
#   'very',
#   'got',
#   'always',
#   'gonna',
#   'gonna',
#   'like,',
#   'looking',
#   'like,'],
#  'always': ['walking',
#   'just–',
#   'wearing,',
#   'look',
#   'think,',
#   'fucking',
#   'some',
#   'will',
#   'think',
#   'happy',
#   'know',
#   'know',
#   'have',
#   'this'],
#  'walking': ['her', 'to', 'together', 'in', 'behind', 'in'],
#  'her': ['dog.',
#   'legs',
#   'legs',
#   'sake,',
#   'to',
#   'life,',
#   'building',
#   'dog',
#   'life.',
#   'to',
#   'circumstances',
#   'terrified.',
#   'courage,',
#   'jacket,',
#   'half',
#   'school.'],
#  'dog.': ['She’s', 'I', 'Even'],
#  'She’s': ['always'],
#  'just–': ['she’s', 'The', 'Poom!', 'They', 'If', '“I', 'You’d'],
#  'old.': ['She'],
#  'She': ['just', 'would', 'wasn’t'],
#  'stands': ['there'],
#  'there': ['just',
#   'looking',
#   'and',
#   'I',
#   'thinking,',
#   'are',
#   'longer.',
#   'who',
#   'who',
#   'with',
#   'is',
#   'like',
#   'and',
#   'was',
#   'would',
#   'would'],
#  'being': ['old,',
#   'eaten.',
#   'a',
#   'towed',
#   'the',
#   'a',
#   'divorced,',
#   'divorced.',
#   'short,',
#   'angry'],
#  'old,': ['And', 'dying'],
#  'dog': ['just', 'Because', 'doesn’t', 'is', 'is', 'just', 'for'],
#  'fights': ['gravity'],
#  'gravity': ['every'],
#  'day,': ['just–', 'worst', 'and', 'and'],
#  'two': ['of', 'dimensions', 'all', 'hours', 'very', 'tits', 'seconds'],
#  'them,': ['it’s', 'And', 'you', 'like'],
#  'it’s': ['really–',
#   'just,',
#   'too',
#   'just,',
#   'OK',
#   'nice.',
#   'just',
#   'over',
#   'not',
#   'always',
#   'agony,',
#   'not',
#   'tough',
#   'gonna',
#   'mean',
#   'a',
#   'the',
#   'because',
#   'like',
#   'up',
#   'been',
#   'true.',
#   'nice',
#   'amazing',
#   'the',
#   '’cause,',
#   'gross.',
#   'a',
#   'not',
#   'happened–',
#   'a',
#   'a'],
#  'really–': ['The'],
#  'dog’s': ['got'],
#  'got': ['a', 'a', 'out', 'brown', 'a', 'on', 'out,', 'their', 'lucky'],
#  'cloudy': ['eye,', 'eye,'],
#  'eye,': ['and', 'And'],
#  'they': ['just',
#   'need',
#   'knew',
#   'do',
#   'didn’t',
#   'don’t.',
#   'are',
#   'die.',
#   'still',
#   'were',
#   'were',
#   'go,',
#   'just',
#   'had',
#   'might',
#   'build',
#   'were'],
#  'stand': ['there'],
#  'looking': ['at', 'at', 'at', 'back', 'at', 'at', 'at', 'up'],
#  'In': ['two', 'a', 'which'],
#  'dimensions': ['together,'],
#  'together,': ['and–', 'man.'],
#  'and–': ['And'],
#  'wearing,': ['like,'],
#  'like,': ['this',
#   '5’10”,',
#   'this',
#   '“yecch,',
#   '“good,”',
#   'three',
#   '“yeah,',
#   '“what',
#   '“fine,”',
#   '“why',
#   '“hey,',
#   '“there’s',
#   'a',
#   'you',
#   '“”',
#   'pulling',
#   '“Num',
#   '“can',
#   'five',
#   '“that’s',
#   '“well,',
#   '80s,',
#   '114,',
#   '“wow,',
#   '“Just–',
#   'lay',
#   '15',
#   '“the',
#   '“there’s',
#   '“”',
#   '“I',
#   '“that',
#   'trying',
#   'one',
#   'a',
#   '“Jesus!',
#   'you',
#   '“that’s',
#   'right',
#   'he',
#   'a',
#   'the'],
#  'sweater': ['dress.', 'when', 'And', 'and'],
#  'dress.': ['I'],
#  'guess': ['it', 'what?'],
#  'it': ['was',
#   'in',
#   'looks',
#   'like',
#   '’cause',
#   'with',
#   'over',
#   'always',
#   'easier',
#   'gets',
#   'takes.',
#   '’cause',
#   'was',
#   'means',
#   'works',
#   'takes',
#   'inside.',
#   'by',
#   'ends,',
#   'was',
#   'would',
#   'gets,',
#   'happened.',
#   'on',
#   'to',
#   'and',
#   'onto',
#   'ends',
#   '’cause',
#   'sucks',
#   'is.',
#   'all',
#   'ending.',
#   'worked',
#   'is',
#   'really',
#   '“next',
#   'is',
#   'is,'],
#  'when': ['she',
#   'you',
#   'you',
#   'I',
#   'I',
#   'they’re',
#   'I',
#   'I',
#   'you',
#   'I',
#   'you',
#   'it',
#   'you',
#   'you',
#   'I’m',
#   'I’m',
#   'I’m',
#   'you',
#   'you'],
#  'she': ['was,',
#   'dies',
#   'dies',
#   'dies–',
#   'has,',
#   'has',
#   'has',
#   'had',
#   'gives',
#   'can',
#   'hits',
#   'says'],
#  'was,': ['like,'],
#  '5’10”,': ['But'],
#  'But': ['now',
#   'if',
#   'I’m',
#   '45,',
#   'you',
#   'I',
#   'they',
#   'for',
#   'I',
#   'he',
#   'women',
#   'you',
#   'that’s',
#   'we',
#   'a',
#   'otherwise…',
#   'divorce',
#   'if',
#   'I',
#   'we',
#   'nobody',
#   'Maybe”',
#   'maybe…”',
#   'maybe…',
#   'maybe…'],
#  'now': ['it’s', 'on,', 'I'],
#  'just,': ['like,', '“why?”', 'you'],
#  'legs': ['are–', 'are', 'are', 'wheeling'],
#  'are–': ['her', 'We'],
#  'are': ['a',
#   'awful.',
#   'the',
#   'all',
#   'when',
#   'out',
#   'aware',
#   'pedophiles,',
#   'you',
#   'people',
#   'hard.',
#   '45',
#   'way',
#   '40',
#   'like,',
#   'people',
#   'millions',
#   'light',
#   'still',
#   'you,',
#   'we',
#   'dancing',
#   'you',
#   'dancing',
#   'you',
#   'OK',
#   'fucking',
#   'in'],
#  'nightmare.': ['They’re'],
#  'They’re': ['just', 'really', 'sitting', 'not', 'not', 'not'],
#  'white': ['with', 'sheep'],
#  'green': ['streaks'],
#  'streaks': ['and'],
#  'bones': ['sticking'],
#  'sticking': ['out.'],
#  'Her': ['legs'],
#  'awful.': ['I', 'Anyway,'],
#  'saw': ['a', 'an', 'this', 'a', 'Nixon', 'the'],
#  'guy': ['with',
#   'Who’s',
#   'looking',
#   'lives',
#   'floating',
#   'I',
#   'talked',
#   'on',
#   'walking',
#   'on',
#   'touches',
#   'ahead',
#   'in'],
#  'wheeling': ['by,'],
#  'by,': ['And'],
#  'he': ['was',
#   'just',
#   'knows',
#   'dies,',
#   'goes,',
#   'die,',
#   'die?',
#   'was',
#   'didn’t',
#   'saying?”',
#   'shuts',
#   'was',
#   'comes',
#   'thinks',
#   'comes',
#   'goes,',
#   'goes',
#   'has',
#   'was',
#   'said',
#   'said',
#   'decided',
#   'has',
#   'walked',
#   'walked',
#   'doesn’t',
#   'says,',
#   'has',
#   'kind',
#   'leaned'],
#  '“yecch,': ['no'],
#  'thank': ['you.'],
#  '“I': ['do',
#   'was',
#   'love',
#   'just',
#   'met',
#   'need',
#   'mean,',
#   'don’t',
#   'know',
#   'hope',
#   'touched',
#   'like',
#   'could',
#   'hope',
#   'hope',
#   'would',
#   'would',
#   'never',
#   'mean,',
#   'think',
#   'told'],
#  'do': ['not',
#   'I',
#   'this',
#   'it',
#   'that.',
#   'at',
#   'I–',
#   'it.',
#   'that.',
#   'anything.”',
#   'you',
#   'you',
#   'that?',
#   'anything.',
#   'I–',
#   'this!”',
#   'women',
#   'they',
#   'it?',
#   'what',
#   'this.',
#   'it',
#   'that.',
#   'women,',
#   'all',
#   'that,',
#   'that,”',
#   'that.”',
#   'good',
#   'this',
#   'when',
#   'anything.',
#   'we'],
#  'not': ['want',
#   'worried',
#   'keep',
#   'used',
#   'gonna',
#   'wrong',
#   'start',
#   'even–',
#   'old',
#   'doing',
#   'gonna',
#   'the',
#   'ancient',
#   'a',
#   'a',
#   'everybody.',
#   'and',
#   'smart,”',
#   'your',
#   'usually',
#   'gonna',
#   'saying',
#   'gonna',
#   'watching',
#   'watching',
#   'blind',
#   'worried',
#   'say',
#   'even',
#   'that'],
#  'want': ['those.', 'her', 'to'],
#  'those.': ['“I’d'],
#  '“I’d': ['rather'],
#  'rather': ['just'],
#  'have': ['air',
#   'Than',
#   'this',
#   'moments',
#   'to',
#   'to',
#   'a',
#   'to–',
#   'to',
#   'to',
#   'to–',
#   'to,',
#   'to',
#   'to',
#   'it!',
#   'it!”',
#   'happened',
#   'to',
#   'zero',
#   'read',
#   'permission,',
#   'to',
#   'said',
#   'it',
#   'a',
#   'bacon',
#   'a',
#   'a',
#   'killed',
#   'to',
#   'your',
#   'both.',
#   'nut',
#   'to',
#   'a',
#   'this',
#   'a',
#   'candles'],
#  'air': ['down'],
#  'down': ['here',
#   'at',
#   'the',
#   'the',
#   'the',
#   'here,”',
#   'and',
#   'to',
#   'and',
#   'because',
#   'the'],
#  'here': ['like', 'like,', 'for'],
#  'like': ['I',
#   'he',
#   'this.',
#   'that.',
#   'him',
#   'this,',
#   'I',
#   'it’s',
#   'the',
#   'a',
#   'I’m',
#   'folding',
#   'an',
#   'this,',
#   'getting',
#   'going',
#   'an',
#   'getting',
#   'me,',
#   'to',
#   'this',
#   'to',
#   'him',
#   'a',
#   'a',
#   'that’s',
#   'Sigourney',
#   'you',
#   'a',
#   'your',
#   'it.',
#   'your',
#   'yours,”',
#   'a',
#   'a',
#   'every',
#   'this.',
#   'we’re',
#   'life.',
#   'it.',
#   'even',
#   'this',
#   'to',
#   'to',
#   'them.',
#   'a'],
#  'Than': ['to'],
#  'look': ['down', 'at', 'too', 'even', 'on', 'just', 'at', 'at', 'at', 'at'],
#  'shit.”': ['I', 'I'],
#  'see': ['these',
#   'them.',
#   'little,',
#   'their',
#   'him',
#   'him',
#   'the',
#   'you.',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'you',
#   'their',
#   'the',
#   'a'],
#  'these': ['two', 'fancy', 'two', 'kids'],
#  'time,': ['and', 'And', 'I'],
#  'think,': ['“god,', '“I', '“I'],
#  '“god,': ['I'],
#  'hope': ['she', 'she', 'this', 'he', 'you', 'you', 'your'],
#  'dies': ['first.”', 'first,', 'first,'],
#  'first.”': ['I'],
#  'do.': ['I', 'I', 'I'],
#  'first,': ['for', 'I’m', 'I'],
#  'sake,': ['Because'],
#  'Because': ['I', 'the', 'this', 'who', 'for', 'the', 'you', 'mostly', 'the'],
#  'lose': ['the', 'tit'],
#  'think': ['she’ll',
#   'they',
#   'you’re',
#   'that',
#   'that',
#   'they’d',
#   'sharks',
#   'sharks',
#   'they’re',
#   'human',
#   'so.',
#   'it’s',
#   'so,',
#   'I',
#   'about',
#   'that',
#   'it’s',
#   'he’s'],
#  'she’ll': ['be', 'say'],
#  'able': ['to'],
#  'handle': ['it.'],
#  'it.': ['If',
#   'I’m',
#   'Idiot.',
#   'I’m',
#   'I',
#   '“that’s',
#   '“I',
#   'If',
#   'I’m',
#   'In',
#   'You',
#   'I',
#   'I'],
#  'If': ['she',
#   'the',
#   'she',
#   'they',
#   'you’re',
#   'I',
#   'I',
#   'I’m–',
#   'I’m',
#   'that',
#   'you’re',
#   'you’re',
#   'you’re',
#   'she’s',
#   'you’re',
#   'you’re',
#   'you',
#   'you’re',
#   'you',
#   'you’re',
#   'you’re',
#   'you',
#   'murder',
#   'murder',
#   'murder',
#   'murder'],
#  'dies–': ['If'],
#  'I’m': ['not',
#   'glad',
#   'this.',
#   'eating',
#   'not',
#   'sitting',
#   'sitting',
#   'sitting',
#   'trying',
#   'like,',
#   'so',
#   'not',
#   'having',
#   'gonna',
#   '45',
#   'either',
#   'gonna',
#   'like,',
#   '45.',
#   'sitting',
#   'sitting',
#   'sitting',
#   'trying',
#   'sitting',
#   'pushing',
#   'asking.',
#   'not',
#   'saying',
#   'here',
#   'totally',
#   'always',
#   'not',
#   'not',
#   'just',
#   'sorry.',
#   'sorry,',
#   'a',
#   'an',
#   'such',
#   'eating',
#   'not',
#   'in',
#   'behind',
#   'at',
#   'a'],
#  'worried': ['about', 'about'],
#  'about': ['the',
#   'the',
#   'that',
#   'a',
#   'me',
#   'my',
#   'your',
#   '60',
#   'three',
#   'it.”',
#   'what',
#   'it',
#   'another',
#   'particular'],
#  'even': ['know',
#   'bother?',
#   'more',
#   'know',
#   'if',
#   'if',
#   'a',
#   'nearly',
#   'more,',
#   'a'],
#  'know': ['about',
#   'he’s',
#   'his',
#   'which',
#   'what?–Penguins',
#   'if',
#   'which',
#   'till',
#   'how',
#   'how',
#   'how',
#   'other',
#   'about',
#   'why?',
#   'why',
#   'what–',
#   'I’m',
#   'it’s',
#   'how',
#   'what',
#   'why',
#   'if',
#   'a',
#   'a',
#   'that',
#   'it!”',
#   'what?',
#   'why?'],
#  'lady.': ['This'],
#  'aware': ['of', 'of', 'of'],
#  'three': ['inches',
#   'scientists',
#   'ph.D.S,',
#   'things',
#   'strokes',
#   'months.”',
#   'feet'],
#  'inches': ['around'],
#  'his': ['head.',
#   'name,',
#   'life.',
#   'neck',
#   'stomach',
#   'own,',
#   'point',
#   'face–',
#   'way',
#   'teeth,',
#   'face',
#   'chest.”',
#   'naked'],
#  'head.': ['He’s'],
#  'He’s': ['living',
#   'got',
#   'worthless.',
#   'had',
#   'had',
#   'seen',
#   'seen',
#   'witnessed',
#   'just',
#   'gonna',
#   'still,',
#   'not',
#   'like'],
#  'living': ['in', 'thing,'],
#  'two-second': ['increments.'],
#  'increments.': ['The'],
#  'second': ['he’s', 'one.', 'of', 'of'],
#  'he’s': ['in',
#   'all',
#   'dead,”',
#   'dead.',
#   'looking',
#   'going–',
#   'looking',
#   'all',
#   'looking',
#   'thinking',
#   'going',
#   'just',
#   'already',
#   'your',
#   'nice.”'],
#  'left': ['Is'],
#  'Is': ['all', 'the', 'A', 'the'],
#  'knows': ['about,', 'more.'],
#  'about,': ['But', 'and'],
#  'if': ['he',
#   'just',
#   'we',
#   'we',
#   'we',
#   'every',
#   'you',
#   'you',
#   'I’m',
#   'I',
#   'you’re',
#   'they’re',
#   'it’s',
#   'you’re',
#   'it',
#   'she',
#   'you',
#   'it’s',
#   'something',
#   'you’re',
#   'you',
#   'you',
#   'it',
#   'you’re',
#   'you’re',
#   'you',
#   'the',
#   'murder',
#   'murder',
#   'touching',
#   'something',
#   'we',
#   'you’re',
#   'you',
#   'you'],
#  'dies,': ['this'],
#  'lady,': ['she’s'],
#  'gonna': ['be',
#   'say?',
#   'see',
#   'eat',
#   'do',
#   'talk',
#   'live.',
#   'do',
#   'happen',
#   'be',
#   'be',
#   'be–',
#   'be',
#   'be',
#   'happen.',
#   'happen.',
#   'be',
#   'like',
#   'let',
#   'fuck',
#   'help',
#   'feel',
#   'touch',
#   'touch',
#   'go',
#   'lay',
#   'watch',
#   'watch',
#   'get'],
#  'destroyed': ['Because'],
#  'has,': ['And'],
#  'has': ['because',
#   'him.',
#   'any',
#   'Parkinson’s,',
#   'happened',
#   'their',
#   'their',
#   'no',
#   'no',
#   'happened.',
#   'no',
#   'no',
#   'been',
#   'a',
#   'that.',
#   'been'],
#  'because': ['she',
#   'didn’t',
#   'for',
#   'you',
#   'you’ll',
#   'a',
#   'we',
#   'that’s',
#   'we'],
#  'him.': ['There’s', 'He', 'He’s'],
#  'no–': ['If'],
#  'had': ['one', 'to', 'no', 'invented', 'some', 'some', 'my', 'this', 'a'],
#  'person': ['in', 'And', 'was', 'I'],
#  'life,': ['She',
#   'Every',
#   'is',
#   'way',
#   '“and',
#   'you',
#   'being',
#   'Not',
#   'that’s'],
#  'would': ['not',
#   'all',
#   'just',
#   'be',
#   'really',
#   'take',
#   'squeeze',
#   'all',
#   'be',
#   'ever',
#   'not',
#   'never',
#   'never',
#   'be',
#   'murder.',
#   'murder',
#   'murder',
#   'just–',
#   'be',
#   'behave',
#   'be',
#   'happen'],
#  'keep': ['this', 'doing'],
#  'piece': ['of', 'of', 'of', 'of', 'of'],
#  'little': ['dog.',
#   'marble',
#   'boys',
#   'out',
#   'help,',
#   'encouragement,',
#   'shoulders.',
#   'bit,',
#   'kinder'],
#  'Even': ['if', 'if', 'if', 'if', 'today,'],
#  'some': ['young',
#   'people',
#   'old',
#   'experience.',
#   'experience.',
#   'people,',
#   'guy',
#   'road',
#   'shit.'],
#  'young': ['woman', 'dudes,', 'guys.', 'woman’s', 'girl’s'],
#  'woman': ['in', 'who', 'to', 'saying'],
#  'morning': ['Were'],
#  'Were': ['to'],
#  'say,': ['“good', '“ok,', '“you'],
#  '“good': ['morning,'],
#  'morning,': ['gladys,”'],
#  'gladys,”': ['She’d'],
#  'She’d': ['be'],
#  '“good,”': ['And'],
#  'flush': ['him', 'a', 'my'],
#  'him': ['down',
#   'down',
#   'a',
#   'go,',
#   'talking',
#   'two',
#   'off',
#   'go.',
#   'or',
#   'out,',
#   'fuck'],
#  'toilet,': ['just–', 'floats'],
#  'Poom!': ['Poom!', 'The', '“”', '“My'],
#  'keeps': ['bumping'],
#  'bumping': ['on'],
#  'drain.': ['Poom!'],
#  '“”': ['she', 'I', 'And', 'and', 'start', 'like', '“no,'],
#  'gives': ['up.', 'a'],
#  'up.': ['Ends', 'yeah.', 'Ha', 'It’s', 'Some', 'Yeah.”'],
#  'Ends': ['up'],
#  'up': ['just',
#   'in',
#   'here',
#   'for',
#   'my',
#   'and',
#   'is',
#   'into',
#   'With',
#   'or',
#   'to',
#   'to',
#   'and',
#   'at',
#   'really',
#   'to',
#   'being',
#   'motherless!”',
#   'your',
#   'a',
#   'and'],
#  'shitting': ['on', 'me?'],
#  'rest': ['of', 'of'],
#  'life.': ['P-p-p!',
#   'My',
#   'You',
#   'I',
#   'They',
#   'I',
#   'I',
#   'If',
#   'This',
#   'You',
#   'So,',
#   'You',
#   '“what’s'],
#  'P-p-p!': ['Poom!'],
#  '“My': ['Daughter'],
#  'Daughter': ['Likes'],
#  'Likes': ['Fish”'],
#  'Fish”': ['You'],
#  'You': ['ever',
#   'ever',
#   'think',
#   'know?',
#   'wake',
#   'burn',
#   'get',
#   'think',
#   'gotta',
#   'gotta–',
#   'can’t',
#   'know,',
#   'know,',
#   'know,',
#   'know,',
#   'know,',
#   'oldest',
#   'gotta',
#   'know',
#   'don’t',
#   'understand?',
#   'see?',
#   'know,',
#   'should.',
#   'know,',
#   'see',
#   'know',
#   'know,',
#   'don’t',
#   'know,',
#   'always',
#   'know,',
#   'really',
#   'must',
#   'don’t',
#   'just',
#   'get',
#   'get',
#   'get',
#   'get',
#   'get',
#   'just–“”',
#   'get',
#   'get',
#   'get',
#   'get',
#   'get',
#   'get',
#   'know,',
#   'tested',
#   'wouldn’t',
#   'wouldn’t',
#   'know,',
#   'didn’t',
#   'know,',
#   'all',
#   'don’t',
#   'can',
#   'really',
#   'can',
#   'guys'],
#  'ever': ['flush',
#   'go',
#   'happened',
#   'happens',
#   'been',
#   'says,',
#   'turn',
#   'do',
#   'happened.',
#   'happened.'],
#  'pet': ['down'],
#  'toilet?': ['I'],
#  'daughter’s': ['fish', 'like,'],
#  'fish': ['down', 'was', 'live'],
#  'toilet.': ['I'],
#  'came': ['home,', 'out'],
#  'home,': ['the'],
#  'dead.': ['She', 'He'],
#  'wasn’t': ['home'],
#  'home': ['from', 'From', 'and'],
#  'from': ['school', 'across', 'his', 'now,', 'the', 'nuts,', 'nuts,'],
#  'school': ['yet,', 'because'],
#  'yet,': ['so', 'But'],
#  'so': ['I',
#   'we’re',
#   'I’m',
#   'there',
#   'excited',
#   'much–',
#   'is',
#   'many',
#   'great.',
#   'I',
#   'I',
#   'much.',
#   'do',
#   'cute!',
#   'bad.',
#   'shitty',
#   'bad.',
#   'much',
#   'quickly?',
#   'you'],
#  'flushed': ['the'],
#  'fish,': ['And'],
#  'that’s': ['a',
#   'what',
#   'her',
#   'later',
#   'gonna',
#   'how',
#   'the',
#   'happening',
#   'an'],
#  'weird': ['moment,', 'thing', 'selection'],
#  'moment,': ['too,'],
#  'too,': ['’cause'],
#  '’cause': ['fish',
#   'I',
#   'it’s',
#   'why',
#   'getting',
#   'you',
#   'they’re',
#   'never',
#   'this',
#   'none',
#   'this',
#   'it’s',
#   'it',
#   'of',
#   'women',
#   'they',
#   'you',
#   'kids',
#   'life',
#   'it',
#   'you',
#   'you',
#   'it',
#   'it’s',
#   'it’s'],
#  'water.': ['So'],
#  'So': ['you', 'you', 'he', 'he’s–“no,”', 'I’m', 'now', 'you’re'],
#  'put': ['it', 'on', 'on', 'it', 'bacon', 'your', 'people', 'a'],
#  'floats': ['to'],
#  'bottom,': ['Like,'],
#  '“yeah,': ['he’s', 'all', 'it’s'],
#  'dead,”': ['And'],
#  'then': ['you',
#   'my',
#   'there’s',
#   'I',
#   'I',
#   'they’re',
#   'I',
#   'quit',
#   'got',
#   'they',
#   'sometimes',
#   'the',
#   'Anna',
#   'goes,',
#   'get',
#   'you',
#   'add',
#   'really',
#   'there’s',
#   'this'],
#  'flush,': ['and'],
#  'looks': ['like', 'like'],
#  'goes,': ['“wait', '“well', '“well,', '“you'],
#  '“wait': ['a'],
#  'second!': ['Aw,'],
#  'Aw,': ['shit!'],
#  'shit!': ['“I'],
#  'taking': ['a', 'a'],
#  'nap!': ['Jesus!'],
#  'Jesus!': ['“you'],
#  '“you': ['gotta', 'chase', 'wanna', 'can’t', 'know', 'have'],
#  'gotta': ['be', 'deal', 'chase', 'wipe', 'explain'],
#  'constant': ['motion'],
#  'motion': ['To'],
#  'To': ['get', 'standing', 'tit', 'lose'],
#  'get': ['any',
#   'to',
#   'a',
#   'it!',
#   'over',
#   'a',
#   'started',
#   'a',
#   'to',
#   'to,',
#   'up',
#   'momentum,',
#   'an',
#   'my',
#   'through',
#   'in',
#   'to',
#   'to',
#   'to',
#   'to',
#   'the',
#   'your',
#   'married.',
#   'married,',
#   'divorced',
#   'to',
#   'to',
#   'to',
#   'with',
#   'when',
#   'life.',
#   'to',
#   'to',
#   'to',
#   'to',
#   'to',
#   'to–',
#   'to',
#   'that',
#   'to',
#   'to',
#   'to',
#   'to',
#   'to',
#   'to',
#   'to',
#   'as',
#   'a',
#   'shot',
#   'shot,',
#   'shot',
#   'to'],
#  'respect': ['in'],
#  'house.”': ['And'],
#  'daughter': ['comes', 'likes', 'was'],
#  'comes': ['home.', 'in', 'over', 'over,', 'with.', 'from,'],
#  'home.': ['“why'],
#  '“why': ['did', 'do'],
#  'did': ['he', 'he', 'nothing', 'they', 'we'],
#  'die,': ['da–”', 'and'],
#  'da–”': ['Come'],
#  'Come': ['on.', 'on,', 'on,'],
#  'on.': ['What', 'Come'],
#  'What': ['am', 'is', '‘Old’', 'are', 'happened', 'kind'],
#  'am': ['I', 'gonna', 'the', 'the', 'I'],
#  'say?': ['Why'],
#  'Why': ['did', 'do', 'are'],
#  'die?': ['Because'],
#  'who': ['gives',
#   'works',
#   'there’s',
#   'never',
#   'we’ve',
#   'he',
#   'didn’t',
#   'have',
#   'manufactures',
#   'has'],
#  'shit?': ['That’s'],
#  'reason.': ['That’s', 'The'],
#  'actual': ['reason,', 'personality.', 'child'],
#  'reason,': ['is'],
#  'didn’t': ['matter',
#   'know',
#   'love',
#   'look',
#   'take',
#   'clap.',
#   'think',
#   'have',
#   'get',
#   'murder',
#   'listen',
#   'give'],
#  'matter': ['That', 'how', 'who’s'],
#  'That': ['he',
#   'thing',
#   'we',
#   'is',
#   'says',
#   'would',
#   'guy',
#   'is',
#   'is',
#   'shit',
#   'takes',
#   'doesn’t',
#   'ends',
#   'you',
#   'is',
#   'comes',
#   'is',
#   'is',
#   'I'],
#  'alive.': ['That’s'],
#  'why': ['he’s', 'animals', 'they', 'not', 'first.', 'I’m', 'we', 'I’m'],
#  'He': ['didn’t',
#   'thinks',
#   'goes,',
#   'says,',
#   'went',
#   'saw',
#   'took',
#   'got',
#   'knows',
#   'saw',
#   'went',
#   'still'],
#  'name,': ['and'],
#  'back.': ['These'],
#  'These': ['are', 'kids'],
#  'facts': ['about'],
#  'fish’s': ['life.'],
#  'My': ['daughter',
#   'daughter’s',
#   'asshole–',
#   'asshole’s',
#   'asshole’s',
#   'Life',
#   'ex-wife',
#   'daughter'],
#  'likes': ['fish.'],
#  'fish.': ['We'],
#  'We': ['took', 'get', 'saw', 'could', 'love', 'have', 'just'],
#  'took': ['her', 'both', 'a'],
#  'aquarium.': ['I'],
#  'both': ['my', 'sides,', 'tits.'],
#  'kids': ['to',
#   'go',
#   'every',
#   'are',
#   'can’t',
#   'doing',
#   'are',
#   'grow',
#   '“when',
#   'with',
#   'dying',
#   'did'],
#  'aquarium': ['in'],
#  'boston,': ['And'],
#  'we': ['were',
#   'don’t',
#   'call',
#   'would',
#   'are',
#   'fully',
#   'got',
#   'were',
#   'were',
#   'could',
#   'have.',
#   'evolve,',
#   'choose',
#   'going?”',
#   'just',
#   'would',
#   'love',
#   'breastfeed,',
#   'do,',
#   'love',
#   'live',
#   'all',
#   'can',
#   'really',
#   'all',
#   'traverse',
#   'fuck',
#   'have'],
#  'were': ['looking',
#   'still',
#   'in',
#   'saying',
#   'cute,',
#   'in',
#   'just',
#   'finished.',
#   'great.'],
#  'seal,': ['or'],
#  'or': ['sea',
#   'almost',
#   'doing',
#   'older?',
#   'older,',
#   'younger?',
#   'younger,',
#   'across.',
#   'not',
#   'like,',
#   'a',
#   'whatever',
#   'anything,',
#   'just',
#   'some',
#   'serves',
#   'hurt,',
#   'let'],
#  'sea': ['lion.', 'lions'],
#  'lion.': ['I'],
#  'which': ['one.', 'one.', 'is', 'case'],
#  'one.': ['I', 'I', '“Nah.”', '“yeah,', 'That’s', 'Nobody'],
#  'care.': ['I', 'There’s,'],
#  'need': ['to', 'to', 'to', 'to', 'to', 'to', 'the', 'to'],
#  'separate': ['things.'],
#  'things.': ['I', 'The', 'Everybody'],
#  'really': ['don’t.',
#   'disgusting',
#   'see',
#   'suck.',
#   'believe',
#   'gotta',
#   'want',
#   'fast,',
#   'is–',
#   'a',
#   'have',
#   'badly',
#   'dumb',
#   'actually',
#   'need',
#   'sucks',
#   'nice,',
#   'have'],
#  'don’t.': ['They', '“Their'],
#  'They': ['don’t',
#   'go–',
#   'swim',
#   'go,',
#   'don’t',
#   'just',
#   'just',
#   'get',
#   'get',
#   'just',
#   'come',
#   'had',
#   'see',
#   'would',
#   'just',
#   'jump'],
#  'care,': ['and'],
#  'There’s,': ['like,', 'like,'],
#  'scientists': ['Who', 'could'],
#  'Who': ['give', 'can’t'],
#  'give': ['a', 'you', 'a', 'a'],
#  'what': ['we',
#   'are',
#   'old',
#   'happens',
#   'I',
#   'I’m',
#   'was',
#   'our',
#   'he’s',
#   'I',
#   'they',
#   'I',
#   'you',
#   'you',
#   'a',
#   'an',
#   'am',
#   'a',
#   'would',
#   'happened',
#   'you'],
#  'call': ['all'],
#  'those': ['things.', 'in', 'few', '“it', 'guys.”', 'pyramids?”'],
#  'could': ['go',
#   'all',
#   'say',
#   'use',
#   'only',
#   'hear',
#   'ask',
#   'be',
#   'drive',
#   'die',
#   'just'],
#  'go': ['on',
#   'to',
#   'to',
#   'to',
#   'like',
#   'find',
#   'fuck',
#   'on',
#   'the',
#   'out',
#   'out',
#   'out',
#   'and',
#   'to',
#   'upstairs',
#   'in',
#   'in',
#   'like',
#   'to',
#   'to'],
#  'TV': ['tomorrow', 'or', 'with'],
#  'tomorrow': ['And', 'at'],
#  '“ok,': ['everybody.'],
#  'everybody.': ['“from', 'There'],
#  '“from': ['now'],
#  'on,': ['seals', 'dude!', 'come', 'come', 'come', 'let’s'],
#  'seals': ['and', 'now,”', 'don’t'],
#  'lions': ['and'],
#  'walruses,': ['And–you'],
#  'And–you': ['know'],
#  'what?–Penguins': ['are'],
#  'now,”': ['And', 'and'],
#  'right.': ['Fine.', 'All', 'shit.', 'It', 'You'],
#  'Fine.': ['Yes.'],
#  'Yes.': ['Whatever,', 'Please,'],
#  'Whatever,': ['man.”', 'just'],
#  'man.”': ['Anyway,'],
#  'Anyway,': ['so', 'seals', 'there’s', 'but', 'we'],
#  'we’re': ['looking',
#   'all',
#   'all',
# ...
#  'making': ['breakfast.', 'these,'],
#  'breakfast.': ['You'],
#  'burn': ['your'],
#  'toast,': ['and'],
#  'too': ['late', 'good,', 'bad.”'],
#  'late': ['to'],
#  'try': ['again,', 'to', 'to'],
#  'again,': ['And', 'if'],
#  'kid': ['comes', 'kicks', 'is', 'and', 'dancing', 'on', 'play'],
#  'says,': ['“beh,”', '“excuse', '“this', 'and', '”'],
#  '“beh,”': ['and'],
#  '“fine,”': ['And'],
#  '“why?”': ['You'],
#  'mail': ['That'],
#  'says': ['that', 'yes,'],
#  'phone’s': ['different,'],
#  'different,': ['And'],
#  'mortgage': ['is'],
#  'company': ['now.'],
#  'now.': ['What?', 'Right', 'If', '“You’re', 'I', 'Divorce', 'Do'],
#  'What?': ['I', 'I'],
#  'it!': ['Then', '“there’s', 'I', 'That’s', 'You'],
#  'Then': ['you’re'],
#  'work': ['like,'],
#  'bother?': ['“shit!'],
#  '“shit!': ['Goddamn', 'Come'],
#  'Goddamn': ['it!', 'it.'],
#  '“there’s': ['always', 'totally', 'someone', 'a'],
#  'fucking': ['cheetahs', 'any', 'kid.', 'sucks', 'driving', 'roof'],
#  'cheetahs': ['at'],
#  'train': ['station!'],
#  'station!': ['Stop'],
#  'Stop': ['it!”'],
#  'it!”': ['You', 'If', 'Because'],
#  'sharks–': ['Do'],
#  'sharks': ['would', 'are', 'think'],
#  'embarrassed': ['If'],
#  'knew': ['that', 'what'],
#  'their': ['fins',
#   'life',
#   'time.',
#   'time.',
#   'genitals',
#   'entire',
#   'phone,',
#   'vision',
#   'actual',
#   'phone,',
#   'faces.',
#   'parents,',
#   'face',
#   'own',
#   'brain',
#   'food',
#   'medication'],
#  'fins': ['Sticking'],
#  'Sticking': ['out'],
#  'water?': ['I'],
#  'they’d': ['be'],
#  'bummed': ['’cause'],
#  'slick.': ['They'],
#  'swim': ['around'],
#  '“hey,': ['nobody', 'I’m', 'fuck', 'fuck'],
#  'nobody': ['has', 'tied', 'for', 'kisses', 'would'],
#  'idea': ['what’s', 'If', 'he’s'],
#  'what’s': ['down'],
#  'here,”': ['And'],
#  'totally': ['a', 'up.', 'HD.'],
#  'shark': ['right'],
#  'right': ['there.”',
#   'away!',
#   'now.”',
#   'now.',
#   'now.',
#   'now!”',
#   'now.',
#   'there',
#   'now.”',
#   'now,”',
#   'next',
#   'to',
#   'in'],
#  'there.”': ['It'],
#  'wouldn’t': ['be', 'trust', 'like'],
#  'fun': ['being', 'kind', 'youth.'],
#  'predator,': ['either.', 'imagine'],
#  'either.': ['If', 'They’re'],
#  'time': ['you’re',
#   'for',
#   'over',
#   'you',
#   'I',
#   'it',
#   'you',
#   'I’m',
#   'Just',
#   'in',
#   'it’s',
#   'a'],
#  'hungry,': ['You'],
#  'chase': ['a', 'the'],
#  'Who’s': ['running'],
#  'running': ['for', 'out'],
#  'gotta–': ['“come'],
#  '“come': ['on,', 'on!'],
#  'dude!': ['Shit,'],
#  'Shit,': ['get'],
#  'over': ['here!”',
#   'And',
#   'to',
#   'to',
#   'where',
#   'on',
#   '45.',
#   'income',
#   'his',
#   'by',
#   'dead'],
#  'here!”': ['And', '“Divorce”'],
#  'hold': ['him'],
#  'bite': ['his'],
#  'neck': ['Till'],
#  'Till': ['he'],
#  'shuts': ['the'],
#  'fuck': ['up',
#   'one',
#   'one.',
#   'up',
#   'down',
#   'home',
#   'me.”',
#   'me',
#   'you!”',
#   'you!”?',
#   'about',
#   'others'],
#  'minute': ['So'],
#  'can': ['just',
#   'tell',
#   'tell',
#   'feel–',
#   'see',
#   'grab',
#   'go',
#   'just',
#   'imagine.',
#   'tell',
#   'say',
#   'hack',
#   'get',
#   'be',
#   'do',
#   'do',
#   'have',
#   'leave'],
#  'sit': ['there'],
#  'eat': ['his', 'the', 'food.'],
#  'stomach': ['Before'],
#  'Before': ['you'],
#  'work.': ['That'],
#  'suck.': ['That’s'],
#  'go,': ['“let’s', '“no.', '“yes,', '“good-bye,', '“that’s', '“hey,', '“how'],
#  '“let’s': ['do'],
#  'man.': ['“you', '“I', '“If'],
#  'parents': ['away.', 'would'],
#  'away.': ['I'],
#  'kid,': ['and'],
#  'circle': ['back.”'],
#  'back.”': ['That’s'],
#  '“fuck': ['it.'],
#  'eating': ['babies.', 'bacon,'],
#  'babies.': ['This'],
#  'bullshit.”': ['“grownups'],
#  '“grownups': ['ain’t'],
#  'ain’t': ['worth'],
#  'worth': ['the'],
#  'meat.”': ['Whoops,'],
#  'Whoops,': ['all'],
#  'All': ['right.'],
#  'shit.': ['Goddamn', 'He', 'I', 'Thanks'],
#  'Idiot.': ['This'],
#  'isn’t': ['a'],
#  'gay': ['voice,', 'man,'],
#  'voice,': ['by'],
#  'way.': ['It’s'],
#  'It’s': ['not.',
#   'finished!”',
#   'OK,”',
#   'like',
#   'just',
#   '’cause',
#   'like',
#   'just',
#   'pussy',
#   'a',
#   'how',
#   'how',
#   'really',
#   'not',
#   'like',
#   'usually',
#   'the',
#   'over.',
#   'like',
#   'totally',
#   'so',
#   'a',
#   'a',
#   'pretty',
#   '’cause',
#   'always',
#   'become',
#   'a'],
#  'not.': ['Shut', 'Of', 'Of', 'Jesus.', 'Of'],
#  'Shut': ['up.', 'up.'],
#  'yeah.': ['“Courtyard'],
#  '“Courtyard': ['Confrontation”'],
#  'Confrontation”': ['I'],
#  'York': ['city,', 'once,'],
#  'city,': ['and'],
#  'OK': ['there.', 'at', 'as'],
#  'building.': ['I', 'He'],
#  'never': ['lived', 'identify', 'find', 'get', 'gonna', 'do', 'do', 'killed'],
#  'lived': ['in'],
#  'before.': ['When'],
#  'When': ['I', 'tit', 'you', 'you’re'],
#  'growing': ['up,'],
#  'up,': ['I', '“and', 'Janet.”'],
#  'money.': ['I'],
#  'mom': ['didn’t.'],
#  'didn’t.': ['Didn’t'],
#  'Didn’t': ['matter.'],
#  'matter.': ['I', 'I'],
#  'child.': ['But'],
#  'used': ['to'],
#  'nice.': ['There’s,', 'I', 'OK.'],
#  'courtyard': ['With', 'of', 'for', 'And'],
#  'With': ['flowers', 'dirty', 'a'],
#  'flowers': ['and'],
#  'fountain': ['with', 'sculptors', 'made'],
#  'marble': ['boys'],
#  'boys': ['pissing.', 'pissing'],
#  'pissing.': ['I'],
#  'know.': ['What', 'Nobody', 'I', 'I', 'I', 'You', 'I’d'],
#  'fountains?': ['Like,'],
#  'sculptors': ['are'],
#  'pedophiles,': ['basically.'],
#  'basically.': ['You'],
#  'can’t': ['get', 'keep', 'take', 'be', 'see'],
#  'made': ['without–', 'me'],
#  'without–': ['“can'],
#  '“can': ['you', 'I'],
#  'make': ['me', 'trips', 'it', 'one'],
#  'me': ['a',
#   'forever!”',
#   'and',
#   'from',
#   'like,',
#   'on',
#   'to',
#   'a',
#   'I',
#   'with',
#   'a',
#   'later,”',
#   'in',
#   'half',
#   'go',
#   'now.'],
#  'fountain?”': ['“yes,'],
#  '“yes,': ['I’ll', 'of'],
#  'I’ll': ['get', 'be', 'realize,', 'help', 'go', 'see', 'prove', 'give'],
#  'started': ['right'],
#  'away!': ['“Yes!'],
#  '“Yes!': ['Yes!'],
#  'Yes!': ['It’s'],
#  'finished!”': ['And'],
#  'pissing': ['on'],
#  'face': ['Of', 'trying', 'and'],
#  'Of': ['a',
#   'their',
#   'something',
#   'your',
#   'course',
#   'course',
#   'course',
#   'course',
#   'course,',
#   'course,',
#   'course,',
#   'course'],
#  'Greek': ['god'],
#  'god': ['that'],
#  'lot.': ['“just', 'I’ll', 'If'],
#  '“just': ['piss', 'go'],
#  'piss': ['on'],
#  'forever!”': ['Anyway,'],
#  'building,': ['And'],
#  'first': ['week', 'time,', 'date', 'date', 'tit', 'time', 'frame'],
#  'week': ['in'],
#  'year': ['ago,', 'has'],
#  'ago,': ['I'],
#  'went': ['down', 'to', 'up', 'over'],
#  'good,': ['you', 'And', 'and'],
#  'Sunday': ['morning.'],
#  'least': ['presentable'],
#  'presentable': ['hour.'],
#  'hour.': ['There’s'],
#  'lot': ['of,', 'of', 'of', 'of', 'of', 'of', 'of'],
#  'of,': ['you', 'you'],
#  'know,': ['just',
#   'food',
#   'there’s',
#   'just',
#   'there’s',
#   'some',
#   'there',
#   'you’re',
#   'Like,',
#   'young',
#   'when',
#   'when',
#   '“well…',
#   'cakes',
#   '’cause',
#   'baby',
#   'like',
#   'like',
#   'a',
#   'I’m',
#   'it’s',
#   'man.',
#   'you’d',
#   'you'],
#  'stains,': ['Just'],
#  'whatever…': ['And'],
#  'sitting': ['there.',
#   'on',
#   'there',
#   'watching',
#   'on',
#   'down.',
#   'anywhere,',
#   'so',
#   'and',
#   'down',
#   'here.',
#   'in'],
#  'So?': ['Shut'],
#  'Ha': ['ha', 'ha', 'ha!'],
#  'ha': ['ha!', 'ha!–', 'ha!'],
#  'ha!': ['Anyway,', 'I', '“well,', 'Rrgh…”'],
#  'was.': ['I’m', '“Getting', 'I'],
#  'stone': ['bench'],
#  'bench': ['of'],
#  'feeling': ['a', 'bad'],
#  'fancy': ['doormen'],
#  'doormen': ['and'],
#  'me.': ['I', '“what?', 'Everything'],
#  'notice': ['he’s'],
#  'across': ['the'],
#  'courtyard,': ['And'],
#  'spiffy-looking.': ['He’s'],
#  'brown': ['shoes,'],
#  'shoes,': ['and'],
#  'tell': ['he', 'he’s', 'it’s'],
#  'thinking': ['I', 'of', 'about'],
#  'thinks': ['I', 'I'],
#  'wandered': ['in'],
#  'off': ['the', 'at', 'the'],
#  'streets': ['And'],
#  'sat': ['in'],
#  'courtyard.': ['I'],
#  'coming': ['over'],
#  'dealing': ['with'],
#  'own,': ['and'],
#  'thinking,': ['Like,'],
#  '“please': ['do', 'use'],
#  'Please,': ['come'],
#  'come': ['on,', 'on.', 'on,', 'on,”', 'to', 'back'],
#  'on,”': ['And'],
#  'trying': ['to', 'to', 'to', 'all', 'to'],
#  'more': ['gross,', 'hours?”', 'information', 'people'],
#  'gross,': ['And'],
#  'I’m,': ['like,'],
#  'pulling': ['up'],
#  'shirt,': ['“”'],
#  '“no.': ['That’s', 'That'],
#  'all,”': ['And'],
#  'me,': ['“”', '“do', 'then.', 'the', 'The', 'this', 'and', 'And', 'I'],
#  '“Num': ['num'],
#  'num': ['num!”'],
#  'num!”': ['I’m'],
#  'excited': ['to', 'I'],
#  'confrontation': ['Where'],
#  'Where': ['I’m', 'you', 'my', 'are', 'else', 'outside'],
#  'wrong': ['at', 'with'],
#  'am.': ['“rrgh!”'],
#  '“rrgh!”': ['So'],
#  'over,': ['says,', 'and'],
#  '“excuse': ['me,'],
#  '“do': ['you', 'I'],
#  'building?”': ['And'],
#  'said,': ['“no,”', '“no.”', '“I', '“well,', '“hi.', '“worthless', '“hey,'],
#  '“no,”': ['’cause'],
#  'start': ['there?',
#   'pushing–',
#   'having',
#   'getting',
#   'with',
#   'kind',
#   'passing',
#   'running'],
#  'there?': ['I', 'That’s'],
#  '“no.”': ['He'],
#  '“well': ['then,'],
#  'then,': ['what', 'if'],
#  'here?”': ['And'],
#  'rest.': ['I’m'],
#  'hard': ['time.”'],
#  'time.”': ['He'],
#  '“this': ['is'],
#  'private': ['property,”'],
#  'property,”': ['And'],
#  '“well,': ['I', 'if', 'all', 'yes.'],
#  'believe': ['in', 'that.', 'it,'],
#  'that.”': ['You', '’cause', 'No.'],
#  'worst': ['things',
#   'part',
#   'part',
#   'part',
#   'part',
#   'thing',
#   'person',
#   'people',
#   'thing',
#   'thing'],
#  'things': ['I', 'I', 'for,', 'like,', 'I’ve', 'I'],
#  'say': ['from', 'things', 'yes,', 'yes', 'it’s', 'that', 'good-bye', 'to'],
#  'point': ['of'],
#  'view': ['is'],
#  'basically': ['all'],
#  'saying,': ['And', 'if'],
#  'leave,': ['I’m'],
#  'talk': ['to'],
#  'doorman.”': ['I'],
#  'stay,': ['like,'],
#  'five': ['more', 'years', 'years,'],
#  'hours?”': ['So'],
#  'he’s–“no,”': ['and'],
#  'goes': ['over'],
#  'doorman': ['and', 'like', 'going,'],
#  'talking': ['about'],
#  'this,': ['and', 'and'],
#  'going,': ['“no.', '“I', '“dude,'],
#  'lives': ['here.', 'are'],
#  'OK,”': ['And'],
#  'face–': ['mwah'],
#  'mwah': ['mwah!'],
#  'mwah!': ['Num'],
#  'Num': ['num!–'],
#  'num!–': ['It'],
#  'so–': ['It'],
#  'beautiful': ['cocktail'],
#  'cocktail': ['of'],
#  'anger': ['and'],
#  'confusion.': ['It’s'],
#  'invented': ['a'],
#  'new': ['way', 'problem.'],
#  'way': ['to',
#   'home',
#   'better',
#   'better.',
#   'more.',
#   'more',
#   'better',
#   'we’re',
#   'they’re',
#   'to',
#   'is'],
#  'hurt': ['somebody’s'],
#  'somebody’s': ['feelings.', 'son.'],
#  'feelings.': ['That’s'],
#  '“Getting': ['What', 'Older'],
#  '‘Old’': ['Is”'],
#  'Is”': ['I’m'],
#  '45': ['now,', 'or', 'or'],
#  'now,': ['So', 'people', 'they’ll'],
#  'either': ['halfway'],
#  'halfway': ['through'],
#  'healthy': ['life', 'life.'],
#  'almost': ['done'],
#  'done': ['with', 'with', 'with'],
#  'not-so-healthy': ['life.'],
#  'won’t': ['know'],
#  'till': ['it’s'],
#  'where': ['this', 'I’m', 'you’re', 'do', 'you', 'human', 'they’re'],
#  'long': ['I’m', 'as', 'you', 'as', 'as'],
#  'live.': ['I'],
#  'Nobody': ['knows,', 'touches', 'does', 'fucks', 'ever', 'watches'],
#  'knows,': ['I'],
#  'guess.': ['I'],
#  'expectancy': ['is'],
#  'good.': ['We', 'He’s'],
#  'run,': ['you'],
#  'Some': ['people', 'kid', 'women', 'guy,', 'people'],
#  'people': ['die',
#   'will',
#   'get',
#   'that',
#   'here,',
#   'out',
#   'in',
#   'here,',
#   'here.',
#   'that',
#   'are',
#   'out',
#   'who',
#   'out',
#   'are',
#   'say',
#   'And',
#   'holding',
#   'I',
#   'are',
#   'in',
#   'get,',
#   'would',
#   'would',
#   'Would',
#   'in',
#   'has',
#   'in'],
#  'early,': ['you'],
#  'will': ['be', 'be.', 'go,', 'write'],
#  '“that’s': ['too', 'a', 'what', 'very'],
#  'bad.”': ['If'],
#  'years': ['from'],
#  'they’ll': ['be'],
#  'right,”': ['like'],
#  'even–': ['It’s–', 'And'],
#  'It’s–': ['Like,'],
#  'soon': ['as'],
#  '50,': ['you’re'],
#  'candidate.': ['You'],
#  'candlelight': ['vigils'],
#  'vigils': ['for'],
#  '50-year-old': ['guys'],
#  'guys': ['that', 'like', 'when', 'were'],
#  'pushing–': ['You'],
#  '80s,': ['90s.'],
#  '90s.': ['You'],
#  'to,': ['like,', 'like,'],
#  '114,': ['and'],
#  'news,': ['and'],
#  'guy,': ['“I', '“yeah.', 'try', 'we’re'],
#  'met': ['Napoleon.”'],
#  'Napoleon.”': ['No,'],
#  'No,': ['you'],
#  'didn’t,': ['you'],
#  'liar,': ['You'],
#  'oldest': ['liar'],
#  'liar': ['in'],
#  'world.': ['But'],
#  '45,': ['you', 'Look,'],
#  'moments': ['Where', 'where'],
#  'getting': ['what', 'up', 'older,', 'older,', 'older', 'caught'],
#  'is,': ['Especially', 'every'],
#  'Especially': ['if', 'smarter'],
#  'take': ['care', 'sitting', 'it.”', 'a'],
#  'care': ['of'],
#  'yourself,': ['you'],
#  '“wow,': ['this'],
#  'seems': ['early'],
#  'early': ['for'],
#  'this.”': ['Like,', 'Nobody’s'],
#  'something': ['that',
#   'has',
#   'that',
#   'really',
#   'terrible',
#   'that’s',
#   'happened'],
#  'happens': ['to', 'to', 'to', 'in', 'in'],
#  'watching': ['TV', 'a', 'it,', 'the', 'your'],
#  'nothing,': ['And'],
#  'sudden,': ['I’ll'],
#  'realize,': ['“I'],
#  'wipe': ['my', 'my', 'my'],
#  'ass': ['right', 'right', 'with'],
#  'now.”': ['“I', 'Gotta', '“I’m', 'And'],
#  'nothing': ['happened,', 'To', 'you', 'to'],
#  'happened,': ['But'],
#  'Right': ['now.”', 'in'],
#  'Gotta': ['make'],
#  'trips': ['to'],
#  'bathroom': ['just', 'and'],
#  'ass.': ['How'],
#  'How': ['does', 'many', 'do', 'do', 'many', 'do', 'do', 'did'],
#  'does': ['this', 'that.'],
#  'happen': ['already?', 'next.', 'if'],
#  'already?': ['I’m'],
#  '45.': ['Already,', 'How', 'This'],
#  'Already,': ['my'],
#  'asshole’s': ['just', 'like', 'like'],
#  '“Just–': ['”'],
#  '”': ['My', 'my'],
#  'asshole–': ['My'],
#  'waistband': ['on'],
#  'pajama': ['bottoms,'],
#  'bottoms,': ['Just'],
#  'kinda…': ['Loose'],
#  'Loose': ['and'],
#  'ineffectual.': ['My'],
#  'bag': ['of', '“with', '“because'],
#  'leaves': ['that', 'onto'],
#  'tied': ['up.'],
#  'lawn,': ['full'],
#  'full': ['and'],
#  'open,': ['Puking'],
#  'Puking': ['leaves'],
#  'onto': ['the', 'your'],
#  'grass': ['with'],
#  'wisp': ['of'],
#  'wind.': ['Some'],
#  'kicks': ['it'],
#  'From': ['a', 'a'],
#  'tough': ['day', 'right'],
#  'day': ['at', 'of', 'in', 'Will'],
#  'school.': ['“rats.”', 'They'],
#  '“rats.”': ['That’s'],
#  'accurate': ['description'],
#  'description': ['of'],
#  'asshole.': ['Here’s', 'Just'],
#  'Here’s': ['another', 'what', 'the', 'your'],
#  'age': ['right'],
#  'I’m–': ['OK.'],
#  'OK.': ['Say', 'That’s', 'Burn', 'Cool.”', 'Here.', 'Back'],
#  'Say': ['I’m'],
#  'down.': ['If'],
#  'anywhere,': ['which–ha'],
#  'which–ha': ['ha'],
#  'ha!–': ['I'],
#  'much–': ['I'],
#  'standing': ['and', 'there'],
#  'better': ['than', 'at', 'when', 'because', 'than'],
#  'than': ['coming.', 'you,', 'you', 'a', 'him,', 'men?', 'the'],
#  'coming.': ['This'],
#  'better.': ['This', 'I’d', 'That’s', 'My'],
#  'what–': ['At', 'OK.'],
#  'At': ['my'],
#  'age,': ['if'],
#  'somebody': ['tells', 'And', 'on', 'who'],
#  'tells': ['me', 'you'],
#  'room,': ['I'],
#  'told': ['all', 'you', 'you'],
#  'information': ['why', 'than'],
#  'first.': ['You'],
#  'explain': ['all'],
#  '“what?': ['Why'],
#  'I–': ['no.', 'everywhere?'],
#  'no.': ['Why,', 'A'],
#  'Why,': ['though?”'],
#  'though?”': ['“Your'],
#  '“Your': ['car'],
#  'car': ['is', 'with', 'is'],
#  'towed': ['right'],
#  'now!”': ['“Well,'],
#  '“Well,': ['that’s'],
#  'then.': ['That’s–'],
#  'That’s–': ['I'],
#  'accept': ['that.”'],
#  'whole': ['thing.', 'nation', 'life,', 'species’', 'thing.', 'bunch', 'race'],
#  'thing.': ['It', 'Tell', 'There’s', 'You', 'That’s', '“That’s', 'It’s'],
#  'means': ['first,', 'I', 'that', 'people', 'there’s'],
#  'decide,': ['“do'],
#  'alive': ['anymore?”', 'kid'],
#  'anymore?”': ['Like,'],
#  'let’s': ['start', 'get–'],
#  'that,': ['And', 'but'],
#  'gotta,': ['“”'],
#  'rocking': ['to'],
#  'momentum,': ['“”'],
#  'an': ['old',
#   'eight-year-old',
#   'interview',
#   'education,',
#   'argument',
#   'insane',
#   'old,',
#   'accident',
#   'attentive,',
#   'amazing',
#   'amazing',
#   'ama–',
#   'indictment.',
#   'elevator',
#   'example,'],
#  'Honda': ['out'],
#  'snow': ['bank.'],
#  'bank.': ['“shit.”'],
#  '“shit.”': ['“Putting'],
#  '“Putting': ['On'],
#  'Socks”': ['The'],
#  'part': ['of', 'of', 'of', 'of', 'of', 'of', 'of', 'of'],
#  'socks.': ['Putting', 'Sorry,', '“If'],
#  'Putting': ['on', 'on'],
#  'socks': ['is', 'because–'],
#  'be.': ['Even', 'And'],
#  'terrible': ['day', 'happens', 'tragedy,'],
#  'future': ['Where', 'star!”'],
#  'grandmother': ['is'],
#  'murdered': ['by', 'child', 'kid'],
#  'grandmother,': ['If'],
#  'happened': ['to', 'to', 'to', 'to', 'at', 'to', 'to'],
#  'Will': ['be'],
#  'because–': ['Putting'],
#  'socks,': ['that'],
#  'to–': ['Here’s', 'It’s', 'you'],
#  'hands': ['past', 'jacked'],
#  'past': ['my'],
#  'pointed': ['toe.'],
#  'toe.': ['I'],
#  'folding': ['a'],
#  'bowling': ['ball'],
#  'ball': ['in'],
#  'half.': ['Soon'],
#  ...}

# %%
generate_sentence(jim_dict)
# Out:
# 'Get into your constitution. And on his head, and one of America called, uh… Maybe.'

# %%
generate_sentence(louis_dict)
# Out:
# 'Wheeling by, And he’s all fat up for his way is way to another company.'

# %%
#Part 2
import random
import string
def new_generate_sentence(chain, count=15):
    '''Input a dictionary in the format of key = current word, value = list of next words
       along with the number of words you would like to see in your generated sentence.'''

    # Capitalize the first word
    word1 = random.choice(list(chain.keys()))
    sentence = word1.capitalize()

    # Generate the second word from the value list. Set the new word as the first word. Repeat.
    for i in range(count-1):
        word2 = random.choice(chain[word1])
        word1 = word2
        sentence += ' ' + word2

    # End it with a period
    sentence += random.choice(list(string.punctuation))
    return(sentence)

# %%
new_generate_sentence(jim_dict)
# Out:
# 'Ones? And as men. This is the movie Hustle & Flow. Now… The kid was('

# %%
new_generate_sentence(louis_dict)
# Out:
# 'Wish the number-one threat to each other book in the worst person was gonna be–#'
